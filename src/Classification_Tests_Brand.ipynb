# %% [markdown]
# # Classification Tests for Brand Class

# %% [markdown]
# spiegazione test

# %% [markdown]
# ### Imports

# %%
import re
import xml.etree.ElementTree as ET
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import it_core_news_sm
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np
import collections
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
# Skopt functions
from sklearn.metrics import make_scorer, f1_score, recall_score
from skopt import BayesSearchCV
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import StratifiedKFold
from skopt import gp_minimize # Bayesian optimization using Gaussian Processes
from skopt.space import Real, Categorical, Integer
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
import matplotlib.pyplot as plt
from matplotlib.widgets import Cursor
from matplotlib.ticker import FuncFormatter
import seaborn as sns
import math
import scipy.stats
import sys
from info_gain import info_gain
from copy import copy

# %%
#nltk.download('punkt')

# %% [markdown]
# ## Classes

# %%
class CarWordsHandler:
    # https://github.com/n8barr/automotive-model-year-data
    def __init__(self, cars_file):
        self.brands_list = set()
        self.models_list = set()
        f = open(cars_file, "r")
        cars_list = f.read().splitlines()
        for i in range(len(cars_list)):
            brand = cars_list[i].split(',')[0][1:].lower()
            model = cars_list[i].split(',')[1][0:-1].lower()
            self.brands_list.add(brand)
            self.models_list.add(model)
        # remove some useless models
        self.models_list.remove('i')
        #self.models_list.remove('gli')
        #self.models_list.remove('estate')
        self.brands_list = list(self.brands_list)
        self.models_list = list(self.models_list)
        self.brands_list.sort()
        self.models_list.sort()
    
    # binary search to get if a word is a brand 
    def isBrand(self, word):
        word = word.lower()
        first = 0
        last = len(self.brands_list) -1
        while first < last:
            mid = int((last + first) / 2)
            if word == self.brands_list[mid]:
                return True
            elif word < self.brands_list[mid]:
                last = mid
            elif word > self.brands_list[mid]:
                first = mid
            if last-first == 1:
                if self.brands_list[first] == word or self.brands_list[last] == word:
                    return True
                else:
                    return False
    # binary search to get if a word is a brand 
    def isModel(self, word):
        word = word.lower()
        first = 0
        last = len(self.models_list) -1
        while first < last:
            mid = int((last + first) / 2)
            if word == self.models_list[mid]:
                return True
            elif word < self.models_list[mid]:
                last = mid
            elif word > self.models_list[mid]:
                first = mid
            if last-first == 1:
                if self.models_list[first] == word or self.models_list[last] == word:
                    return True
                else:
                    return False

# %%
a = CarWordsHandler('resources/cars.txt')
a.models_list
a.isModel('e 110')
# Out:
# False

# %% [markdown]
# ## Functions

# %%
# encoding issues
def correctEncodings(comment):
    fin_comment = comment
    fin_comment = re.sub('Ã¨', 'è', fin_comment)
    fin_comment = re.sub('Ã©', 'é', fin_comment)
    fin_comment = re.sub('Ã¬', 'ì', fin_comment)
    fin_comment = re.sub('Ã²', 'ò', fin_comment)
    fin_comment = re.sub('Ã¹', 'ù', fin_comment)
    fin_comment = re.sub('Ã', 'à', fin_comment)
    return fin_comment
# tokenize function
def tokenize(text):
    tokens = nltk.word_tokenize(text, 'italian')
    italian_stopwords = stopwords.words('italian')
    return [token for token in tokens if not token in italian_stopwords]
# recognize an URL
def isURL(word):
    # http://forum.rusconi.it/gentemotori/viewtopic.php ? t=434&sid=57c88f1b507d8f57717ea18e74e25324Â 
    return len(re.findall("^((http(s){0,1}://)|(www.))\S+$", word)) > 0
# recognize an image tag
def isPicture(word):
    return len(re.findall("^<img.*>$", word)) > 0
# remove punctation
def removePunctation(comment):
    return re.sub(r'\s{2,}', ' ', str(re.sub(r'[\'\"\,\.,\:\-]', ' ', comment)))
# fix issues on urls
def replaceURLs(comment):
    return str(re.sub(r'(http(s){0,1}://|www.)(([^\s]+)|/)+((\s\?\s)[^\s]+){0,1}', 'URL', comment)).replace(u'\xa0', u' ')
# replace images
def replaceIMGs(comment):
    return str(re.sub(r'<img.+>', 'IMG', comment))
# replace brands
def replaceBrands(cwhandler, comment):
    tokens = tokenize(comment)
    for i in range(len(tokens)):
        if cwhandler.isBrand(tokens[i]):
            tokens[i] = 'BRAND'
    return ' '.join(tokens)
# replace models
def replaceModels(cwhandler, comment):
    tokens = tokenize(comment)
    for i in range(len(tokens)):
        if cwhandler.isModel(tokens[i]):
            tokens[i] = 'MODEL'
    return ' '.join(tokens)
# replace question marks
def replaceQMarks(comment):
    comment = re.sub(r'\?{2,}', ' MULTI_QMARK', comment)
    comment = re.sub(r'\?', ' QMARK', comment)
    return comment
# replace esclamation marks
def replaceEMarks(comment):
    comment = re.sub(r'\!{2,}', ' MULTI_EMARK', comment)
    comment = re.sub(r'\!', ' EMARK', comment)
    return comment
# remove character repetitions
def removeRepeat(comment):
    return re.sub(r'(a-zA-Z)\1{2,}', r'\1\1\1', comment)
# replace speed
def replaceSpeed(comment):
    return re.sub(r'([0-9\.*]+(\s*(\-|\/|\s)\s*)+){0,1}[0-9\.*]+(\s*)(km\/h|mph|kmh)', 'SPEED', comment)
# replace consumption
def replaceConsumption(comment):
    return re.sub(r'([0-9\.*]+(\s*(\-|\/|\s)\s*)+){0,1}[0-9\.*]+(\s*)(km\/l|mpg)', 'CONSUMPTION', comment)
# replace weight
def replaceWeight(comment):
    return re.sub(r'[0-9\.*]+(\s*)(kg|tonnellate|ton|chili|kili)', 'WEIGHT', comment)
# replace power + torque
def replacePower(comment):
    return re.sub(r'[0-9]+\s*(cv|nm|kw)', 'POWER', comment)
# replace distance
def replaceDistance(comment):
    return re.sub(r'([0-9\.*]+(\s*(\-|\/|\s)\s*)+){0,1}[0-9\.*]+(\s*)(km|miles|kilometri|chilometri)', 'DISTANCE', comment)
# replace numbers
def replaceNumbers(comment):
    return re.sub(r'[0-9]{3,}', 'NUMBER', comment)

# %% [markdown]
# Sentiment http://valeriobasile.github.io/twita/sentix.html

# %%
class ItalianWordsHandler:
    # https://dspace-clarin-it.ilc.cnr.it/repository/xmlui/handle/20.500.11752/ILC-73
    def __init__(self, words_file):
        # words information
        self.words_dict = dict()
        root = ET.parse(words_file).getroot()
        for entry in root.findall('Lexicon/LexicalEntry'):
            word = entry.find('Lemma').get('writtenForm')
            pos = entry.get('partOfSpeech')
            senti = entry.find('Sense/Sentiment').get('polarity')
            conf = entry.find('Sense/Confidence').get('score')
            self.words_dict[word] = {'POS': pos, 'Sentiment': senti, 'Confidence': conf}
        # stemmer
        self.it_stem = nltk.stem.SnowballStemmer("italian", ignore_stopwords=True)
        
    # get word info. None if not exists
    def getWordInfo(self, word):
        # fields: POS, Sentiment, Confidence
        return self.words_dict.get(word)
    
    # italian stemmer http://snowball.tartarus.org/algorithms/italian/stemmer.html
    def stem(self, comment):
        tokens = tokenize(comment)
        return ' '.join([token if token.isupper() else self.it_stem.stem(token) for token in tokens])
    
    # correct words
    def correctWords(self, text):
        # not yet implemented
        return text

# %%
class Preprocessor:
    
    def __init__(self):
        self.cwh = CarWordsHandler('resources/cars.txt')
        self.iwh = ItalianWordsHandler('resources/ita_opeNER.xml')
        self.pos = it_core_news_sm.load()
    # preprocess text
    # allowed methods: word, swnt, pos
    # ner (named entity recognition), replacing for instance 100 km/h with SPEED
    def preprocessText(self, text, method='word', use_stemmer=False, ner=False):
        if method not in ['word', 'pos', 'swnt']:
            raise ValueError('Method not recognized. Select from word, swnt, pos')
        # correct encodings (not yet implemented)
        fin_text = correctEncodings(text)
        # remove punctation
        fin_text = removePunctation(fin_text)
        # some basic preprocessing
        fin_text = fin_text.lower()
        # correct words (not yet)
        fin_text = self.iwh.correctWords(fin_text)
        # manage repetitions
        fin_text = removeRepeat(fin_text)
        # manage punctation
        fin_text = replaceQMarks(fin_text)
        fin_text = replaceEMarks(fin_text)
        # manage URLs
        fin_text = replaceURLs(fin_text)
        # manage Images
        fin_text = replaceIMGs(fin_text)
        # remove stopwords
        tokens = tokenize(fin_text)
        fin_text = ' '.join(tokens) 
        # NOW DEPENDS ON NER
        if ner:
            # manage brands and models
            fin_text = replaceBrands(self.cwh, fin_text)
            fin_text = replaceModels(self.cwh, fin_text)
            # manage speed consumption and weight
            fin_text = replaceSpeed(fin_text)
            fin_text = replaceConsumption(fin_text)
            fin_text = replaceWeight(fin_text)
            fin_text = replacePower(fin_text)
            fin_text = replaceDistance(fin_text)
            fin_text = replaceNumbers(fin_text)
        # NOW DEPENDS ON METHOD
        if method == 'word':
            # just do nothing except eventually stemming
            if use_stemmer:
                tokens = tokenize(fin_text)
                fin_text = ' '.join([t if t.isupper() else self.iwh.stem(t) for t in tokens]) 
        elif method == 'swnt':
            tokens = tokenize(fin_text)
            swnt_tokens = []
            for t in tokens:
                info = self.iwh.getWordInfo(t)
                if info == None or info['Sentiment'] == None:
                    swnt_tokens.append(t)
                else:
                    # confidence 0-100
                    swnt_tokens.append(str(info['Sentiment'])[:3].upper() + '_' + str(int(float(info['Confidence'])*10)))
            fin_text = ' '.join(swnt_tokens)
            # stemmer
            if use_stemmer:
                tokens = tokenize(fin_text)
                fin_text = ' '.join([t if t.isupper() else self.iwh.stem(t) for t in tokens]) 
        elif method == 'pos':
            doc = self.pos(fin_text)
            pos_tokens = []
            # pos
            for t in doc:
                pos_tokens.append(str(t.pos_))
            # pos_word
            for t in doc:
                pos_tokens.append(str(t.pos_) + '_' + str(t))
                    
            fin_text = ' '.join(pos_tokens)
            # stemmer
            if use_stemmer:
                fin_text = self.iwh.stem(fin_text) 
        
        return str(re.sub(r'\s{2,}', ' ', fin_text))

# %% [markdown]
# Preprocessing Example

# %%
text = 'Sono reali calcolati nel arco del tutto anno nel estate qualcosa in piÃ¹ causa gomme di 17" e climatizzatore nel inverno un po di meno. Per quanto riguarda le autostrade quelle che percorro io principalmente la A4 e molto congestionata cosi spesso la media e 110-115 km/h che ovviamente influisce positivamente a i consumi. Ma quello che mi piace di piÃ¹ Ã¨ assenza dei guasti. Sulla vecchia Accord il primo guasto lo ho avuto a 200000 km si Ã¨ rotto il termostato della clima. Ogni tanto faccio giro di altri forum e leggo delle turbine rotte catene di distribuzione progettate male iniettori fatti male mah nel 2015 per me sono le cose incomprensibili . Con tutti gli difetti che puÃ² avere preferisco la Honda. '
print(text)
print('##########################################################################################')
p = Preprocessor()
print(p.preprocessText(text, ner=True, use_stemmer=True, method='word'))
print('##########################################################################################')
print(p.preprocessText(text, ner=True, use_stemmer=False, method='swnt'))
print('##########################################################################################')
print(p.preprocessText(text, ner=True, use_stemmer=True, method='pos'))
# Out:
# Sono reali calcolati nel arco del tutto anno nel estate qualcosa in piÃ¹ causa gomme di 17" e climatizzatore nel inverno un po di meno. Per quanto riguarda le autostrade quelle che percorro io principalmente la A4 e molto congestionata cosi spesso la media e 110-115 km/h che ovviamente influisce positivamente a i consumi. Ma quello che mi piace di piÃ¹ Ã¨ assenza dei guasti. Sulla vecchia Accord il primo guasto lo ho avuto a 200000 km si Ã¨ rotto il termostato della clima. Ogni tanto faccio giro di altri forum e leggo delle turbine rotte catene di distribuzione progettate male iniettori fatti male mah nel 2015 per me sono le cose incomprensibili . Con tutti gli difetti che puÃ² avere preferisco la Honda.
# ##########################################################################################
# real calcol arco anno MODEL qualcos caus gomm MODEL climatizz invern po men riguard autostrad percorr principal MODEL molt congestion cos spess med MODEL SPEED ovvi influ posit consum piac assenz guast vecc MODEL prim guast DISTANCE rott termost clim ogni MODEL gir altri forum legg turbin rott caten distribu progett mal iniettor fatt mal mah NUMBER me cos incomprens difett può aver prefer BRAND
# ##########################################################################################
# POS_2 calcolati NEU_2 anno MODEL qualcosa POS_5 gomme MODEL climatizzatore inverno po meno riguarda autostrade percorro principalmente MODEL molto congestionata cosi spesso NEU_2 MODEL SPEED ovviamente influisce POS_10 consumi piace NEG_6 guasti vecchia MODEL POS_6 NEG_5 DISTANCE NEG_5 termostato clima ogni MODEL NEU_2 altri forum leggo turbine rotte catene NEU_5 progettate NEG_6 iniettori fatti NEG_6 mah NUMBER me cose incomprensibili difetti può NEG_5 preferisco BRAND
# ##########################################################################################
# ADJ VERB ADJ NOUN PROPN PRON NOUN ADJ PROPN NOUN ADJ VERB ADV VERB NOUN ADJ ADV PROPN ADV VERB ADJ ADV ADJ PROPN PROPN ADV VERB ADV NOUN VERB NOUN NOUN VERB PROPN ADJ NOUN PROPN VERB ADJ NOUN DET PROPN NOUN DET NOUN DET NOUN VERB VERB NOUN VERB ADV NOUN VERB ADV NOUN PROPN PRON NOUN ADJ NOUN AUX VERB NOUN PROPN adj_real verb_calcol adj_arc noun_ann PROPN_MODEL pron_qualc noun_caus adj_gomm PROPN_MODEL noun_climatizz adj_invern verb_p adv_men verb_riguard noun_autostrad adj_percorr adv_principal PROPN_MODEL adv_molt verb_congestion adj_cos adv_spess adj_med PROPN_MODEL PROPN_SPEED adv_ovv verb_influ adv_posit noun_consum verb_piac noun_asst noun_guast verb_vecc PROPN_MODEL adj_prim noun_guast PROPN_DISTANCE verb_rott adj_termost noun_clim det_ogn PROPN_MODEL noun_gir det_altr noun_forum det_legg noun_turbin verb_rott verb_caten noun_distribu verb_progett adv_mal noun_iniettor verb_fatt adv_mal noun_mah PROPN_NUMBER pron_m noun_cos adj_incomprens noun_difett aux_pu verb_av noun_prefer PROPN_BRAND

# %% [markdown]
# For each comment divide Text from Quote by setting _TEXT or _QUOTE at the end of each word. This after preprocessing

# %%
def combine_text_quote(text, quote, divide_quote=True):
    text_tokens = tokenize(text)
    quote_tokens = tokenize(quote)
    combined_tokens = []
    for tt in text_tokens:
        if divide_quote:
            combined_tokens.append(str(tt) + '_TEXT')
        else:
            combined_tokens.append(str(tt))
    for qt in quote_tokens:
        if divide_quote:
            combined_tokens.append(str(qt) + '_QUOTE')
        else:
            combined_tokens.append(str(qt))
    return ' '.join(combined_tokens)

# %%
print(combine_text_quote('Bene grazie', 'ciao come va', divide_quote=False))
# Out:
# Bene grazie ciao va

# %% [markdown]
# # Dataset

# %%
column = 'Brand'

# %%
original_dataset = pd.read_csv('dataset.csv').fillna('')[['TESTO', '(Testo Citato)', column]]
dataset = original_dataset.copy(deep=True)
dataset
# Out:
#                                                   TESTO  \
# 0     Allora il problema è che non sono aggiornati i...
# 1     E' virgolettato appositamente.... E soprattutt...
# 2     Mah io sulla mappa ev-way ho visto solo tipo 2...
# 3     Ah però.... uno pensa di averne viste tante su...
# 4     Basta darsi delle regole e per questo tipo di ...
# 5     Personalmente posso ritenermi un possessore di...
# 6     Confermo che il posteriore è riuscitissimo e a...
# 7     Mi sa che l'unica cosa apprezzabile del rst è ...
# 8                                     grazie ! ! ! ! !
# 9                    Cosimo hai centrato completamente
# 10    bisogna distinguere tra le garanzia supplement...
# 11    Mah parleranno di ipotetiche versioni ibride o...
# 12    Qual è secondo voi il miglior 4x4 non Suv o fu...
# 13                                          SZ ES-30 ?
# 14    Ciao perché intitoli il post : "problemi della...
# 15    Diosanto che bello il Rosso 8C confrontato con...
# 16    Ax sensazione non vuol dire illusione. Non mi ...
# 17    Benvenuta nel posto giusto Allora sentirai div...
# 18    Ma come c'è il gpl ! ! ! Ahahaha Nel 2010 se b...
# 19                                               Mitico
# 20    Infatti la U cromata del paraurti anteriore è ...
# 21    Si è vero il jimny è un vero fuoristrada. Però...
# 22    Hanno limiti di emissioni diversi come in Usa ...
# 23    Fra l'altro la hybrid con quest'ultimo fl ha b...
# 24    Purtroppo accade con tutti i tag... e tra l'al...
# 25    RS ? ......quante minchiate che si sentono ! I...
# 26                          voglio aderire pure io ! !
# 27                  buono a sapersi grazie per le info
# 28    Occhio che si potrebbe sempre invocare la vers...
# 29               Per ora no rinviato a sabato prossimo
# ...                                                 ...
# 7153  Scusami Tiziano ... non volevo essere scortese...
# 7154  NUOVO LEXUS RX HYBRID 2016 PARTE DA 69.000 EUR...
# 7155  Dopo tre giorni d'uso posso cominciare ad espr...
# 7156  grazie stanotte sto di servizio in portineria ...
# 7157  Scusate però il fatto che 2 autopareristi abbi...
# 7158  in altri forum se un utente bannato si re-iscr...
# 7159                           E DI QUALSIASI TAGLIA !
# 7160  Ciao malayes il montaggio delle trombe mi ha a...
# 7161  Ah ecco ero convinto che la coupé 5 cilindri a...
# 7162  Sei sicuro ? si può selezionare anche dal conf...
# 7163                Grazie della spiegazione mic1998 !
# 7164  Intendi questa Ypsilon -&gt Lancia Ypsilon - W...
# 7165  Un pelo meno se ci sono solo accessori da cata...
# 7166  Tra le tre nominate vai di Geolandar le AT/S g...
# 7167  Ciao a tutti oggi ho visto una jeep compass L ...
# 7168                                      ECCO LE FOTO
# 7169                   prendila merita di per sè:wink:
# 7170  Ciao io ho preso una FIESTA ST LINE 140 cv FUL...
# 7171          bel mezzo parecchio americano come stile
# 7172  Non male tutt'altro. Al posteriore assomiglia ...
# 7173  A me questo aggeggio continua ad ispirare simp...
# 7174  posto che sono 2 vetture eccezionali e mi par ...
# 7175  Salve a tutti ecco una nuova sezione dedicata ...
# 7176  Inoltre derivavano direttamente dalle corse in...
# 7177  E allora perchè hai scritto sopra "I modelli N...
# 7178  Devi vedere 4C come un investimento pubblicita...
# 7179  Parto con dire una cosa : Bella e molto + bell...
# 7180  Mi sembri agguerrito ! Bravo ! Ti manderei anc...
# 7181  Grazie per la risposta. In realtà alla fine ho...
# 7182  io l'ho vista dal vivo e ti confremo che è com...
#
#                                          (Testo Citato)        Brand
# 0                                                        irrilevante
# 1                                                        irrilevante
# 2     'Inferiore non s ma probabilmente uguale (il m...  irrilevante
# 3     Sinceramente una differenza di 9.800? non mi p...  irrilevante
# 4                                                        irrilevante
# 5                                                           positivo
# 6     "sono stato anch'io in conce per altri motivi ...  irrilevante
# 7                                                        irrilevante
# 8                                                        irrilevante
# 9                                                        irrilevante
# 10                                                       irrilevante
# 11                                                       irrilevante
# 12                                                       irrilevante
# 13                                                       irrilevante
# 14                                                          positivo
# 15                                                          positivo
# 16                                                          positivo
# 17    "Buongiorno a tutti So che il titolo di questo...       neutro
# 18                                                          positivo
# 19                                                       irrilevante
# 20    modello vecchio tra l'altro... e con pochi sap...     negativo
# 21                                                          positivo
# 22                                                       irrilevante
# 23                                                          positivo
# 24                                                       irrilevante
# 25                                                            neutro
# 26                                                       irrilevante
# 27                                                       irrilevante
# 28                                                            neutro
# 29    'ragazz scusate l OT e scusate se scrivo ben p...  irrilevante
# ...                                                 ...          ...
# 7153                                                     irrilevante
# 7154                                                        positivo
# 7155                                                     irrilevante
# 7156                                                     irrilevante
# 7157                                                        positivo
# 7158                                                     irrilevante
# 7159                       Le supposte a qualsiasi ora!  irrilevante
# 7160                                                     irrilevante
# 7161                                                     irrilevante
# 7162                                                          neutro
# 7163                                                     irrilevante
# 7164                                                     irrilevante
# 7165                                                     irrilevante
# 7166                                                     irrilevante
# 7167                                                     irrilevante
# 7168                                                     irrilevante
# 7169  " Però una 3.0csi costa sui 12K davvero bell v...  irrilevante
# 7170                                                     irrilevante
# 7171                                                     irrilevante
# 7172                                                     irrilevante
# 7173                                                        positivo
# 7174                                                     irrilevante
# 7175           'Grande idea......... grazie RossoCorsa'     positivo
# 7176                                                     irrilevante
# 7177                                      'Nemmeno io.'       neutro
# 7178                                                        positivo
# 7179  'Caxxo stamattina mi ero preoccupato non veden...     positivo
# 7180                                                     irrilevante
# 7181                                                     irrilevante
# 7182                                                     irrilevante
#
# [7183 rows x 3 columns]

# %% [markdown]
# Preprocessing

# %%
pp = Preprocessor()
# TESTO
for i in range(len(dataset)):
    dataset['TESTO'][i] = pp.preprocessText(dataset['TESTO'][i], method='word', use_stemmer=True, ner=True)
# (Testo Citato)
for i in range(len(dataset)):
    dataset['(Testo Citato)'][i] = pp.preprocessText(dataset['(Testo Citato)'][i], method='word', use_stemmer=True, ner=True)

# %%
# combine labels "molto positivo" = "positivo" and so on
dataset[column] = dataset[column].replace('molto positivo', 'positivo')
dataset[column] = dataset[column].replace('molto negativo', 'negativo')

# %% [markdown]
# Vectorization

# %% [markdown]
# Split into training and test

# %%
# numpy_dataset = np.array(preprocessed_dataset)
# print('Length: ' + str(numpy_dataset.shape[0]))

# %%
np.random.seed(42)
# split 80% training and 20% test
# FARLO RISPETTANDO LA DISTRIBUZIONE
#perm = np.random.permutation(numpy_dataset.shape[0])
#np.random.shuffle(numpy_dataset)
#numpy_dataset = numpy_dataset[perm]
#split = int(0.8 * numpy_dataset.shape[0])
#train_dataset, test_dataset = numpy_dataset[:split,:], numpy_dataset[split:,:]
train_dataset_X, test_dataset_X, train_dataset_y, test_dataset_y = train_test_split(dataset[['TESTO', '(Testo Citato)']], dataset[column], test_size=0.2, stratify=dataset[column], shuffle=True, random_state=52)
# split validation
train_dataset_X, valid_dataset_X, train_dataset_y, valid_dataset_y = train_test_split(train_dataset_X, train_dataset_y, test_size=0.2, stratify=train_dataset_y, shuffle=True, random_state=52)

# %%
train_dataset_X
# Out:
#                                                   TESTO  \
# 5225  scus davver dobb riemp pagin dir MODEL ved per...
# 2410  cap benz ser alluminium diesel chrom poi MODEL...
# 1941  possibil anzi molt probabil rottur dov caus ac...
# 5411  ripesc https //URL it/auto/v /golf MODEL 5p co...
# 6066    oh unic cos guard nn cap moden nn camb f1 QMARK
# 1048                        wuauu tagl erba tagl nessun
# 3567  cavol second me ver notiz fast ( nuov QMARK ) ...
# 4430  premett prefer motor benzin amo motor sal velo...
# 6787                                paga due anni fa 35
# 2064  cia comferm inieziom MODEL cv MODEL dovrebb es...
# 2788  pecc ital percep premium oltre aver MODEL gran...
# 5296  alfa sospension tutt altro stil tavol marm anz...
# 471   termost romp apert quas attual temperatur sten...
# 1310  propr serratur inoltr cos opiac romp vetr apre...
# 5256  oggi vad vision cos pens QMARK par po altin pr...
# 4732  impiant ottic ( modul xen ) cred ident mont MO...
# 5486  mission conclus 8 ) riusc raggiunt giust MODEL...
# 3271  nient nient co legg rival MODEL NUMBER 4marc N...
# 2391  divis argoment nuov ionity inaugur tutt ser nu...
# 194                                         ver notevol
# 5423  ser sì famos immagin cataloghin MODEL tip sedi...
# 1312  effett uscit megl lott purtropp propr categor ...
# 6246  chied poss parl cal vend modell appen mess com...
# 1403                            @ gattostanc sa lett fb
# 999                 BRAND EMARK EMARK EMARK BRAND MODEL
# 5289                                               teor
# 6799        & # NUMBER & # NUMBER & # NUMBER & # NUMBER
# 5059  ricord ancor quand manda fot galler perc sap p...
# 4187                              scomp semplic trasfer
# 5655  cia legg MODEL segu interess discussion torn B...
# ...                                                 ...
# 6822                         NUMBER eur compr MODEL e36
# 6529                                             prefer
# 2315  sbagl sezion post zon franc aver piu possibil ...
# 2955  sap nuov class mont 1 MODEL dci BRAND stess MO...
# 2741  rived cifr prevent ier jtd progression stess p...
# 3015  purtropp andat MODEL compr 1 MODEL benzin ( pr...
# 5690  MODEL cv sicur bell MODEL ampi d accord qualit...
# 779                         immagin gioi tifos juventus
# 1199  pass ier concessionar s dett dovess pass tass ...
# 3379  vot MODEL sper affianc person giust ( compett ...
# 4041  MODEL DISTANCE 1 MODEL multijet caten distribu...
# 2850  afferm potrebber aver sens vw listin MODEL tsi...
# 6873  cia fab possied MODEL pai mes acquist 14ma km ...
# 1289  interess sit esselugn trov mar document tecnic...
# 5974  aggiung rar pass trov MODEL km zer ( vist ) pr...
# 4217  effett ragion vecc version ser freg disegn ogn...
# 956   MODEL MODEL EMARK EMARK comunqu piac cos conc ...
# 628                                tem aver cap rispost
# 2430                         infatt son incazz me stess
# 5867                                  riesc farmel piac
# 6579          ah ah EMARK pratic tolt apparecc ortodont
# 5413  sì attual gener alzat MODEL prezz real perd po...
# 6411  final arriv qualcos modern adrenalin MODEL 13 ...
# 1609  mymau graz rispost esaurient MODEL dedic pensi...
# 3400  cia nuov mond BRAND piac compr BRAND numberd N...
# 2614  pens vend ( immagin quind compr ) BRAND MODEL ...
# 5476                              sol lavor 50/60 + iva
# 6765  ancor dev farl pres qui ved ora negoz \xe8 chi...
# 3119  http //cgi ebay it/interfacc ipod dension gate...
# 5566                                              decis
#
#                                          (Testo Citato)
# 5225
# 2410
# 1941
# 5411                                    sap MULTI_EMARK
# 6066
# 1048  @ pilota54 effett rasaerb gold fenomenal fors ...
# 3567
# 4430
# 6787
# 2064
# 2788
# 5296
# 471
# 1310
# 5256
# 4732
# 5486
# 3271                     autoquot almen legg prim EMARK
# 2391
# 194   prefer gran lung stat concept almen not + diff...
# 5423
# 1312
# 6246
# 1403
# 999
# 5289
# 6799                                              banza
# 5059
# 4187
# 5655
# ...                                                 ...
# 6822                         NUMBER eur compr MODEL e36
# 6529
# 2315
# 2955  http //URL it/immagini/number 4/mercedes citan...
# 2741
# 3015
# 5690
# 779
# 1199
# 3379
# 4041
# 2850  oltre ciò legg forum scars affid NUMBER tsi qu...
# 6873
# 1289
# 5974
# 4217  ser sol copricerc cerc flexweels MODEL pollic ...
# 956
# 628
# 2430
# 5867
# 6579
# 5413  prezz forest ben altra sostanz me piac NUMBER ...
# 6411
# 1609
# 3400
# 2614
# 5476  NUMBER  pur settiman lavor MODEL /h dic vuol...
# 6765
# 3119
# 5566
#
# [4596 rows x 2 columns]

# %% [markdown]
# Some statistics

# %%
collections.Counter(valid_dataset_y)
# Out:
# Counter({'positivo': 104, 'irrilevante': 930, 'negativo': 71, 'neutro': 45})

# %%
train_concat = []
for i in range(len(train_dataset_X)):
    train_concat.append(combine_text_quote(train_dataset_X['TESTO'].iloc[i], train_dataset_X['(Testo Citato)'].iloc[i], divide_quote=False))
valid_concat = []
for i in range(len(valid_dataset_X)):
    valid_concat.append(combine_text_quote(valid_dataset_X['TESTO'].iloc[i], valid_dataset_X['(Testo Citato)'].iloc[i], divide_quote=False))
test_concat = []
for i in range(len(test_dataset_X)):
    test_concat.append(combine_text_quote(test_dataset_X['TESTO'].iloc[i], test_dataset_X['(Testo Citato)'].iloc[i], divide_quote=False))

# %%
# access a validation entry
# valid_concat[0]
# valid_dataset_X['TESTO'].loc[2575]

# %% [markdown]
# Finally replace text with vector, and replace label with numerical representation

# %%
# VECTORIZE
vec = TfidfVectorizer(ngram_range=(1,2), lowercase=False)
#train_dataset_X = vec.fit_transform(train_dataset_X)

# final dataset for the classification
train_X = vec.fit_transform(train_concat)
train_y = np.empty([len(train_concat), 1]).ravel()
valid_X = vec.transform(valid_concat)
valid_y = np.empty([len(valid_concat), 1]).ravel()
# training
train_y = train_dataset_y.replace('irrilevante',  0).replace('positivo', 1).replace('neutro', 1).replace('negativo', 1)
# validation
valid_y = valid_dataset_y.replace('irrilevante',  0).replace('positivo', 1).replace('neutro', 1).replace('negativo', 1)

# %%
train_X
# Out:
# <4596x159296 sparse matrix of type '<class 'numpy.float64'>'
# 	with 353589 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## SVM _TFIDF Classifier

# %% [markdown]
# https://towardsdatascience.com/automated-machine-learning-hyperparameter-tuning-in-python-dfda59b72f8a

# %% [markdown]
# First tests for feature selection

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)
svm_clf = svm.SVC(kernel='linear', decision_function_shape='ovr', verbose=2, random_state=42)

tuned_parameters = {'C': np.logspace(-3, 3, 7),}

# f1, f1_macro (for multiclass), recall
scores = ['f1']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(svm_clf, tuned_parameters, cv=skf, n_jobs=-1, scoring=score, verbose=2)
    clf.fit(train_X, train_y)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()
# Out:
# # Tuning hyper-parameters for f1
#
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:  1.5min finished
# [LibSVM]Best parameters set found on development set:
#
# {'C': 100.0}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 0.001}
# 0.000 (+/-0.000) for {'C': 0.01}
# 0.000 (+/-0.000) for {'C': 0.1}
# 0.124 (+/-0.046) for {'C': 1.0}
# 0.235 (+/-0.049) for {'C': 10.0}
# 0.237 (+/-0.042) for {'C': 100.0}
# 0.237 (+/-0.042) for {'C': 1000.0}

# %% [markdown]
# Refit with best parameters and then draw confusion matrix on validation data

# %%
# predictions
pred_y = clf.best_estimator_.predict(valid_X)

# %%
# 0=irrilevante, 1=rilevante
print('F1 score on validation data: ' + str(f1_score(valid_y, pred_y, average='binary')))
print('Recall on validation data: ' + str(recall_score(valid_y, pred_y)))
print('Precision on validation data: ' + str(precision_score(valid_y, pred_y)))
cm = confusion_matrix(valid_y, pred_y, labels=[0, 1])
ax = sns.heatmap(cm, annot=True, xticklabels=['irrelevant','relevant'], yticklabels=['irrelevant','relevant'], fmt="d")
ax.xaxis.set_ticks_position('top')
# Out:
# F1 score on validation data: 0.4314720812182741
# Recall on validation data: 0.38636363636363635
# Precision on validation data: 0.4885057471264368

# %% [markdown]
# Features selection. Plot by descending weight
#
# The weight/coefficient matrix of a generalised linear model predictor, of shape (n_features,) for binary classification and single-output regression, (n_classes, n_features) for multiclass classification and (n_targets, n_features) for multi-output regression. Note this does not include the intercept (or bias) term, which is stored in intercept_.
#
# When available, feature_importances_ is not usually provided as well, but can be calculated as the norm of each feature’s entry in coef_.
#
# https://stats.stackexchange.com/questions/39243/how-does-one-interpret-svm-feature-weights

# %%
weights = clf.best_estimator_.coef_
print(weights.shape)
# 6 perchè fa un classifictore per ogni coppia di labels (ovr) -> verificare
# Out:
# (1, 159296)

# %%
print(weights.indices)
print(weights.data)
# Out:
# [153946  69783 151154 ...   4018   3853   3239]
# [ 5.91646028e-01  5.91646028e-01  1.70431636e-01 ... -5.27219556e-01
#  -1.10503932e-04  5.70866750e-01]

# %%
# Data for plotting
for i in range(weights.shape[0]):
    fig, ax = plt.subplots(figsize=(15,5))
    ax.plot(range(weights[i].data.shape[0]), sorted(abs(weights[i].data), reverse = True))
    ax.set(xlabel='Feature', ylabel='Weight', title='Features\' weights ' + str(i))
    ax.grid()
    #fig.savefig("test.png")
    plt.show()

# %%
# select most important features
cutoff_0 = 0.15
selected_features_0 = [i for i in sorted(zip(map(lambda x: round(x, 4), abs(weights[0].data)), weights[0].indices), reverse=True) if i[0] > cutoff_0]

# %%
# take the union of selected features (a word important for a classification may be not important for other classifications)
selected_features = set()
for f in selected_features_0:
    selected_features.add(f[1])
print('Selected ' + str(len(selected_features)) + ' features')
# Out:
# Selected 24587 features

# %% [markdown]
# Now retry grid search using only selected features

# %%
train_X_fs = train_X[:, list(selected_features)]
train_y_fs = train_y
valid_X_fs = valid_X[:, list(selected_features)]
valid_y_fs = valid_y

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)
svm_clf_fs = svm.SVC(kernel='linear', decision_function_shape='ovr', verbose=2, random_state=42)

tuned_parameters = {'C': np.logspace(-3, 3, 7),}

scores = ['f1']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_fs = GridSearchCV(svm_clf_fs, tuned_parameters, cv=skf, n_jobs=-1, scoring=score, verbose=2)
    clf_fs.fit(train_X_fs, train_y_fs)

    print("Best parameters set found on development set:")
    print()
    print(clf_fs.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf_fs.cv_results_['mean_test_score']
    stds = clf_fs.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_fs.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()
# Out:
# # Tuning hyper-parameters for f1
#
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:   39.7s finished
# [LibSVM]Best parameters set found on development set:
#
# {'C': 10.0}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 0.001}
# 0.000 (+/-0.000) for {'C': 0.01}
# 0.000 (+/-0.000) for {'C': 0.1}
# 0.036 (+/-0.026) for {'C': 1.0}
# 0.379 (+/-0.093) for {'C': 10.0}
# 0.376 (+/-0.099) for {'C': 100.0}
# 0.376 (+/-0.099) for {'C': 1000.0}

# %% [markdown]
# New confusion matrix

# %%
# predictions
pred_y_fs = clf_fs.best_estimator_.predict(valid_X_fs)

# %%
# 0=irrilevante, 1=positivo, 2=neutro, 3=negativo
print('F1 score on validation data: ' + str(f1_score(valid_y_fs, pred_y_fs)))
print('Recall on validation data: ' + str(recall_score(valid_y_fs, pred_y_fs)))
print('Precision on validation data: ' + str(precision_score(valid_y_fs, pred_y_fs)))
cm = confusion_matrix(valid_y_fs, pred_y_fs, labels=[0, 1])
ax = sns.heatmap(cm, annot=True, xticklabels=['irrelevant','relevant'], yticklabels=['irrelevant','relevant'], fmt="d")
ax.xaxis.set_ticks_position('top')
# Out:
# F1 score on validation data: 0.43216080402010054
# Recall on validation data: 0.39090909090909093
# Precision on validation data: 0.48314606741573035

# %% [markdown]
# Most important features

# %%
best_n = 50
feature_names = vec.get_feature_names()
for i in range(weights.shape[0]):
    print('### ' + str(i))
    fn = []
    fv = []
    f = [i for i in sorted(zip(map(lambda x: round(x, 4), clf_fs.best_estimator_.coef_[i].data), clf_fs.best_estimator_.coef_[i].indices), reverse=True, key=lambda k: abs(k[0]))][:best_n]
    for j in range(len(f)):
        fn.append(feature_names[f[j][1]])
        fv.append(f[j][0])
        #print(str(feature_names[f[j][1]]) + ': ' + str(f[j][0]))
    fig, ax = plt.subplots(figsize=(15,5))
    plt.bar([i for i in range(best_n) if fv[i]>0], [x for x in fv if x>0])
    plt.bar([i for i in range(best_n) if fv[i]<0], [x for x in fv if x<0], color='r')
    plt.xticks(range(best_n), fn, rotation='vertical')
    plt.show()
# Out:
# ### 0

# %% [markdown]
# ## Logistic Regression for relevance classification

# %%
original_dataset = pd.read_csv('dataset.csv').fillna('')[['TESTO', '(Testo Citato)', column]]
dataset_logreg = original_dataset.copy(deep=True)
dataset_logreg
# Out:
#                                                   TESTO  \
# 0     Allora il problema è che non sono aggiornati i...
# 1     E' virgolettato appositamente.... E soprattutt...
# 2     Mah io sulla mappa ev-way ho visto solo tipo 2...
# 3     Ah però.... uno pensa di averne viste tante su...
# 4     Basta darsi delle regole e per questo tipo di ...
# 5     Personalmente posso ritenermi un possessore di...
# 6     Confermo che il posteriore è riuscitissimo e a...
# 7     Mi sa che l'unica cosa apprezzabile del rst è ...
# 8                                     grazie ! ! ! ! !
# 9                    Cosimo hai centrato completamente
# 10    bisogna distinguere tra le garanzia supplement...
# 11    Mah parleranno di ipotetiche versioni ibride o...
# 12    Qual è secondo voi il miglior 4x4 non Suv o fu...
# 13                                          SZ ES-30 ?
# 14    Ciao perché intitoli il post : "problemi della...
# 15    Diosanto che bello il Rosso 8C confrontato con...
# 16    Ax sensazione non vuol dire illusione. Non mi ...
# 17    Benvenuta nel posto giusto Allora sentirai div...
# 18    Ma come c'è il gpl ! ! ! Ahahaha Nel 2010 se b...
# 19                                               Mitico
# 20    Infatti la U cromata del paraurti anteriore è ...
# 21    Si è vero il jimny è un vero fuoristrada. Però...
# 22    Hanno limiti di emissioni diversi come in Usa ...
# 23    Fra l'altro la hybrid con quest'ultimo fl ha b...
# 24    Purtroppo accade con tutti i tag... e tra l'al...
# 25    RS ? ......quante minchiate che si sentono ! I...
# 26                          voglio aderire pure io ! !
# 27                  buono a sapersi grazie per le info
# 28    Occhio che si potrebbe sempre invocare la vers...
# 29               Per ora no rinviato a sabato prossimo
# ...                                                 ...
# 7153  Scusami Tiziano ... non volevo essere scortese...
# 7154  NUOVO LEXUS RX HYBRID 2016 PARTE DA 69.000 EUR...
# 7155  Dopo tre giorni d'uso posso cominciare ad espr...
# 7156  grazie stanotte sto di servizio in portineria ...
# 7157  Scusate però il fatto che 2 autopareristi abbi...
# 7158  in altri forum se un utente bannato si re-iscr...
# 7159                           E DI QUALSIASI TAGLIA !
# 7160  Ciao malayes il montaggio delle trombe mi ha a...
# 7161  Ah ecco ero convinto che la coupé 5 cilindri a...
# 7162  Sei sicuro ? si può selezionare anche dal conf...
# 7163                Grazie della spiegazione mic1998 !
# 7164  Intendi questa Ypsilon -&gt Lancia Ypsilon - W...
# 7165  Un pelo meno se ci sono solo accessori da cata...
# 7166  Tra le tre nominate vai di Geolandar le AT/S g...
# 7167  Ciao a tutti oggi ho visto una jeep compass L ...
# 7168                                      ECCO LE FOTO
# 7169                   prendila merita di per sè:wink:
# 7170  Ciao io ho preso una FIESTA ST LINE 140 cv FUL...
# 7171          bel mezzo parecchio americano come stile
# 7172  Non male tutt'altro. Al posteriore assomiglia ...
# 7173  A me questo aggeggio continua ad ispirare simp...
# 7174  posto che sono 2 vetture eccezionali e mi par ...
# 7175  Salve a tutti ecco una nuova sezione dedicata ...
# 7176  Inoltre derivavano direttamente dalle corse in...
# 7177  E allora perchè hai scritto sopra "I modelli N...
# 7178  Devi vedere 4C come un investimento pubblicita...
# 7179  Parto con dire una cosa : Bella e molto + bell...
# 7180  Mi sembri agguerrito ! Bravo ! Ti manderei anc...
# 7181  Grazie per la risposta. In realtà alla fine ho...
# 7182  io l'ho vista dal vivo e ti confremo che è com...
#
#                                          (Testo Citato)        Brand
# 0                                                        irrilevante
# 1                                                        irrilevante
# 2     'Inferiore non s ma probabilmente uguale (il m...  irrilevante
# 3     Sinceramente una differenza di 9.800? non mi p...  irrilevante
# 4                                                        irrilevante
# 5                                                           positivo
# 6     "sono stato anch'io in conce per altri motivi ...  irrilevante
# 7                                                        irrilevante
# 8                                                        irrilevante
# 9                                                        irrilevante
# 10                                                       irrilevante
# 11                                                       irrilevante
# 12                                                       irrilevante
# 13                                                       irrilevante
# 14                                                          positivo
# 15                                                          positivo
# 16                                                          positivo
# 17    "Buongiorno a tutti So che il titolo di questo...       neutro
# 18                                                          positivo
# 19                                                       irrilevante
# 20    modello vecchio tra l'altro... e con pochi sap...     negativo
# 21                                                          positivo
# 22                                                       irrilevante
# 23                                                          positivo
# 24                                                       irrilevante
# 25                                                            neutro
# 26                                                       irrilevante
# 27                                                       irrilevante
# 28                                                            neutro
# 29    'ragazz scusate l OT e scusate se scrivo ben p...  irrilevante
# ...                                                 ...          ...
# 7153                                                     irrilevante
# 7154                                                        positivo
# 7155                                                     irrilevante
# 7156                                                     irrilevante
# 7157                                                        positivo
# 7158                                                     irrilevante
# 7159                       Le supposte a qualsiasi ora!  irrilevante
# 7160                                                     irrilevante
# 7161                                                     irrilevante
# 7162                                                          neutro
# 7163                                                     irrilevante
# 7164                                                     irrilevante
# 7165                                                     irrilevante
# 7166                                                     irrilevante
# 7167                                                     irrilevante
# 7168                                                     irrilevante
# 7169  " Però una 3.0csi costa sui 12K davvero bell v...  irrilevante
# 7170                                                     irrilevante
# 7171                                                     irrilevante
# 7172                                                     irrilevante
# 7173                                                        positivo
# 7174                                                     irrilevante
# 7175           'Grande idea......... grazie RossoCorsa'     positivo
# 7176                                                     irrilevante
# 7177                                      'Nemmeno io.'       neutro
# 7178                                                        positivo
# 7179  'Caxxo stamattina mi ero preoccupato non veden...     positivo
# 7180                                                     irrilevante
# 7181                                                     irrilevante
# 7182                                                     irrilevante
#
# [7183 rows x 3 columns]

# %%
pp = Preprocessor()
# TESTO
for i in range(len(dataset_logreg)):
    dataset_logreg['TESTO'][i] = pp.preprocessText(dataset_logreg['TESTO'][i], method='word', use_stemmer=True, ner=True)
# (Testo Citato)
for i in range(len(dataset_logreg)):
    dataset_logreg['(Testo Citato)'][i] = pp.preprocessText(dataset_logreg['(Testo Citato)'][i], method='word', use_stemmer=True, ner=True)    

# combine labels "molto positivo" = "positivo" and so on
dataset_logreg[column] = dataset_logreg[column].replace('molto positivo', 'positivo')
dataset_logreg[column] = dataset_logreg[column].replace('molto negativo', 'negativo')

# %%
np.random.seed(42)
# split 80% training and 20% test
# FARLO RISPETTANDO LA DISTRIBUZIONE
train_dataset_X_logreg, test_dataset_X_logreg, train_dataset_y_logreg, test_dataset_y_logreg = train_test_split(dataset_logreg[['TESTO', '(Testo Citato)']], dataset_logreg[column], test_size=0.2, stratify=dataset_logreg[column], shuffle=True, random_state=52)
# split validation
train_dataset_X_logreg, valid_dataset_X_logreg, train_dataset_y_logreg, valid_dataset_y_logreg = train_test_split(train_dataset_X_logreg, train_dataset_y_logreg, test_size=0.2, stratify=train_dataset_y_logreg, shuffle=True, random_state=52)

# %%
train_dataset_X_logreg
# Out:
#                                                   TESTO  \
# 5225  scus davver dobb riemp pagin dir MODEL ved per...
# 2410  cap benz ser alluminium diesel chrom poi MODEL...
# 1941  possibil anzi molt probabil rottur dov caus ac...
# 5411  ripesc https //URL it/auto/v /golf MODEL 5p co...
# 6066    oh unic cos guard nn cap moden nn camb f1 QMARK
# 1048                        wuauu tagl erba tagl nessun
# 3567  cavol second me ver notiz fast ( nuov QMARK ) ...
# 4430  premett prefer motor benzin amo motor sal velo...
# 6787                                paga due anni fa 35
# 2064  cia comferm inieziom MODEL cv MODEL dovrebb es...
# 2788  pecc ital percep premium oltre aver MODEL gran...
# 5296  alfa sospension tutt altro stil tavol marm anz...
# 471   termost romp apert quas attual temperatur sten...
# 1310  propr serratur inoltr cos opiac romp vetr apre...
# 5256  oggi vad vision cos pens QMARK par po altin pr...
# 4732  impiant ottic ( modul xen ) cred ident mont MO...
# 5486  mission conclus 8 ) riusc raggiunt giust MODEL...
# 3271  nient nient co legg rival MODEL NUMBER 4marc N...
# 2391  divis argoment nuov ionity inaugur tutt ser nu...
# 194                                         ver notevol
# 5423  ser sì famos immagin cataloghin MODEL tip sedi...
# 1312  effett uscit megl lott purtropp propr categor ...
# 6246  chied poss parl cal vend modell appen mess com...
# 1403                            @ gattostanc sa lett fb
# 999                 BRAND EMARK EMARK EMARK BRAND MODEL
# 5289                                               teor
# 6799        & # NUMBER & # NUMBER & # NUMBER & # NUMBER
# 5059  ricord ancor quand manda fot galler perc sap p...
# 4187                              scomp semplic trasfer
# 5655  cia legg MODEL segu interess discussion torn B...
# ...                                                 ...
# 6822                         NUMBER eur compr MODEL e36
# 6529                                             prefer
# 2315  sbagl sezion post zon franc aver piu possibil ...
# 2955  sap nuov class mont 1 MODEL dci BRAND stess MO...
# 2741  rived cifr prevent ier jtd progression stess p...
# 3015  purtropp andat MODEL compr 1 MODEL benzin ( pr...
# 5690  MODEL cv sicur bell MODEL ampi d accord qualit...
# 779                         immagin gioi tifos juventus
# 1199  pass ier concessionar s dett dovess pass tass ...
# 3379  vot MODEL sper affianc person giust ( compett ...
# 4041  MODEL DISTANCE 1 MODEL multijet caten distribu...
# 2850  afferm potrebber aver sens vw listin MODEL tsi...
# 6873  cia fab possied MODEL pai mes acquist 14ma km ...
# 1289  interess sit esselugn trov mar document tecnic...
# 5974  aggiung rar pass trov MODEL km zer ( vist ) pr...
# 4217  effett ragion vecc version ser freg disegn ogn...
# 956   MODEL MODEL EMARK EMARK comunqu piac cos conc ...
# 628                                tem aver cap rispost
# 2430                         infatt son incazz me stess
# 5867                                  riesc farmel piac
# 6579          ah ah EMARK pratic tolt apparecc ortodont
# 5413  sì attual gener alzat MODEL prezz real perd po...
# 6411  final arriv qualcos modern adrenalin MODEL 13 ...
# 1609  mymau graz rispost esaurient MODEL dedic pensi...
# 3400  cia nuov mond BRAND piac compr BRAND numberd N...
# 2614  pens vend ( immagin quind compr ) BRAND MODEL ...
# 5476                              sol lavor 50/60 + iva
# 6765  ancor dev farl pres qui ved ora negoz \xe8 chi...
# 3119  http //cgi ebay it/interfacc ipod dension gate...
# 5566                                              decis
#
#                                          (Testo Citato)
# 5225
# 2410
# 1941
# 5411                                    sap MULTI_EMARK
# 6066
# 1048  @ pilota54 effett rasaerb gold fenomenal fors ...
# 3567
# 4430
# 6787
# 2064
# 2788
# 5296
# 471
# 1310
# 5256
# 4732
# 5486
# 3271                     autoquot almen legg prim EMARK
# 2391
# 194   prefer gran lung stat concept almen not + diff...
# 5423
# 1312
# 6246
# 1403
# 999
# 5289
# 6799                                              banza
# 5059
# 4187
# 5655
# ...                                                 ...
# 6822                         NUMBER eur compr MODEL e36
# 6529
# 2315
# 2955  http //URL it/immagini/number 4/mercedes citan...
# 2741
# 3015
# 5690
# 779
# 1199
# 3379
# 4041
# 2850  oltre ciò legg forum scars affid NUMBER tsi qu...
# 6873
# 1289
# 5974
# 4217  ser sol copricerc cerc flexweels MODEL pollic ...
# 956
# 628
# 2430
# 5867
# 6579
# 5413  prezz forest ben altra sostanz me piac NUMBER ...
# 6411
# 1609
# 3400
# 2614
# 5476  NUMBER  pur settiman lavor MODEL /h dic vuol...
# 6765
# 3119
# 5566
#
# [4596 rows x 2 columns]

# %%
collections.Counter(valid_dataset_y_logreg)
# Out:
# Counter({'positivo': 104, 'irrilevante': 930, 'negativo': 71, 'neutro': 45})

# %%
train_concat_logreg = []
for i in range(len(train_dataset_X_logreg)):
    train_concat_logreg.append(combine_text_quote(train_dataset_X_logreg['TESTO'].iloc[i], train_dataset_X_logreg['(Testo Citato)'].iloc[i], divide_quote=False))
valid_concat_logreg = []
for i in range(len(valid_dataset_X_logreg)):
    valid_concat_logreg.append(combine_text_quote(valid_dataset_X_logreg['TESTO'].iloc[i], valid_dataset_X_logreg['(Testo Citato)'].iloc[i], divide_quote=False))
test_concat_logreg = []
for i in range(len(test_dataset_X_logreg)):
    test_concat_logreg.append(combine_text_quote(test_dataset_X_logreg['TESTO'].iloc[i], test_dataset_X_logreg['(Testo Citato)'].iloc[i], divide_quote=False))

# %%
# VECTORIZE
vec_logreg = TfidfVectorizer(ngram_range=(1,2), lowercase=False)
#train_dataset_X = vec.fit_transform(train_dataset_X)

# final dataset for the classification
train_X_logreg = vec_logreg.fit_transform(train_concat_logreg)
train_y_logreg = np.empty([len(train_concat_logreg), 1]).ravel()
valid_X_logreg = vec_logreg.transform(valid_concat_logreg)
valid_y_logreg = np.empty([len(valid_concat_logreg), 1]).ravel()
# training
train_y_logreg = train_dataset_y_logreg.replace('irrilevante',  0).replace('positivo', 1).replace('neutro', 1).replace('negativo', 1)
# validation
valid_y_logreg = valid_dataset_y_logreg.replace('irrilevante',  0).replace('positivo', 1).replace('neutro', 1).replace('negativo', 1)

# %%
train_X_logreg
# Out:
# <4596x159296 sparse matrix of type '<class 'numpy.float64'>'
# 	with 353589 stored elements in Compressed Sparse Row format>

# %% [markdown]
# First for feature selection

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)

logreg_clf = LogisticRegression(penalty='l1', random_state=42)

tuned_parameters = {'C': np.logspace(-3, 3, 7),}

# f1, f1_macro (for multiclass), recall
scores = ['f1']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_logreg = GridSearchCV(logreg_clf, tuned_parameters, cv=skf, n_jobs=-1, scoring=score, verbose=2)
    clf_logreg.fit(train_X_logreg, train_y_logreg)

    print("Best parameters set found on development set:")
    print()
    print(clf_logreg.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf_logreg.cv_results_['mean_test_score']
    stds = clf_logreg.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_logreg.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()
# Out:
# # Tuning hyper-parameters for f1
#
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  35 | elapsed:    2.5s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:   21.9s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Best parameters set found on development set:
#
# {'C': 10.0}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 0.001}
# 0.000 (+/-0.000) for {'C': 0.01}
# 0.000 (+/-0.000) for {'C': 0.1}
# 0.169 (+/-0.068) for {'C': 1.0}
# 0.295 (+/-0.079) for {'C': 10.0}
# 0.291 (+/-0.074) for {'C': 100.0}
# 0.286 (+/-0.057) for {'C': 1000.0}

# %%
# predictions
pred_y_logreg = clf_logreg.best_estimator_.predict(valid_X_logreg)

# %%
# 0=irrilevante, 1=rilevante
print('F1 score on validation data: ' + str(f1_score(valid_y_logreg, pred_y_logreg, average='binary')))
print('Recall on validation data: ' + str(recall_score(valid_y_logreg, pred_y_logreg)))
print('Precision on validation data: ' + str(precision_score(valid_y_logreg, pred_y_logreg)))
cm = confusion_matrix(valid_y_logreg, pred_y_logreg, labels=[0, 1])
ax = sns.heatmap(cm, annot=True, xticklabels=['irrelevant','relevant'], yticklabels=['irrelevant','relevant'], fmt="d")
ax.xaxis.set_ticks_position('top')
# Out:
# F1 score on validation data: 0.4137931034482759
# Recall on validation data: 0.4090909090909091
# Precision on validation data: 0.4186046511627907

# %%
weights_logreg = clf_logreg.best_estimator_.coef_
print(weights_logreg.shape)
# 6 perchè fa un classifictore per ogni coppia di labels (ovr) -> verificare
# Out:
# (1, 159296)

# %%
weights_logreg.shape
# Out:
# (1, 159296)

# %%
# Data for plotting
for i in range(weights_logreg.shape[0]):
    fig, ax = plt.subplots(figsize=(15,5))
    ax.plot(range(weights_logreg[i].data.shape[0]), sorted(abs(weights_logreg[i]), reverse = True))
    ax.set(xlabel='Feature', ylabel='Weight', title='Features\' weights ' + str(i))
    ax.set_xscale('log')
    ax.grid()
    #fig.savefig("test.png")
    plt.show()

# %%
# take most relevant features
cutoff_0 = 0.05
selected_features_logreg = [i for i in range(len(weights_logreg[0])) if abs(weights_logreg[0][i]) > cutoff_0]
print('Selected ' + str(len(selected_features_logreg)) + ' features')
# Out:
# Selected 1684 features

# %% [markdown]
# Refit with selected features

# %%
train_X_logreg_fs = train_X_logreg[:, list(selected_features_logreg)]
train_y_logreg_fs = train_y_logreg
valid_X_logreg_fs = valid_X_logreg[:, list(selected_features_logreg)]
valid_y_logreg_fs = valid_y_logreg

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)

logreg_clf_fs = LogisticRegression(penalty='l2', random_state=42)

tuned_parameters = {'C': np.logspace(-3, 3, 7),}

scores = ['f1']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_logreg_fs = GridSearchCV(logreg_clf_fs, tuned_parameters, cv=skf, n_jobs=-1, scoring=score, verbose=2)
    clf_logreg_fs.fit(train_X_logreg_fs, train_y_logreg_fs)

    print("Best parameters set found on development set:")
    print()
    print(clf_logreg_fs.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf_logreg_fs.cv_results_['mean_test_score']
    stds = clf_logreg_fs.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_logreg_fs.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()
# Out:
# # Tuning hyper-parameters for f1
#
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Best parameters set found on development set:
#
# {'C': 1000.0}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 0.001}
# 0.000 (+/-0.000) for {'C': 0.01}
# 0.000 (+/-0.000) for {'C': 0.1}
# 0.054 (+/-0.042) for {'C': 1.0}
# 0.296 (+/-0.074) for {'C': 10.0}
# 0.569 (+/-0.126) for {'C': 100.0}
# 0.663 (+/-0.076) for {'C': 1000.0}
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    0.6s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# predictions
pred_y_logreg_fs = clf_logreg_fs.best_estimator_.predict(valid_X_logreg_fs)

# %%
# 0=irrilevante, 1=positivo, 2=neutro, 3=negativo
print('F1 score on validation data: ' + str(f1_score(valid_y_logreg_fs, pred_y_logreg_fs)))
print('Recall on validation data: ' + str(recall_score(valid_y_logreg_fs, pred_y_logreg_fs)))
print('Precision on validation data: ' + str(precision_score(valid_y_logreg_fs, pred_y_logreg_fs)))
cm = confusion_matrix(valid_y_logreg_fs, pred_y_logreg_fs, labels=[0, 1])
ax = sns.heatmap(cm, annot=True, xticklabels=['irrelevant','relevant'], yticklabels=['irrelevant','relevant'], fmt="d")
ax.xaxis.set_ticks_position('top')
# Out:
# F1 score on validation data: 0.39065817409766457
# Recall on validation data: 0.41818181818181815
# Precision on validation data: 0.3665338645418327

# %% [markdown]
# Most important features

# %%
best_n = 50
feature_names = vec.get_feature_names()
for i in range(weights.shape[0]):
    print('### ' + str(i))
    fn = []
    fv = []
    f = [i for i in sorted(zip(map(lambda x: round(x, 4), clf_logreg_fs.best_estimator_.coef_[i]), range(clf_logreg_fs.best_estimator_.coef_[i].shape[0])), reverse=True, key=lambda k: abs(k[0]))][:best_n]
    for j in range(len(f)):
        fn.append(feature_names[f[j][1]])
        fv.append(f[j][0])
        #print(str(feature_names[f[j][1]]) + ': ' + str(f[j][0]))
    fig, ax = plt.subplots(figsize=(15,5))
    plt.bar([i for i in range(best_n) if fv[i]>0], [x for x in fv if x>0])
    plt.bar([i for i in range(best_n) if fv[i]<0], [x for x in fv if x<0], color='r')
    plt.xticks(range(best_n), fn, rotation='vertical')
    plt.show()
# Out:
# ### 0

# %% [markdown]
# ## Sentiment Classification

# %%
# get only rows for sentiment classification
train_dataset_X_snt = train_dataset_X[train_dataset_y != 'irrilevante']
train_dataset_y_snt = train_dataset_y[train_dataset_y != 'irrilevante']
valid_dataset_X_snt = valid_dataset_X[valid_dataset_y != 'irrilevante']
valid_dataset_y_snt = valid_dataset_y[valid_dataset_y != 'irrilevante']
test_dataset_X_snt = test_dataset_X[test_dataset_y != 'irrilevante']
test_dataset_y_snt = test_dataset_y[test_dataset_y != 'irrilevante']

train_concat_snt = []
for i in range(len(train_dataset_X_snt)):
    train_concat_snt.append(combine_text_quote(train_dataset_X_snt['TESTO'].iloc[i], train_dataset_X_snt['(Testo Citato)'].iloc[i], divide_quote=False))
valid_concat_snt = []
for i in range(len(valid_dataset_X_snt)):
    valid_concat_snt.append(combine_text_quote(valid_dataset_X_snt['TESTO'].iloc[i], valid_dataset_X_snt['(Testo Citato)'].iloc[i], divide_quote=False))
test_concat_snt = []
for i in range(len(test_dataset_X_snt)):
    test_concat_snt.append(combine_text_quote(test_dataset_X_snt['TESTO'].iloc[i], test_dataset_X_snt['(Testo Citato)'].iloc[i], divide_quote=False))

# %%
collections.Counter(test_dataset_y_snt)
# Out:
# Counter({'positivo': 130, 'neutro': 56, 'negativo': 88})

# %% [markdown]
# Vectorize

# %%
# VECTORIZE
vec_snt = TfidfVectorizer(ngram_range=(1,2), lowercase=False)
#train_dataset_X = vec.fit_transform(train_dataset_X)

# final dataset for the classification
train_X_snt = vec_snt.fit_transform(train_concat_snt)
valid_X_snt = vec_snt.transform(valid_concat_snt)
# training
train_y_snt = train_dataset_y[train_dataset_y != 'irrilevante'].replace('positivo', 1).replace('neutro', 2).replace('negativo', 3)
# validation
valid_y_snt = valid_dataset_y[valid_dataset_y != 'irrilevante'].replace('positivo', 1).replace('neutro', 2).replace('negativo', 3)

# %%
len(train_y_snt)
# Out:
# 878

# %% [markdown]
# SVM_TFIDF_Classifier without feaure selection

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)
svm_clf_snt = svm.SVC(kernel='linear', decision_function_shape='ovr', verbose=2, random_state=42)

tuned_parameters = {'C': np.logspace(-3, 3, 7),}

# f1, f1_macro (for multiclass), recall
scores = ['f1_macro']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_snt = GridSearchCV(svm_clf_snt, tuned_parameters, cv=skf, n_jobs=-1, scoring=score, verbose=2)
    clf_snt.fit(train_X_snt, train_y_snt)

    print("Best parameters set found on development set:")
    print()
    print(clf_snt.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf_snt.cv_results_['mean_test_score']
    stds = clf_snt.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_snt.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()
# Out:
# # Tuning hyper-parameters for f1_macro
#
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    4.4s finished
# [LibSVM]Best parameters set found on development set:
#
# {'C': 10.0}
#
# Grid scores on development set:
#
# 0.215 (+/-0.001) for {'C': 0.001}
# 0.215 (+/-0.001) for {'C': 0.01}
# 0.215 (+/-0.001) for {'C': 0.1}
# 0.297 (+/-0.028) for {'C': 1.0}
# 0.350 (+/-0.041) for {'C': 10.0}
# 0.350 (+/-0.041) for {'C': 100.0}
# 0.350 (+/-0.041) for {'C': 1000.0}

# %%
# predictions
pred_y_snt = clf_snt.best_estimator_.predict(valid_X_snt)

# %%
# 0=positivo, 1=neutro, 2=negativo
print('F1 score macro on validation data: ' + str(f1_score(valid_y_snt, pred_y_snt, average='macro')))
print('F1 score micro on validation data: ' + str(f1_score(valid_y_snt, pred_y_snt, average='micro')))
cm_snt = confusion_matrix(valid_y_snt, pred_y_snt, labels=[1, 2, 3])
ax = sns.heatmap(cm_snt, annot=True, xticklabels=['positive','neutral','negative'], yticklabels=['positive','neutral','negative'])
ax.xaxis.set_ticks_position('top')
# Out:
# F1 score macro on validation data: 0.38735150244584204
# F1 score micro on validation data: 0.4909090909090909

# %% [markdown]
# Feature Selection

# %%
weights_snt = clf_snt.best_estimator_.coef_
print(weights.shape)
# 6 perchè fa un classifictore per ogni coppia di labels (ovr) -> verificare
# Out:
# (1, 159296)

# %%
# Data for plotting
for i in range(weights_snt.shape[0]):
    fig, ax = plt.subplots(figsize=(15,5))
    ax.plot(range(weights_snt[i].data.shape[0]), sorted(abs(weights_snt[i].data), reverse = True))
    ax.set(xlabel='Sentiment Feature', ylabel='Weight', title='Features\' weights ' + str(i))
    ax.grid()
    #fig.savefig("test.png")
    plt.show()

# %%
# select most important features
cutoff_0 = 0.1
selected_features_snt_0 = [i for i in sorted(zip(map(lambda x: round(x, 4), abs(weights_snt[0].data)), weights_snt[0].indices), reverse=True) if i[0] > cutoff_0]
cutoff_1 = 0.1
selected_features_snt_1 = [i for i in sorted(zip(map(lambda x: round(x, 4), abs(weights_snt[1].data)), weights_snt[1].indices), reverse=True) if i[0] > cutoff_1]
cutoff_2 = 0.1
selected_features_snt_2 = [i for i in sorted(zip(map(lambda x: round(x, 4), abs(weights_snt[2].data)), weights_snt[2].indices), reverse=True) if i[0] > cutoff_2]

# %%
# take the union of selected features (a word important for a classification may be not important for other classifications)
selected_features_snt = set()
for f in selected_features_snt_0:
    selected_features_snt.add(f[1])
for f in selected_features_snt_1:
    selected_features_snt.add(f[1])
for f in selected_features_snt_2:
    selected_features_snt.add(f[1])
print('Selected ' + str(len(selected_features_snt)) + ' features')
# Out:
# Selected 21295 features

# %% [markdown]
# Retry with selected features

# %%
train_X_fs_snt = train_X_snt[:, list(selected_features_snt)]
train_y_fs_snt = train_y_snt
valid_X_fs_snt = valid_X_snt[:, list(selected_features_snt)]
valid_y_fs_snt = valid_y_snt

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)
svm_clf_fs_snt = svm.SVC(kernel='linear', decision_function_shape='ovr', verbose=2, random_state=42)

tuned_parameters = {'C': np.logspace(-3, 3, 7),}

scores = ['f1_macro']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_fs_snt = GridSearchCV(svm_clf_fs, tuned_parameters, cv=skf, n_jobs=-1, scoring=score, verbose=2)
    clf_fs_snt.fit(train_X_fs_snt, train_y_fs_snt)

    print("Best parameters set found on development set:")
    print()
    print(clf_fs_snt.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf_fs_snt.cv_results_['mean_test_score']
    stds = clf_fs_snt.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_fs.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()
# Out:
# # Tuning hyper-parameters for f1_macro
#
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    3.7s finished
# [LibSVM]Best parameters set found on development set:
#
# {'C': 10.0}
#
# Grid scores on development set:
#
# 0.215 (+/-0.001) for {'C': 0.001}
# 0.215 (+/-0.001) for {'C': 0.01}
# 0.215 (+/-0.001) for {'C': 0.1}
# 0.277 (+/-0.016) for {'C': 1.0}
# 0.389 (+/-0.042) for {'C': 10.0}
# 0.389 (+/-0.042) for {'C': 100.0}
# 0.389 (+/-0.042) for {'C': 1000.0}

# %%
# predictions
pred_y_fs_snt = clf_fs_snt.best_estimator_.predict(valid_X_fs_snt)

# %%
# 0=positivo, 1=neutro, 2=negativo
print('F1 macro score on validation data: ' + str(f1_score(valid_y_fs_snt, pred_y_fs_snt, average='macro')))
print('F1 micro score on validation data: ' + str(f1_score(valid_y_fs_snt, pred_y_fs_snt, average='micro')))
cm_fs_snt = confusion_matrix(valid_y_fs_snt, pred_y_fs_snt, labels=[1, 2, 3])
ax = sns.heatmap(cm_fs_snt, annot=True, xticklabels=['positive','neutral','negative'], yticklabels=['positive','neutral','negative'])
ax.xaxis.set_ticks_position('top')
# Out:
# F1 macro score on validation data: 0.4063738387216647
# F1 micro score on validation data: 0.509090909090909

# %%
best_n = 50
feature_names_snt = vec_snt.get_feature_names()
for i in range(weights_snt.shape[0]):
    print('### ' + str(i))
    fn_snt = []
    fv_snt = []
    f_snt = [i for i in sorted(zip(map(lambda x: round(x, 4), clf_fs_snt.best_estimator_.coef_[i].data), clf_fs_snt.best_estimator_.coef_[i].indices), reverse=True, key=lambda k: abs(k[0]))][:best_n]
    for j in range(len(f_snt)):
        fn_snt.append(feature_names_snt[f_snt[j][1]])
        fv_snt.append(f_snt[j][0])
        #print(str(feature_names[f[j][1]]) + ': ' + str(f[j][0]))
    fig, ax = plt.subplots(figsize=(15,5))
    plt.bar([i for i in range(best_n) if fv_snt[i]>0], [x for x in fv_snt if x>0])
    plt.bar([i for i in range(best_n) if fv_snt[i]<0], [x for x in fv_snt if x<0], color='r')
    plt.xticks(range(best_n), fn_snt, rotation='vertical')
    plt.show()
# Out:
# ### 0
# ### 1
# ### 2

# %% [markdown]
# ## Classification with 4 labels

# %%
# get only rows for sentiment classification
train_dataset_X_4l = train_dataset_X
train_dataset_y_4l = train_dataset_y
valid_dataset_X_4l = valid_dataset_X
valid_dataset_y_4l = valid_dataset_y
test_dataset_X_4l = test_dataset_X
test_dataset_y_4l = test_dataset_y

train_concat_4l = []
for i in range(len(train_dataset_X_4l)):
    train_concat_4l.append(combine_text_quote(train_dataset_X_4l['TESTO'].iloc[i], train_dataset_X_4l['(Testo Citato)'].iloc[i], divide_quote=False))
valid_concat_4l = []
for i in range(len(valid_dataset_X_4l)):
    valid_concat_4l.append(combine_text_quote(valid_dataset_X_4l['TESTO'].iloc[i], valid_dataset_X_4l['(Testo Citato)'].iloc[i], divide_quote=False))
test_concat_4l = []
for i in range(len(test_dataset_X_4l)):
    test_concat_4l.append(combine_text_quote(test_dataset_X_4l['TESTO'].iloc[i], test_dataset_X_4l['(Testo Citato)'].iloc[i], divide_quote=False))

# %%
collections.Counter(test_dataset_y_4l)
# Out:
# Counter({'irrilevante': 1163, 'positivo': 130, 'neutro': 56, 'negativo': 88})

# %% [markdown]
# Vectorization

# %%
# VECTORIZE
vec_4l = TfidfVectorizer(ngram_range=(1,2), lowercase=False)
#train_dataset_X = vec.fit_transform(train_dataset_X)

# final dataset for the classification
train_X_4l = vec_4l.fit_transform(train_concat_4l)
valid_X_4l = vec_4l.transform(valid_concat_4l)
test_X_4l = vec_4l.transform(test_concat_4l)
# training
train_y_4l = train_dataset_y_4l.replace('irrilevante', 0).replace('positivo', 1).replace('neutro', 2).replace('negativo', 3)
# validation
valid_y_4l = valid_dataset_y_4l.replace('irrilevante', 0).replace('positivo', 1).replace('neutro', 2).replace('negativo', 3)
# test
test_y_4l = test_dataset_y_4l.replace('irrilevante', 0).replace('positivo', 1).replace('neutro', 2).replace('negativo', 3)

# %%
len(valid_concat_4l)
# Out:
# 1150

# %% [markdown]
# SVM _TFIDF Classifier

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)
svm_clf_4l = svm.SVC(kernel='linear', decision_function_shape='ovr', verbose=2, random_state=42)

tuned_parameters = {'C': np.logspace(-3, 3, 7),}

# f1, f1_macro (for multiclass), recall
scores = ['f1_macro']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_4l = GridSearchCV(svm_clf_4l, tuned_parameters, cv=skf, n_jobs=-1, scoring=score, verbose=2)
    clf_4l.fit(train_X_4l, train_y_4l)

    print("Best parameters set found on development set:")
    print()
    print(clf_4l.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf_4l.cv_results_['mean_test_score']
    stds = clf_4l.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_4l.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()
# Out:
# # Tuning hyper-parameters for f1_macro
#
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:  2.2min finished
# [LibSVM]Best parameters set found on development set:
#
# {'C': 100.0}
#
# Grid scores on development set:
#
# 0.224 (+/-0.000) for {'C': 0.001}
# 0.224 (+/-0.000) for {'C': 0.01}
# 0.224 (+/-0.000) for {'C': 0.1}
# 0.227 (+/-0.006) for {'C': 1.0}
# 0.244 (+/-0.017) for {'C': 10.0}
# 0.245 (+/-0.020) for {'C': 100.0}
# 0.245 (+/-0.020) for {'C': 1000.0}

# %% [markdown]
# Refit with best parameters and then draw confusion matrix on validation data

# %%
# predictions
pred_y_4l = clf_4l.best_estimator_.predict(valid_X_4l)

# %%
# 0=irrilevante, 1=positivo, 2=neutro, 3=negativo
print('F1 macro score on validation data: ' + str(f1_score(valid_y_4l, pred_y_4l, average='macro')))
print('F1 micro score on validation data: ' + str(f1_score(valid_y_4l, pred_y_4l, average='micro')))
cm_all = confusion_matrix(valid_y_4l, pred_y_4l, labels=[0, 1, 2, 3])
ax = sns.heatmap(cm_all, annot=True, xticklabels=['irrelevant','positive','neutral', 'negative'], yticklabels=['irrelevant','positive','neutral', 'negative'], fmt="d")
ax.xaxis.set_ticks_position('top')
# Out:
# F1 macro score on validation data: 0.28385168408671624
# F1 micro score on validation data: 0.8000000000000002

# %% [markdown]
# Features selection. Plot by descending weight

# %%
weights_4l = clf_4l.best_estimator_.coef_
print(weights_4l.shape)
# 6 perchè fa un classifictore per ogni coppia di labels (ovr) -> verificare
# Out:
# (6, 159296)

# %%
# Data for plotting
for i in range(weights_4l.shape[0]):
    fig, ax = plt.subplots(figsize=(15,5))
    ax.plot(range(weights_4l[i].data.shape[0]), sorted(abs(weights_4l[i].data), reverse = True))
    ax.set(xlabel='Feature', ylabel='Weight', title='Features\' weights ' + str(i))
    ax.grid()
    #fig.savefig("test.png")
    plt.show()

# %%
# select most important features
cutoff_0 = 0.05
selected_features_4l_0 = [i for i in sorted(zip(map(lambda x: round(x, 4), abs(weights_4l[0].data)), weights_4l[0].indices), reverse=True) if i[0] > cutoff_0]
cutoff_1 = 0.05
selected_features_4l_1 = [i for i in sorted(zip(map(lambda x: round(x, 4), abs(weights_4l[1].data)), weights_4l[1].indices), reverse=True) if i[0] > cutoff_1]
cutoff_2 = 0.05
selected_features_4l_2 = [i for i in sorted(zip(map(lambda x: round(x, 4), abs(weights_4l[2].data)), weights_4l[2].indices), reverse=True) if i[0] > cutoff_2]
cutoff_3 = 0.1
selected_features_4l_3 = [i for i in sorted(zip(map(lambda x: round(x, 4), abs(weights_4l[3].data)), weights_4l[3].indices), reverse=True) if i[0] > cutoff_3]
cutoff_4 = 0.1
selected_features_4l_4 = [i for i in sorted(zip(map(lambda x: round(x, 4), abs(weights_4l[4].data)), weights_4l[4].indices), reverse=True) if i[0] > cutoff_4]
cutoff_5 = 0.1
selected_features_4l_5 = [i for i in sorted(zip(map(lambda x: round(x, 4), abs(weights_4l[5].data)), weights_4l[5].indices), reverse=True) if i[0] > cutoff_5]

# %%
# take the union of selected features (a word important for a classification may be not important for other classifications)
selected_features_4l = set()
for f in selected_features_4l_0:
    selected_features_4l.add(f[1])
for f in selected_features_4l_1:
    selected_features_4l.add(f[1])
for f in selected_features_4l_2:
    selected_features_4l.add(f[1])
for f in selected_features_4l_3:
    selected_features_4l.add(f[1])
for f in selected_features_4l_4:
    selected_features_4l.add(f[1])
for f in selected_features_4l_5:
    selected_features_4l.add(f[1])
print('Selected ' + str(len(selected_features_4l)) + ' features')
# Out:
# Selected 76014 features

# %% [markdown]
# Now retry grid search using only selected features

# %%
train_X_fs_4l = train_X_4l[:, list(selected_features_4l)]
train_y_fs_4l = train_y_4l
valid_X_fs_4l = valid_X_4l[:, list(selected_features_4l)]
valid_y_fs_4l = valid_y_4l
test_X_fs_4l = test_X_4l[:, list(selected_features_4l)]
test_y_fs_4l = test_y_4l

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)
svm_clf_fs_4l = svm.SVC(kernel='linear', decision_function_shape='ovr', verbose=2, random_state=42)

tuned_parameters = {'C': np.logspace(-3, 3, 7),}

scores = ['f1_macro']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_fs_4l = GridSearchCV(svm_clf_fs_4l, tuned_parameters, cv=skf, n_jobs=-1, scoring=score, verbose=2)
    clf_fs_4l.fit(train_X_fs_4l, train_y_fs_4l)

    print("Best parameters set found on development set:")
    print()
    print(clf_fs_4l.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf_fs_4l.cv_results_['mean_test_score']
    stds = clf_fs_4l.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_fs_4l.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()
# Out:
# # Tuning hyper-parameters for f1_macro
#
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:  1.6min finished
# [LibSVM]Best parameters set found on development set:
#
# {'C': 100.0}
#
# Grid scores on development set:
#
# 0.224 (+/-0.000) for {'C': 0.001}
# 0.224 (+/-0.000) for {'C': 0.01}
# 0.224 (+/-0.000) for {'C': 0.1}
# 0.225 (+/-0.005) for {'C': 1.0}
# 0.246 (+/-0.016) for {'C': 10.0}
# 0.248 (+/-0.024) for {'C': 100.0}
# 0.248 (+/-0.024) for {'C': 1000.0}

# %%
# predictions
pred_y_fs_4l = clf_fs_4l.best_estimator_.predict(valid_X_fs_4l)

# %%
# 0=irrilevante, 1=positivo, 2=neutro, 3=negativo
print('F1 macro score on validation data: ' + str(f1_score(valid_y_fs_4l, pred_y_fs_4l, average='macro')))
print('F1 micro score on validation data: ' + str(f1_score(valid_y_fs_4l, pred_y_fs_4l, average='micro')))
cm = confusion_matrix(valid_y_fs_4l, pred_y_fs_4l, labels=[0, 1, 2, 3])
ax = sns.heatmap(cm, annot=True, xticklabels=['irrelevant','positive','neutral', 'negative'], yticklabels=['irrelevant','positive','neutral', 'negative'], fmt="d")
ax.xaxis.set_ticks_position('top')
# Out:
# F1 macro score on validation data: 0.28136643320868615
# F1 micro score on validation data: 0.8017391304347826

# %% [markdown]
# Most important features

# %%
best_n = 50
feature_names_4l = vec_4l.get_feature_names()
for i in range(weights_4l.shape[0]):
    print('### ' + str(i))
    fn_4l = []
    fv_4l = []
    f_4l = [i for i in sorted(zip(map(lambda x: round(x, 4), clf_fs_4l.best_estimator_.coef_[i].data), clf_fs_4l.best_estimator_.coef_[i].indices), reverse=True, key=lambda k: abs(k[0]))][:best_n]
    for j in range(len(f_4l)):
        fn_4l.append(feature_names_4l[f_4l[j][1]])
        fv_4l.append(f_4l[j][0])
        #print(str(feature_names[f[j][1]]) + ': ' + str(f[j][0]))
    fig, ax = plt.subplots(figsize=(15,5))
    plt.bar([i for i in range(best_n) if fv_4l[i]>0], [x for x in fv_4l if x>0])
    plt.bar([i for i in range(best_n) if fv_4l[i]<0], [x for x in fv_4l if x<0], color='r')
    plt.xticks(range(best_n), fn_4l, rotation='vertical')
    plt.show()
# Out:
# ### 0
# ### 1
# ### 2
# ### 3
# ### 4
# ### 5

# %% [markdown]
# ## BPEF for sentiment classification

# %%
class Dataset:
    
    # input dataset with labels just positive/neutral/negative
    def __init__(self, text, quote, label, feature, ner=False, use_stemmer=False, combine_text_quote=False):
        if feature not in ['word', 'pos', 'swnt']:
            raise ValueError('feature parameter must be in (\'word\', \'pos\', \'swnt\')')
        self.text = text
        self.quote = quote
        self.label = label
        self.label = self.label.replace('positivo', 0)
        self.label = self.label.replace('neutro', 1)
        self.label = self.label.replace('negativo', 2)
        self.feature = feature
        self.ner = ner
        self.use_stemmer = use_stemmer
        self.combine_text_quote = combine_text_quote
        self.combined = pd.Series()
        self.vec = CountVectorizer(ngram_range=(1,2), lowercase=False)
        self.vectorized_before_fs = None
        self.vectorized_after_fs = None
        self.selected_features = None
        self.features_entropy = None
        # fit model -> transform
        self.__fit()
        self.__feature_selection()
        # apply features selection
        self.selected_features_after_fs = self.selected_features
        self.vectorized_after_fs = self.vectorized_before_fs[:, self.selected_features_after_fs]
        
        
    def __fit(self):
        # preprocess
        self.pp = Preprocessor()
        for i in range(len(self.text)):
            self.text.iloc[i] = pp.preprocessText(self.text.iloc[i], method=self.feature, use_stemmer=self.use_stemmer, ner=self.ner)
        if self.quote is not None:
            for i in range(len(self.quote)):
                self.quote.iloc[i] = pp.preprocessText(self.quote.iloc[i], method=self.feature, use_stemmer=self.use_stemmer, ner=self.ner)
        # combine text quote
        if self.quote is not None:
            for i in range(len(self.text)):
                comb = combine_text_quote(self.text.iloc[i], self.quote.iloc[i], divide_quote=self.combine_text_quote)
                self.combined.loc[i] = comb
        else:
            self.combined = self.text
        # vectorization (count vectorizer vediamo)
        self.vectorized_before_fs = self.vec.fit_transform(self.combined)
        
            
    def transform(self, text, quote):
        combined = pd.Series()
        for i in range(len(text)):
            text.iloc[i] = self.pp.preprocessText(text.iloc[i], method=self.feature, use_stemmer=self.use_stemmer, ner=self.ner)
        if quote is not None:
            for i in range(len(quote)):
                quote.iloc[i] = self.pp.preprocessText(quote.iloc[i], method=self.feature, use_stemmer=self.use_stemmer, ner=self.ner)
        # combine text quote
        if quote is not None:
            for i in range(len(text)):
                comb = combine_text_quote(text.iloc[i], quote.iloc[i], divide_quote=self.combine_text_quote)
                combined.loc[i] = comb
        else:
            combined = text
        # vectorization (count vectorizer vediamo) and feature selection
        vectorized = self.vec.transform(combined)[:, self.selected_features_after_fs]
        return vectorized
    
    # https://www3.nd.edu/~rjohns15/cse40647.sp14/www/content/lectures/23%20-%20Decision%20Trees%202.pdf
    # https://pypi.org/project/info-gain/
    def __feature_selection(self):
        self.selected_features = [i for i in range(self.vectorized_before_fs.shape[1])]
        self.features_entropy = []
        
        #H_class = scipy.stats.entropy(self.label.value_counts())
        
        # for each feature calculate information gain
        for feat_idx in range(self.vectorized_before_fs.shape[1]):
            # print
            sys.stdout.write("\r IG: " + str(feat_idx) + '/' + str(self.vectorized_before_fs.shape[1]-1))
            sys.stdout.flush()
            '''
            H_feat = 0
            values = set(np.append(self.vectorized_before_fs[:, feat_idx].data, 0)) # zero added manually bcause sparse matrix is stupid
            # for each value calculate the conditional entropy
            for v in values:
                indexes = [i for i in range(self.vectorized_before_fs.shape[0]) if self.vectorized_before_fs[i, feat_idx] == v]
                feat_list = self.label[indexes]
                # entropy
                feat_prob = len(feat_list) / self.vectorized_before_fs.shape[0]
                H_feat += feat_prob * scipy.stats.entropy(feat_list.value_counts())
            #print(H_feat)
            # information gain of the feature
            IG = H_class - H_feat
            '''
            IG = info_gain.info_gain(self.label, self.vectorized_before_fs[:, feat_idx].toarray().ravel())
            self.features_entropy.append(IG)
            
    def plot_IG_feature(self):
        plot_ig = sorted(self.features_entropy, reverse=True)
        plt.subplots(figsize=(15,5))
        plt.semilogy(range(len(plot_ig)), plot_ig)
        plt.show()
        
    def cut_features(self, cutoff_value):
        # cut and apply features selection
        self.selected_features_after_fs = [i for i in range(len(self.features_entropy)) if self.features_entropy[i] > cutoff_value]
        self.vectorized_after_fs = self.vectorized_before_fs[:, self.selected_features_after_fs]

# %% [markdown]
# ### BPEF

# %% [markdown]
# Create dataset dictionary

# %%
np.random.seed(42)

dataset_bpef = original_dataset.copy(deep=True)
# split 80% training and 20% test
train_dataset_X_bpef, test_dataset_X_bpef, train_dataset_y_bpef, test_dataset_y_bpef = train_test_split(dataset_bpef[['TESTO', '(Testo Citato)']], dataset_bpef[column], test_size=0.2, stratify=dataset_bpef[column], shuffle=True, random_state=52)
# split validation
train_dataset_X_bpef, valid_dataset_X_bpef, train_dataset_y_bpef, valid_dataset_y_bpef = train_test_split(train_dataset_X_bpef, train_dataset_y_bpef, test_size=0.2, stratify=train_dataset_y_bpef, shuffle=True, random_state=52)

train_dataset_X_bpef = train_dataset_X_bpef[train_dataset_y_bpef != 'irrilevante']
train_dataset_y_bpef = train_dataset_y_bpef[train_dataset_y_bpef != 'irrilevante']
valid_dataset_X_bpef = valid_dataset_X_bpef[valid_dataset_y_bpef != 'irrilevante']
valid_dataset_y_bpef = valid_dataset_y_bpef[valid_dataset_y_bpef != 'irrilevante']
test_dataset_X_bpef = test_dataset_X_bpef[test_dataset_y_bpef != 'irrilevante']
test_dataset_y_bpef = test_dataset_y_bpef[test_dataset_y_bpef != 'irrilevante']

# %%
collections.Counter(train_dataset_y_bpef)
# Out:
# Counter({'positivo': 347,
#          'negativo': 262,
#          'molto positivo': 70,
#          'neutro': 179,
#          'molto negativo': 20})

# %%
feature_values = ['word', 'pos', 'swnt']
ner_values = [False, True]
column = 'Brand'

train_X_bpef = train_dataset_X_bpef
train_y_bpef = train_dataset_y_bpef.replace('positivo', 1).replace('neutro', 2).replace('negativo', 3).replace('molto positivo', 1).replace('molto negativo', 3)
valid_X_bpef = valid_dataset_X_bpef
valid_y_bpef = valid_dataset_y_bpef.replace('positivo', 1).replace('neutro', 2).replace('negativo', 3).replace('molto positivo', 1).replace('molto negativo', 3)
test_X_bpef = test_dataset_X_bpef
test_y_bpef = test_dataset_y_bpef.replace('positivo', 1).replace('neutro', 2).replace('negativo', 3).replace('molto positivo', 1).replace('molto negativo', 3)


dataset_dict = {}
for f in feature_values:
    for n in ner_values:
        print(f + ' ' + str(n))
        
        d = Dataset(text=train_X_bpef['TESTO'].copy(deep=True), quote=train_X_bpef['(Testo Citato)'].copy(deep=True), label=train_y_bpef.copy(), feature=f, ner=n, use_stemmer=True, combine_text_quote=False)
        
        d.plot_IG_feature()
        dataset_dict[(f, n)] = d
# Out:
# word False
#  IG: 57559/57559
# word True
#  IG: 52901/52901
# pos False
#  IG: 66202/66202
# pos True
#  IG: 60917/60917
# swnt False
#  IG: 48466/48466
# swnt True
#  IG: 44231/44231

# %%
sorted(dataset_dict[('word', True)].features_entropy, reverse=True)[14000]
# Out:
# 0.0012949259447183614

# %%
# dataset no feature selection
dataset_dict_nofs = copy(dataset_dict)

# %%
# without feature selection
for k in dataset_dict_nofs.keys():
    dataset_dict_nofs[k].cut_features(0)
    print(str(k) + ' ' + str(len(dataset_dict_nofs[k].selected_features_after_fs)))
# Out:
# ('word', False) 57560
# ('word', True) 52902
# ('pos', False) 66203
# ('pos', True) 60918
# ('swnt', False) 48467
# ('swnt', True) 44232

# %%
class BPEF:
    
    def __init__(self, dict_dataset):
        self.dict_dataset = dict_dataset
        
    # text plain, quote plain, labels numerical
    def train(self, text, quote, labels):
        self.classifiers_dict = {}
        keys = self.dict_dataset.keys()
        classifiers = ['svm', 'logreg', 'naibay', 'rndfst']
        # for each feature type -> keys ('feature', True/False)
        for k in keys:
            d = self.dict_dataset[k]
            # train set
            text_copy = text.copy(deep=True)
            quote_copy = quote.copy(deep=True)
            X = d.transform(text_copy, quote_copy)
            # train every classifier
            for c in classifiers:
                print('######## ' + str((k + (c, ))) + ' ########')
                
                if c == 'svm':
                    # train, estimate C with gridsearch
                    skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)
                    svmclf = svm.SVC(kernel='linear', decision_function_shape='ovr', verbose=2, random_state=42)
                    tuned_parameters = {'C': np.logspace(-3, 3, 7),}
                    clf = GridSearchCV(svmclf, tuned_parameters, cv=skf, n_jobs=-1, scoring='f1_macro', verbose=2)
                    clf.fit(X, labels)
                    print("Best parameters set found on development set:")
                    print()
                    print(clf.best_params_)
                    print()
                    print("Grid scores on development set:")
                    print()
                    means = clf.cv_results_['mean_test_score']
                    stds = clf.cv_results_['std_test_score']
                    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
                        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
                    print()
                    # add classifier to dictionary
                    self.classifiers_dict[k + (c, )] = clf.best_estimator_
                    
                elif c == 'logreg':
                    # train, estimate C with gridsearch
                    skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)
                    logreg = LogisticRegression(multi_class='ovr', verbose=2, random_state=42)
                    tuned_parameters = {'C': np.logspace(-3, 3, 7)}
                    clf = GridSearchCV(logreg, tuned_parameters, cv=skf, n_jobs=-1, scoring='f1_macro', verbose=2)
                    clf.fit(X, labels)
                    print("Best parameters set found on development set:")
                    print()
                    print(clf.best_params_)
                    print()
                    print("Grid scores on development set:")
                    print()
                    means = clf.cv_results_['mean_test_score']
                    stds = clf.cv_results_['std_test_score']
                    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
                        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
                    print()
                    # add classifier to dictionary
                    self.classifiers_dict[k + (c, )] = clf.best_estimator_
                    
                elif c == 'naibay':
                    # train, estimate C with gridsearch
                    skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)
                    naibay = GaussianNB()
                    tuned_parameters = {}
                    clf = GridSearchCV(naibay, tuned_parameters, cv=skf, n_jobs=-1, scoring='f1_macro', verbose=2)
                    clf.fit(X.toarray(), labels)
                    print("Best parameters set found on development set:")
                    print()
                    print(clf.best_params_)
                    print()
                    print("Grid scores on development set:")
                    print()
                    means = clf.cv_results_['mean_test_score']
                    stds = clf.cv_results_['std_test_score']
                    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
                        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
                    print()
                    # add classifier to dictionary
                    self.classifiers_dict[k + (c, )] = clf.best_estimator_
                    
                elif c == 'rndfst':
                    # train, estimate C with gridsearch
                    skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=False)
                    rndfst = RandomForestClassifier(random_state=42, n_jobs=-1, oob_score=True)
                    tuned_parameters = {'n_estimators': [201,501], 'max_features': ['auto', 'log2'], 'max_depth' : [10, 100], 'criterion' :['gini', 'entropy']}
                    clf = GridSearchCV(rndfst, tuned_parameters, cv=skf, n_jobs=-1, scoring='f1_macro', verbose=2)
                    clf.fit(X.toarray(), labels)
                    print("Best parameters set found on development set:")
                    print()
                    print(clf.best_params_)
                    print()
                    print("Grid scores on development set:")
                    print()
                    means = clf.cv_results_['mean_test_score']
                    stds = clf.cv_results_['std_test_score']
                    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
                        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
                    print()
                    # add classifier to dictionary
                    self.classifiers_dict[k + (c, )] = clf.best_estimator_
            
        
    # text quote plain
    def predict(self, text, quote):
        text_copy = text.copy(deep=True)
        quote_copy = quote.copy(deep=True)
        predictions = {}
        keys = self.dict_dataset.keys()
        classifiers = ['svm', 'logreg', 'naibay', 'rndfst']
        for k in keys:
            d = self.dict_dataset[k]
            # train set
            text_copy = text.copy(deep=True)
            quote_copy = quote.copy(deep=True)
            X = d.transform(text_copy, quote_copy)
            # train every classifier
            for c in classifiers:
                print('######## ' + str((k + (c, ))) + ' ########')
                # make prediction
                pred = self.classifiers_dict[k + (c, )].predict(X.toarray())
                predictions[k + (c, )] = pred
        # calculate the ensemble
        fin_pred = []
        for i in range(text_copy.shape[0]):
            curr_pred = []
            for k in keys:
                for c in classifiers:
                    curr_pred.append(predictions[k + (c, )][i])
            fin_pred.append(max(set(curr_pred), key = curr_pred.count))
        return fin_pred

# %% [markdown]
# without feature selection

# %%
bpef_nofs = BPEF(dataset_dict_nofs)

# %%
bpef_nofs.train(train_X_bpef['TESTO'], train_X_bpef['(Testo Citato)'], train_y_bpef)
# Out:
# ######## ('word', False, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.2s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [LibSVM]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.216 (+/-0.011) for {'C': 0.001}
# 0.297 (+/-0.030) for {'C': 0.01}
# 0.376 (+/-0.084) for {'C': 0.1}
# 0.401 (+/-0.045) for {'C': 1.0}
# 0.401 (+/-0.045) for {'C': 10.0}
# 0.401 (+/-0.045) for {'C': 100.0}
# 0.401 (+/-0.045) for {'C': 1000.0}
#
# ######## ('word', False, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  35 | elapsed:    2.6s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    4.7s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [LibLinear]Best parameters set found on development set:
#
# {'C': 10.0}
#
# Grid scores on development set:
#
# 0.226 (+/-0.023) for {'C': 0.001}
# 0.299 (+/-0.071) for {'C': 0.01}
# 0.354 (+/-0.079) for {'C': 0.1}
# 0.392 (+/-0.052) for {'C': 1.0}
# 0.395 (+/-0.050) for {'C': 10.0}
# 0.389 (+/-0.054) for {'C': 100.0}
# 0.394 (+/-0.052) for {'C': 1000.0}
#
# ######## ('word', False, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    4.5s remaining:    6.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.4s finished
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.354 (+/-0.060) for {}
#
# ######## ('word', False, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed: 10.3min finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
#
# Grid scores on development set:
#
# 0.217 (+/-0.010) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.270 (+/-0.061) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.263 (+/-0.054) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.260 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.255 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
#
# ######## ('word', True, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.0s finished
# [LibSVM]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.216 (+/-0.012) for {'C': 0.001}
# 0.292 (+/-0.029) for {'C': 0.01}
# 0.380 (+/-0.060) for {'C': 0.1}
# 0.390 (+/-0.017) for {'C': 1.0}
# 0.390 (+/-0.017) for {'C': 10.0}
# 0.390 (+/-0.017) for {'C': 100.0}
# 0.390 (+/-0.017) for {'C': 1000.0}
#
# ######## ('word', True, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  35 | elapsed:    2.5s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    4.5s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [LibLinear]Best parameters set found on development set:
#
# {'C': 1000.0}
#
# Grid scores on development set:
#
# 0.251 (+/-0.039) for {'C': 0.001}
# 0.303 (+/-0.058) for {'C': 0.01}
# 0.366 (+/-0.060) for {'C': 0.1}
# 0.393 (+/-0.064) for {'C': 1.0}
# 0.390 (+/-0.031) for {'C': 10.0}
# 0.400 (+/-0.016) for {'C': 100.0}
# 0.401 (+/-0.011) for {'C': 1000.0}
#
# ######## ('word', True, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    4.2s remaining:    6.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.0s finished
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.330 (+/-0.032) for {}
#
# ######## ('word', True, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  9.4min finished
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
#
# Grid scores on development set:
#
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.267 (+/-0.048) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.255 (+/-0.039) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.011) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.214 (+/-0.001) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.254 (+/-0.043) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.251 (+/-0.045) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.214 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
#
# ######## ('pos', False, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    9.2s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [LibSVM]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.240 (+/-0.031) for {'C': 0.001}
# 0.333 (+/-0.097) for {'C': 0.01}
# 0.374 (+/-0.074) for {'C': 0.1}
# 0.389 (+/-0.110) for {'C': 1.0}
# 0.389 (+/-0.110) for {'C': 10.0}
# 0.389 (+/-0.110) for {'C': 100.0}
# 0.389 (+/-0.110) for {'C': 1000.0}
#
# ######## ('pos', False, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    7.6s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [LibLinear]Best parameters set found on development set:
#
# {'C': 100.0}
#
# Grid scores on development set:
#
# 0.314 (+/-0.066) for {'C': 0.001}
# 0.321 (+/-0.041) for {'C': 0.01}
# 0.391 (+/-0.075) for {'C': 0.1}
# 0.405 (+/-0.091) for {'C': 1.0}
# 0.406 (+/-0.095) for {'C': 10.0}
# 0.410 (+/-0.090) for {'C': 100.0}
# 0.405 (+/-0.102) for {'C': 1000.0}
#
# ######## ('pos', False, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    4.6s remaining:    6.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.4s finished
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.338 (+/-0.048) for {}
#
# ######## ('pos', False, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  9.7min finished
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
#
# Grid scores on development set:
#
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.217 (+/-0.011) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.246 (+/-0.023) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.242 (+/-0.026) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.251 (+/-0.022) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.249 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
#
# ######## ('pos', True, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    9.5s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [LibSVM]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.241 (+/-0.041) for {'C': 0.001}
# 0.319 (+/-0.091) for {'C': 0.01}
# 0.393 (+/-0.108) for {'C': 0.1}
# 0.403 (+/-0.121) for {'C': 1.0}
# 0.403 (+/-0.121) for {'C': 10.0}
# 0.403 (+/-0.121) for {'C': 100.0}
# 0.403 (+/-0.121) for {'C': 1000.0}
#
# ######## ('pos', True, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    7.7s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [LibLinear]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.320 (+/-0.045) for {'C': 0.001}
# 0.355 (+/-0.046) for {'C': 0.01}
# 0.386 (+/-0.084) for {'C': 0.1}
# 0.403 (+/-0.100) for {'C': 1.0}
# 0.399 (+/-0.103) for {'C': 10.0}
# 0.389 (+/-0.099) for {'C': 100.0}
# 0.386 (+/-0.110) for {'C': 1000.0}
#
# ######## ('pos', True, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    4.8s remaining:    7.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.8s finished
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.338 (+/-0.042) for {}
#
# ######## ('pos', True, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  8.9min finished
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
#
# Grid scores on development set:
#
# 0.220 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.217 (+/-0.011) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.251 (+/-0.032) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.256 (+/-0.039) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.217 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.262 (+/-0.034) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.253 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
#
# ######## ('swnt', False, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.0s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [LibSVM]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.214 (+/-0.002) for {'C': 0.001}
# 0.303 (+/-0.062) for {'C': 0.01}
# 0.395 (+/-0.086) for {'C': 0.1}
# 0.398 (+/-0.058) for {'C': 1.0}
# 0.398 (+/-0.058) for {'C': 10.0}
# 0.398 (+/-0.058) for {'C': 100.0}
# 0.398 (+/-0.058) for {'C': 1000.0}
#
# ######## ('swnt', False, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  35 | elapsed:    2.4s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    4.1s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [LibLinear]Best parameters set found on development set:
#
# {'C': 10.0}
#
# Grid scores on development set:
#
# 0.250 (+/-0.028) for {'C': 0.001}
# 0.320 (+/-0.031) for {'C': 0.01}
# 0.379 (+/-0.099) for {'C': 0.1}
# 0.405 (+/-0.096) for {'C': 1.0}
# 0.410 (+/-0.088) for {'C': 10.0}
# 0.399 (+/-0.062) for {'C': 100.0}
# 0.399 (+/-0.050) for {'C': 1000.0}
#
# ######## ('swnt', False, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    3.8s remaining:    5.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.6s finished
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.343 (+/-0.077) for {}
#
# ######## ('swnt', False, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  8.6min finished
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
#
# Grid scores on development set:
#
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.249 (+/-0.035) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.249 (+/-0.035) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.008) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.239 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.243 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.220 (+/-0.013) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
#
# ######## ('swnt', True, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    5.2s finished
# [LibSVM]Best parameters set found on development set:
#
# {'C': 0.1}
#
# Grid scores on development set:
#
# 0.214 (+/-0.003) for {'C': 0.001}
# 0.309 (+/-0.034) for {'C': 0.01}
# 0.398 (+/-0.028) for {'C': 0.1}
# 0.395 (+/-0.059) for {'C': 1.0}
# 0.392 (+/-0.059) for {'C': 10.0}
# 0.392 (+/-0.059) for {'C': 100.0}
# 0.392 (+/-0.059) for {'C': 1000.0}
#
# ######## ('swnt', True, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  35 | elapsed:    2.3s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    4.1s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [LibLinear]Best parameters set found on development set:
#
# {'C': 10.0}
#
# Grid scores on development set:
#
# 0.283 (+/-0.030) for {'C': 0.001}
# 0.322 (+/-0.046) for {'C': 0.01}
# 0.391 (+/-0.064) for {'C': 0.1}
# 0.393 (+/-0.056) for {'C': 1.0}
# 0.406 (+/-0.067) for {'C': 10.0}
# 0.400 (+/-0.064) for {'C': 100.0}
# 0.401 (+/-0.072) for {'C': 1000.0}
#
# ######## ('swnt', True, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    3.5s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.2s finished
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.343 (+/-0.058) for {}
#
# ######## ('swnt', True, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  7.6min finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
#
# Grid scores on development set:
#
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.234 (+/-0.033) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.244 (+/-0.020) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.010) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.217 (+/-0.010) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.249 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.240 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.219 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.217 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}

# %%
pred_nofs = bpef_nofs.predict(valid_X_bpef['TESTO'], valid_X_bpef['(Testo Citato)'])
# Out:
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########

# %%
# 0=positivo, 1=neutro, 2=negativo
print('F1 macro score on validation data: ' + str(f1_score(valid_y_bpef, pred_nofs, average='macro')))
print('F1 micro score on validation data: ' + str(f1_score(valid_y_bpef, pred_nofs, average='micro')))
cm_fs_bpef_nofs = confusion_matrix(valid_y_bpef, pred_nofs, labels=[1, 2, 3])
ax = sns.heatmap(cm_fs_bpef_nofs, annot=True, xticklabels=['positive','neutral','negative'], yticklabels=['positive','neutral','negative'])
ax.xaxis.set_ticks_position('top')
# Out:
# F1 macro score on validation data: 0.3544621749408983
# F1 micro score on validation data: 0.5318181818181819

# %%
# feature selection
# cut less informative features -> cutoff at 0.0019 (heuristic)
for k in dataset_dict.keys():
    dataset_dict[k].cut_features(0.0025)
    print(str(k) + ' ' + str(len(dataset_dict[k].selected_features_after_fs)))
# Out:
# ('word', False) 2240
# ('word', True) 2327
# ('pos', False) 2590
# ('pos', True) 2597
# ('swnt', False) 2295
# ('swnt', True) 2306

# %% [markdown]
# With feature selection

# %%
bpef = BPEF(dataset_dict)

# %%
bpef.train(train_X_bpef['TESTO'], train_X_bpef['(Testo Citato)'], train_y_bpef)
# Out:
# ######## ('word', False, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    1.8s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [LibSVM]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.214 (+/-0.002) for {'C': 0.001}
# 0.293 (+/-0.063) for {'C': 0.01}
# 0.429 (+/-0.064) for {'C': 0.1}
# 0.435 (+/-0.072) for {'C': 1.0}
# 0.420 (+/-0.073) for {'C': 10.0}
# 0.420 (+/-0.067) for {'C': 100.0}
# 0.420 (+/-0.067) for {'C': 1000.0}
#
# ######## ('word', False, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    1.2s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.1s remaining:    0.2s
# [LibLinear]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.233 (+/-0.029) for {'C': 0.001}
# 0.331 (+/-0.081) for {'C': 0.01}
# 0.433 (+/-0.069) for {'C': 0.1}
# 0.463 (+/-0.049) for {'C': 1.0}
# 0.458 (+/-0.056) for {'C': 10.0}
# 0.449 (+/-0.064) for {'C': 100.0}
# 0.436 (+/-0.070) for {'C': 1000.0}
#
# ######## ('word', False, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.634 (+/-0.028) for {}
#
# ######## ('word', False, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:   38.4s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
#
# Grid scores on development set:
#
# 0.240 (+/-0.026) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.240 (+/-0.023) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.225 (+/-0.019) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.225 (+/-0.019) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.359 (+/-0.075) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.372 (+/-0.088) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.358 (+/-0.101) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.340 (+/-0.071) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.229 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.233 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.220 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.351 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.355 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.310 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.318 (+/-0.053) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
#
# ######## ('word', True, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    2.7s finished
# [LibSVM]Best parameters set found on development set:
#
# {'C': 0.1}
#
# Grid scores on development set:
#
# 0.214 (+/-0.002) for {'C': 0.001}
# 0.289 (+/-0.031) for {'C': 0.01}
# 0.426 (+/-0.072) for {'C': 0.1}
# 0.421 (+/-0.044) for {'C': 1.0}
# 0.424 (+/-0.032) for {'C': 10.0}
# 0.423 (+/-0.039) for {'C': 100.0}
# 0.423 (+/-0.039) for {'C': 1000.0}
#
# ######## ('word', True, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    1.7s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [LibLinear]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.256 (+/-0.048) for {'C': 0.001}
# 0.326 (+/-0.048) for {'C': 0.01}
# 0.433 (+/-0.067) for {'C': 0.1}
# 0.453 (+/-0.040) for {'C': 1.0}
# 0.442 (+/-0.047) for {'C': 10.0}
# 0.440 (+/-0.064) for {'C': 100.0}
# 0.442 (+/-0.067) for {'C': 1000.0}
#
# ######## ('word', True, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.650 (+/-0.040) for {}
#
# ######## ('word', True, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:   40.1s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
#
# Grid scores on development set:
#
# 0.245 (+/-0.043) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.242 (+/-0.047) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.010) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.220 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.383 (+/-0.141) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.382 (+/-0.146) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.347 (+/-0.076) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.339 (+/-0.077) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.240 (+/-0.041) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.234 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.385 (+/-0.107) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.366 (+/-0.116) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.340 (+/-0.085) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.328 (+/-0.097) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
#
# ######## ('pos', False, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.1s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [LibSVM]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.235 (+/-0.039) for {'C': 0.001}
# 0.324 (+/-0.087) for {'C': 0.01}
# 0.436 (+/-0.056) for {'C': 0.1}
# 0.449 (+/-0.078) for {'C': 1.0}
# 0.428 (+/-0.080) for {'C': 10.0}
# 0.426 (+/-0.079) for {'C': 100.0}
# 0.426 (+/-0.079) for {'C': 1000.0}
#
# ######## ('pos', False, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    2.3s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [LibLinear]Best parameters set found on development set:
#
# {'C': 100.0}
#
# Grid scores on development set:
#
# 0.314 (+/-0.071) for {'C': 0.001}
# 0.336 (+/-0.062) for {'C': 0.01}
# 0.418 (+/-0.087) for {'C': 0.1}
# 0.450 (+/-0.106) for {'C': 1.0}
# 0.454 (+/-0.096) for {'C': 10.0}
# 0.460 (+/-0.113) for {'C': 100.0}
# 0.447 (+/-0.114) for {'C': 1000.0}
#
# ######## ('pos', False, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.669 (+/-0.045) for {}
#
# ######## ('pos', False, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:   38.4s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
#
# Grid scores on development set:
#
# 0.251 (+/-0.023) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.255 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.321 (+/-0.049) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.322 (+/-0.070) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.310 (+/-0.040) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.293 (+/-0.052) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.241 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.251 (+/-0.022) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.217 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.319 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.315 (+/-0.053) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.284 (+/-0.044) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.275 (+/-0.046) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
#
# ######## ('pos', True, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.2s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [LibSVM]Best parameters set found on development set:
#
# {'C': 0.1}
#
# Grid scores on development set:
#
# 0.241 (+/-0.041) for {'C': 0.001}
# 0.330 (+/-0.047) for {'C': 0.01}
# 0.437 (+/-0.110) for {'C': 0.1}
# 0.421 (+/-0.081) for {'C': 1.0}
# 0.406 (+/-0.078) for {'C': 10.0}
# 0.406 (+/-0.078) for {'C': 100.0}
# 0.406 (+/-0.078) for {'C': 1000.0}
#
# ######## ('pos', True, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    2.2s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [LibLinear]Best parameters set found on development set:
#
# {'C': 10.0}
#
# Grid scores on development set:
#
# 0.323 (+/-0.042) for {'C': 0.001}
# 0.374 (+/-0.066) for {'C': 0.01}
# 0.437 (+/-0.075) for {'C': 0.1}
# 0.459 (+/-0.089) for {'C': 1.0}
# 0.465 (+/-0.082) for {'C': 10.0}
# 0.462 (+/-0.062) for {'C': 100.0}
# 0.457 (+/-0.069) for {'C': 1000.0}
#
# ######## ('pos', True, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.666 (+/-0.028) for {}
#
# ######## ('pos', True, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:   38.0s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
#
# Grid scores on development set:
#
# 0.263 (+/-0.038) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.258 (+/-0.028) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.227 (+/-0.022) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.217 (+/-0.011) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.321 (+/-0.089) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.321 (+/-0.071) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.302 (+/-0.068) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.299 (+/-0.060) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.256 (+/-0.021) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.253 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.220 (+/-0.013) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.343 (+/-0.095) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.331 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.309 (+/-0.086) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.290 (+/-0.052) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
#
# ######## ('swnt', False, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    2.8s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [LibSVM]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.214 (+/-0.002) for {'C': 0.001}
# 0.286 (+/-0.057) for {'C': 0.01}
# 0.431 (+/-0.082) for {'C': 0.1}
# 0.441 (+/-0.088) for {'C': 1.0}
# 0.432 (+/-0.062) for {'C': 10.0}
# 0.433 (+/-0.115) for {'C': 100.0}
# 0.432 (+/-0.123) for {'C': 1000.0}
#
# ######## ('swnt', False, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    1.3s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.1s remaining:    0.2s
# [LibLinear]Best parameters set found on development set:
#
# {'C': 1.0}
#
# Grid scores on development set:
#
# 0.259 (+/-0.015) for {'C': 0.001}
# 0.339 (+/-0.031) for {'C': 0.01}
# 0.452 (+/-0.085) for {'C': 0.1}
# 0.470 (+/-0.084) for {'C': 1.0}
# 0.466 (+/-0.113) for {'C': 10.0}
# 0.456 (+/-0.107) for {'C': 100.0}
# 0.455 (+/-0.114) for {'C': 1000.0}
#
# ######## ('swnt', False, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.650 (+/-0.039) for {}
#
# ######## ('swnt', False, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:   39.2s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
#
# Grid scores on development set:
#
# 0.245 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.237 (+/-0.010) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.010) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.217 (+/-0.010) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.353 (+/-0.078) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.336 (+/-0.077) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.320 (+/-0.056) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.329 (+/-0.088) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.231 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.225 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.217 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.337 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.328 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.307 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.292 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
#
# ######## ('swnt', True, 'svm') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    2.8s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [LibSVM]Best parameters set found on development set:
#
# {'C': 0.1}
#
# Grid scores on development set:
#
# 0.214 (+/-0.003) for {'C': 0.001}
# 0.292 (+/-0.019) for {'C': 0.01}
# 0.459 (+/-0.045) for {'C': 0.1}
# 0.427 (+/-0.016) for {'C': 1.0}
# 0.424 (+/-0.050) for {'C': 10.0}
# 0.416 (+/-0.061) for {'C': 100.0}
# 0.416 (+/-0.061) for {'C': 1000.0}
#
# ######## ('swnt', True, 'logreg') ########
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    1.6s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [LibLinear]Best parameters set found on development set:
#
# {'C': 10.0}
#
# Grid scores on development set:
#
# 0.282 (+/-0.030) for {'C': 0.001}
# 0.338 (+/-0.048) for {'C': 0.01}
# 0.448 (+/-0.034) for {'C': 0.1}
# 0.464 (+/-0.026) for {'C': 1.0}
# 0.474 (+/-0.061) for {'C': 10.0}
# 0.454 (+/-0.069) for {'C': 100.0}
# 0.440 (+/-0.067) for {'C': 1000.0}
#
# ######## ('swnt', True, 'naibay') ########
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.648 (+/-0.055) for {}
#
# ######## ('swnt', True, 'rndfst') ########
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:   38.9s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
#
# Grid scores on development set:
#
# 0.234 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.237 (+/-0.028) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.217 (+/-0.011) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.368 (+/-0.079) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.368 (+/-0.091) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.338 (+/-0.099) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.316 (+/-0.080) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}
# 0.225 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 201}
# 0.232 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 501}
# 0.222 (+/-0.012) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 201}
# 0.215 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 501}
# 0.346 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 201}
# 0.348 (+/-0.117) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'n_estimators': 501}
# 0.328 (+/-0.084) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 201}
# 0.311 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'n_estimators': 501}

# %%
pred = bpef.predict(valid_X_bpef['TESTO'], valid_X_bpef['(Testo Citato)'])
# Out:
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########

# %%
# 0=positivo, 1=neutro, 2=negativo
print('F1 macro score on validation data: ' + str(f1_score(valid_y_bpef, pred, average='macro')))
print('F1 micro score on validation data: ' + str(f1_score(valid_y_bpef, pred, average='micro')))
cm_fs_bpef = confusion_matrix(valid_y_bpef, pred, labels=[1, 2, 3])
ax = sns.heatmap(cm_fs_bpef, annot=True, xticklabels=['positive','neutral','negative'], yticklabels=['positive','neutral','negative'])
ax.xaxis.set_ticks_position('top')
# Out:
# F1 macro score on validation data: 0.386048182283017
# F1 micro score on validation data: 0.5318181818181819

# %%
print('positive: ' + str(list(train_y_bpef).count(1)))
print('neutral: ' + str(list(train_y_bpef).count(2)))
print('negative: ' + str(list(train_y_bpef).count(3)))
# Out:
# positive: 417
# neutral: 179
# negative: 282

# %% [markdown]
# Some errors

# %%
valid_X_bpef.iloc[0]
# Out:
# TESTO             L'analisi è ottima però hai tralasciato il fat...
# (Testo Citato)    Dacia Sandero 1.2 ambiance con clima e radio a...
# Name: 6231, dtype: object

# %%
# positive predicted negative
err_pos_neu = [i for i in range(valid_y_bpef.shape[0]) if valid_y_bpef.iloc[i]==1 and pred[i]==3]
print(valid_X_bpef['TESTO'].iloc[err_pos_neu[1]])
print('################################################################')
print(valid_X_bpef['(Testo Citato)'].iloc[err_pos_neu[1]])
# Out:
# ho configurato una insigina ST CDTI con sopra praticamente tutto..... ( mancherebbero tetto panoramico e automatico ) non arriva a 36.000 euro.... che cavolo...a prezzi ci siamo eccome.....
# ################################################################

# %%
# neutral predicted positive
err_neu_pos = [i for i in range(valid_y_bpef.shape[0]) if valid_y_bpef.iloc[i]==2 and pred[i]==1]
print(valid_X_bpef['TESTO'].iloc[err_neu_pos[1]])
print('################################################################')
print(valid_X_bpef['(Testo Citato)'].iloc[err_neu_pos[1]])
# Out:
# Sto guidando da un p\xf2 di giorni una boxter 2.5 anno 97 con aggiornamento estetico al 2003 compreso di litronic. Veniamo al dunque: la macchina perde olio dalla parte posteriore destra non funziona il clackson non funzionano le luci di posizione ha gli ammortizzatori scarichi le pastiglie anteriori da cambiare i cerchi da 18 che non sono a libretto l'alettone posteriore che non si alza e la carrozzeria \xe8 stata riverniciata ed \xe8 completamente da tagliandare. Allora..Premetto che il motore nel complesso gira bene non ha vuoti parte al primo colpo e tira veramente sempre senza esitazioni il cambio \xe8 bello fluido e preciso... Per questo sono qui a chiedervi un consiglio..Che faccio ? La tengo o gliela riporto indietro ? ah il prezzo.....Voi quanto dareste per una macchina messa cos\xec ? Attendo risposte celeri perch\xe8 devo decidere entro questo pomeriggio. )
# ################################################################

# %%
# negative predicted positive
err_neg_pos = [i for i in range(valid_y_bpef.shape[0]) if valid_y_bpef.iloc[i]==3 and pred[i]==1]
print(valid_X_bpef['TESTO'].iloc[err_neg_pos[3]])
print('################################################################')
print(valid_X_bpef['(Testo Citato)'].iloc[err_neg_pos[3]])
# Out:
# Giusto quello il SUV C giusto perchè serve a Fiat per il resto IMHO se fallisce la 940 l'Alfa potrebbe non esistere più o si tornerà alla Tempra.
# ################################################################

# %% [markdown]
# ### 4 label cascade classifier

# %%
# valid_y_4l validation dataset
collections.Counter(valid_y_4l)
# Out:
# Counter({1: 104, 0: 930, 3: 71, 2: 45})

# %%
# use validation set of 4 labels classifier
valid_idx = list(valid_y_4l.index)
valid_dataset_X_cas = original_dataset.loc[valid_idx]
valid_dataset_X_cas
# Out:
#                                                   TESTO  \
# 6988  Ti sbagli la 8.32 é una macchina precisamente ...
# 2557  Ciao a tutti grazie del benvenuto. Ho da poco ...
# 2575  Ciao ragazzi.. Dopo essere stato al concession...
# 3163                Purtroppo la penso anchio così....
# 3912  sic transit gloria mundi ( et naturalis aspira...
# 4533  Vi siete mai chiesti come funzioni esattamente...
# 5135  Con eccezioni come Subaru che anzi non venderà...
# 3769             son dietro la macchina fotografica...
# 1019  vero solo che i numeri valgono solo come termi...
# 6658  Scusa ma io mi domando: con i soldi che hai sp...
# 5027  Beh è l'accostamento sul quale mio stò orienta...
# 3661                            sulla M5 del 95 c'era.
# 1843                                            Foto ?
# 1452  Su una rivista innominabile quella motorizzazi...
# 968   C'è anche 1 altro discorso da fare: siamo su a...
# 4422  Ah bhe...come se le GoodYear fossero meglio. S...
# 7026  A pensar male si fa peccato ma spesso ci si az...
# 6374  Domani ragazzi finalmente vado a ritirare la m...
# 3055  http://www.fiatpress.com.br/releases/gerenciar...
# 2819  L'avete vista ? Secondo me è bellissima sporti...
# 3848  Ciao Virgilio senza dubbio ! Se una S viene co...
# 6315  si grande capo...ha avuto il coraggio di ripos...
# 2253  Il fatto dei sedili è un po' come il materasso...
# 1277  onore alla 159 2.4 jtd pesa solo 1860 kg con 2...
# 841   x questa sbaverei.......ma c'è da attendere un...
# 5641  Scusa devi aggiornare il cellulare o il sistem...
# 1678  Ma è bellissima l'aurelia ! ! ! ! Quella lì sì...
# 1547  Non male per carità ma dalle spy mi aspettavo ...
# 2070  http://forum.rusconi.it/gentemotori/viewtopic....
# 2860  Dopo la Cayenne possono solo migliorare. Mi as...
# ...                                                 ...
# 6329  Messaggi sul 2.2 Mazda e su Mazda 3 e annessi ...
# 874   davvero ? ? non l'ho mai sentito dire.. fabio ...
# 3658                             ancora chulone RSR...
# 5199  Cavolo Davide si si sono stupendi... Li metter...
# 812   Potrei sapere che versione hai comprato e che ...
# 1781  Lo so anch'io che il torsen sarebbe meglio.Ma ...
# 3248  Ciao a tutti.Ho ricevuto via mail il libretto ...
# 3953     capiamo come si comportano i concessionari...
# 6379                                   agevolo filmato
# 2426  Alvaro \xe8 buona regola cancellare le targhe ...
# 6870  Una cosa che non mi manca e' proprio la sincer...
# 1578  ci sono delle persiane che ottimizzano il flus...
# 3415  Questa si che è una bella macchina http://cgi....
# 747   Ma per suvvizzata intendi la Trekking o la "X" ?
# 38    Che belle porte muscolose e di design che ha i...
# 3320  Comunque..... timem innanz.... Questa volta il...
# 581   I vari SUV coreani e giapponesi hanno la "prot...
# 2786  Fidatevi che \xe8 recuperabilissima. Questo es...
# 2444  Nuovi stilemi di design ? Bo a me sembra una s...
# 5678  OT ultimo rigo e non parlo più son andato a ve...
# 608   Guarda che noi siamo sempre qui ! Se ti si pol...
# 409   Ci attacchi la borsa frigo quando viaggi O la ...
# 5315  il fresh blue sarà disponibile anche sul nero....
# 4837  Ma attaccare il carica batterie "classico" ai ...
# 2441  Salve a tutti. All'ultimo tagliando della mia ...
# 6471  -Alla consegna la macchina non deve avere dife...
# 6375  Non trovate qualche vaga somiglianza con la Ev...
# 5298  Come scritto nell'articolo la tabella si rifer...
# 6220  Credo che avere 2 colonnine per 3 ore quando s...
# 3238  vista ieri la cosa che mi piaceva di piu cioè ...
#
#                                          (Testo Citato)           Brand
# 6988  '...peccato che la Thema 8.32 facesse schifo c...        positivo
# 2557                                                           positivo
# 2575  solo 1800euro di sconto sulla lexus? solo per ...     irrilevante
# 3163  'E' un problema gravemente irrisolto quello de...        negativo
# 3912                                                        irrilevante
# 4533  'Parliamo anche dei cigolii vari che il tetto ...     irrilevante
# 5135  'Allora attendiamo le prove! Intanto osservo c...        positivo
# 3769  'O.T. Maaaa ...dalle foto ...chi saresti? Fine...     irrilevante
# 1019  'guardando i numeri il mazda perde il confront...     irrilevante
# 6658                                                           positivo
# 5027                                                        irrilevante
# 3661                                                        irrilevante
# 1843                                                        irrilevante
# 1452  'sottolineo che stiamo parlando di una vettura...     irrilevante
# 968                                                              neutro
# 4422                                                        irrilevante
# 7026  ... Mi sa che il venditore l'ha raccontata gro...     irrilevante
# 6374                                                        irrilevante
# 3055                                                        irrilevante
# 2819                                                        irrilevante
# 3848                                                        irrilevante
# 6315  Davide lo sa bene ke è lu lo incoccia dagli I ...     irrilevante
# 2253                                                        irrilevante
# 1277                                                        irrilevante
# 841   'cio lo sviluppo o ma non ho mai visto nessuna...     irrilevante
# 5641                                                        irrilevante
# 1678                                                     molto positivo
# 1547                                                        irrilevante
# 2070  "Mi vengono in mente due curiositÃ  a proposit...     irrilevante
# 2860          'vuoi mettere poter esibire uno status? '        negativo
# ...                                                 ...             ...
# 6329                                                        irrilevante
# 874   Vorrei conoscere il motivo per il quale la mia...     irrilevante
# 3658                                                        irrilevante
# 5199                                                        irrilevante
# 812                                                         irrilevante
# 1781  'Lo so anch'io che il torsen sarebbe meglio.Ma...     irrilevante
# 3248                                                        irrilevante
# 3953                                                        irrilevante
# 6379                                                        irrilevante
# 2426                                                        irrilevante
# 6870  "Pensa t dici che Modus72 è sempre stato al li...     irrilevante
# 1578                                                        irrilevante
# 3415                                                        irrilevante
# 747                                                         irrilevante
# 38                                                          irrilevante
# 3320                                                        irrilevante
# 581                                                         irrilevante
# 2786                                                        irrilevante
# 2444                                                        irrilevante
# 5678                                                           positivo
# 608                                                         irrilevante
# 409                                                         irrilevante
# 5315                                                        irrilevante
# 4837                                                        irrilevante
# 2441                                                        irrilevante
# 6471                                                        irrilevante
# 6375                                                        irrilevante
# 5298                                                             neutro
# 6220                                                        irrilevante
# 3238                                                        irrilevante
#
# [1150 rows x 3 columns]

# %% [markdown]
# irrelevant / relevant

# %%
# irrelevant / relevant
valid_dataset_X_cas_svm = valid_dataset_X_cas.copy(deep=True)
pp = Preprocessor()
# TESTO
for i in range(valid_dataset_X_cas_svm.shape[0]):
    valid_dataset_X_cas_svm['TESTO'].iloc[i] = pp.preprocessText(valid_dataset_X_cas_svm['TESTO'].iloc[i], method='word', use_stemmer=True, ner=True)
# (Testo Citato)
for i in range(valid_dataset_X_cas_svm.shape[0]):
    valid_dataset_X_cas_svm['(Testo Citato)'].iloc[i] = pp.preprocessText(valid_dataset_X_cas_svm['(Testo Citato)'].iloc[i], method='word', use_stemmer=True, ner=True)

# %%
valid_concat_svm = []
for i in range(len(valid_dataset_X_cas_svm)):
    valid_concat_svm.append(combine_text_quote(valid_dataset_X_cas_svm['TESTO'].iloc[i], valid_dataset_X_cas_svm['(Testo Citato)'].iloc[i], divide_quote=False))

# %%
# predict irrelevant/relevant
valid_X_cas_svm = vec_logreg.transform(valid_concat_svm)
valid_X_cas_svm_fs = valid_X_cas_svm[:, list(selected_features_logreg)]

# %%
pred_cas_svm_ir = clf_logreg_fs.best_estimator_.predict(valid_X_cas_svm_fs)

# %% [markdown]
# sentiment with SVM

# %%
for i in range(len(pred_cas_svm_ir)):
    if pred_cas_svm_ir[i] == 1:
        v = vec_snt.transform([valid_concat_svm[i]])
        v_fs = v[0,list(selected_features_snt)]
        p = clf_fs_snt.best_estimator_.predict(v_fs)
        pred_cas_svm_ir[i] = p

# %%
collections.Counter(pred_cas_svm_ir)
# Out:
# Counter({0: 899, 2: 13, 1: 166, 3: 72})

# %%
column
# Out:
# 'Brand'

# %%
valid_true = valid_dataset_X_cas[column].replace('irrilevante', 0).replace('positivo', 1).replace('neutro', 2).replace('negativo', 3).replace('molto positivo', 1).replace('molto negativo', 3).tolist()

# %%
# 0=irrilevante, 1=positivo, 2=neutro, 3=negativo
print('F1 macro score on validation data: ' + str(f1_score(valid_true, pred_cas_svm_ir, average='macro')))
print('F1 micro score on validation data: ' + str(f1_score(valid_true, pred_cas_svm_ir, average='micro')))
cm = confusion_matrix(valid_true, pred_cas_svm_ir, labels=[0, 1, 2, 3])
ax = sns.heatmap(cm, annot=True, xticklabels=['irrelevant','positive','neutral', 'negative'], yticklabels=['irrelevant','positive','neutral', 'negative'], fmt="d")
ax.xaxis.set_ticks_position('top')
# Out:
# F1 macro score on validation data: 0.32900542440520947
# F1 micro score on validation data: 0.7086956521739132

# %% [markdown]
# sentiment with BPEF

# %%
valid_dataset_X_cas_bpef = valid_dataset_X_cas.copy(deep=True)
pred_cas_bpef_ir = pred_cas_svm_ir

# %%
for i in range(len(pred_cas_bpef_ir)):
    if pred_cas_bpef_ir[i] == 1:
        testo = valid_dataset_X_cas_bpef.iloc[i]['TESTO']
        quote = valid_dataset_X_cas_bpef.iloc[i]['(Testo Citato)']
        p = bpef.predict(pd.Series(testo), pd.Series(quote))
        pred_cas_bpef_ir[i] = p[0]
# Out:
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ...
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########

# %%
# 0=irrilevante, 1=positivo, 2=neutro, 3=negativo
print('F1 macro score on validation data: ' + str(f1_score(valid_true, pred_cas_bpef_ir, average='macro')))
print('F1 micro score on validation data: ' + str(f1_score(valid_true, pred_cas_bpef_ir, average='micro')))
cm = confusion_matrix(valid_true, pred_cas_bpef_ir, labels=[0, 1, 2, 3])
ax = sns.heatmap(cm, annot=True, xticklabels=['irrelevant','positive','neutral', 'negative'], yticklabels=['irrelevant','positive','neutral', 'negative'], fmt="d")
ax.xaxis.set_ticks_position('top')
# Out:
# F1 macro score on validation data: 0.4174274181071006
# F1 micro score on validation data: 0.7260869565217392

# %% [markdown]
# ### Classification with test data

# %%
# valid_y_4l validation dataset
collections.Counter(test_y_4l)
# Out:
# Counter({0: 1163, 1: 130, 2: 56, 3: 88})

# %%
# use validation set of 4 labels classifier
test_idx = list(test_y_4l.index)
test_dataset_X_cas = original_dataset.loc[test_idx]
test_dataset_X_cas
# Out:
#                                                   TESTO  \
# 1759                                                 D
# 525   Sicuramente Raikkonen in questa stagione ha av...
# 1234  Complimenti. Goditela e quando arrivapistacile...
# 2414  Alcune considerazioni sulle 3 soluzioni di pon...
# 5364  Direi che hanno fatto un ottimo lavoro.. Mi se...
# 1134  La 6 Exceed ha di serie xenon navi e telecamer...
# 5646  <img alt="[?IMG]" class="bbCodeImage LbImage" ...
# 4884  Grazie per info.La mia immatricolata settembre...
# 6683  non si arriva in CP ho fatto fare un preventiv...
# 7036  ecco i prezzi probabilmente francesi e della b...
# 2145  Quest'auto temo farÃ  sfracelli. Bella ben fat...
# 2067  hai tutte e due le spie accese che dico io ? s...
# 5172  Vista di sfuggita mentre uscivo dal museo a Zu...
# 5684  Si..era una battuta...ma sarebbe interessante ...
# 983   Confermo la diagnosi: sono montate di serie an...
# 1443  Alfa Romeo Giulia Q.v. al Lingotto Fiere di To...
# 4606    Per che cercava l'area moderazione. Eccola qui
# 2869  Ieri sera una amica che ha appena acquistato u...
# 4189  Non mi trovi d'accordo che ci sia una correlaz...
# 5725  oggi leggendo il giornale ho rivisto le stesse...
# 3485  Ovvio ma ci vogliono decisioni piu analoghe a ...
# 4200  L'elenco è un po' lungo perché sono già compre...
# 2323  Permettetemelo... Oggi è ufficialmente diventa...
# 5928  Boh non capisco ... Un'altra colonnina fast vi...
# 3165  Bellissime foto bellissimo thread bellissime m...
# 6552  bha capirai che tempone 8.8 sec per 185cv la 1...
# 4670  Bè le BMW di sicuro brutte sensazioni nn ne da...
# 5484  Il metano per chi vive in città ha un grosso e...
# 2912  Spese di gestione un filino diverse..............
# 6738  diciamo che il 1.2 tsi non è proprio il riferi...
# ...                                                 ...
# 2871  Credo che ti convenga aprire un nuovo argoment...
# 1496  +++ Attached files /attachments/1706176=31098-...
# 4324  Preciso Punto normale non Gpunto 1.3 mjet da 7...
# 2627  "C'è anche rossa" ( cit. ) Ma bianca è di una ...
# 4036  il domani sarà ancora diesel. L'ho già scritto...
# 4673  Appena entrata in listino 1.4 Turbo FSI da 125...
# 5339  No o meglio..non per i ripresini. Da quanto ho...
# 554   molto di più che con le pezze al sedere...tant...
# 7172  Non male tutt'altro. Al posteriore assomiglia ...
# 3604  ragazzi...non dimentichiamo ch equesta nuova h...
# 3630  Io su questo non sono d'accordo. AR ha un fasc...
# 4072  Salve a tutti. Volevo chiedervi se tra di voi ...
# 629   8 gennaio 2011 Nel corso del 2011 verranno pre...
# 6981  Stilo è una evo della a3 e della skoda.....ovv...
# 1238  Dipende molto dalla concessionaria. Ho avuto p...
# 6515  Ti tocca tornare all'ovile un bel Coupé prima ...
# 1421  Ma come si fa a far diminuire i giri della tur...
# 939   Vi dirò a me piace. Penso che questa e la clas...
# 2649  mah questa sarebbe la qualità = se non superio...
# 6043  Ciao a tutti ragazzi mi chiamo Davide sono del...
# 3345                               Buona sera a tutti.
# 5124                  E benvenuto anche da parte mia !
# 5589  il cambio manuale sull'80% delle auto non ha p...
# 4514  il discorso e': se la tieni 7/8 anni vai di ni...
# 6240  oltre che sulla 147 lo faccio lo stesso pure s...
# 4124  Una meraviglia.... Che non ha avuto ne' avra' ...
# 2463  Vero e stessa sensazione pure sulla pesante A4...
# 616   Quando ho preso la mia 3er ( l'anno scorso ) m...
# 1248  grazie. In effetti sul sito ford italia parlan...
# 957                                     nn ho capito .
#
#                                          (Testo Citato)           Brand
# 1759                                                        irrilevante
# 525   'Diciamo che la lotta tra le seconde guide è i...     irrilevante
# 1234  "Dopo una lunga indecision confront prov infor...        positivo
# 2414                                              '+++'        positivo
# 5364                                                        irrilevante
# 1134                                                        irrilevante
# 5646                                                        irrilevante
# 4884                                                        irrilevante
# 6683  'Pensi che si possa arrivare a 10.000 euro di ...     irrilevante
# 7036                                                        irrilevante
# 2145                                                        irrilevante
# 2067                                                        irrilevante
# 5172                                                        irrilevante
# 5684                                                        irrilevante
# 983   'Da quando ho messo le estive (michelin premac...     irrilevante
# 1443                                                        irrilevante
# 4606                                                        irrilevante
# 2869                                                        irrilevante
# 4189  'anche perchè aumenta (mediamente) la cultura ...          neutro
# 5725                                                        irrilevante
# 3485  'Vendere auto in perdita avrebbe ancora meno s...     irrilevante
# 4200  'Sui sedili non saprei dirt ma alla fine la co...     irrilevante
# 2323                                                        irrilevante
# 5928                                                        irrilevante
# 3165                                                        irrilevante
# 6552                                                        irrilevante
# 4670                                                     molto positivo
# 5484                                                        irrilevante
# 2912                                                        irrilevante
# 6738                                                        irrilevante
# ...                                                 ...             ...
# 2871  'Scusat ai possessori del multiair 140 cv tct ...     irrilevante
# 1496                                                        irrilevante
# 4324                                                        irrilevante
# 2627                                                        irrilevante
# 4036                                                        irrilevante
# 4673                                                        irrilevante
# 5339                                                        irrilevante
# 554                                                         irrilevante
# 7172                                                        irrilevante
# 3604                                                        irrilevante
# 3630                                                           positivo
# 4072                                                        irrilevante
# 629                                                         irrilevante
# 6981                                                             neutro
# 1238                                                        irrilevante
# 6515                                                        irrilevante
# 1421  "E probabilmente anche meno aria di reffreddam...     irrilevante
# 939                                                         irrilevante
# 2649                                                           negativo
# 6043                                                        irrilevante
# 3345                                                        irrilevante
# 5124                                                        irrilevante
# 5589                                                        irrilevante
# 4514                                                        irrilevante
# 6240                                                        irrilevante
# 4124  "Piccolo OT L'unico 3 cilindr nella mia esperi...     irrilevante
# 2463  'Il 143 vw in effetti è linearissim a tal punt...     irrilevante
# 616                                                         irrilevante
# 1248                                                             neutro
# 957                                                         irrilevante
#
# [1437 rows x 3 columns]

# %% [markdown]
# irrelevant / relevant

# %%
# irrelevant / relevant
test_dataset_X_cas_svm = test_dataset_X_cas.copy(deep=True)
pp = Preprocessor()
# TESTO
for i in range(test_dataset_X_cas_svm.shape[0]):
    test_dataset_X_cas_svm['TESTO'].iloc[i] = pp.preprocessText(test_dataset_X_cas_svm['TESTO'].iloc[i], method='word', use_stemmer=True, ner=True)
# (Testo Citato)
for i in range(test_dataset_X_cas_svm.shape[0]):
    test_dataset_X_cas_svm['(Testo Citato)'].iloc[i] = pp.preprocessText(test_dataset_X_cas_svm['(Testo Citato)'].iloc[i], method='word', use_stemmer=True, ner=True)

# %%
test_concat_svm = []
for i in range(len(test_dataset_X_cas_svm)):
    test_concat_svm.append(combine_text_quote(test_dataset_X_cas_svm['TESTO'].iloc[i], test_dataset_X_cas_svm['(Testo Citato)'].iloc[i], divide_quote=False))

# %%
# predict irrelevant/relevant
test_X_cas_svm = vec_logreg.transform(test_concat_svm)
test_X_cas_svm_fs = test_X_cas_svm[:, list(selected_features_logreg)]

# %%
test_pred_cas_svm_ir = clf_logreg_fs.best_estimator_.predict(test_X_cas_svm_fs)

# %% [markdown]
# sentiment with SVM

# %%
for i in range(len(test_pred_cas_svm_ir)):
    if test_pred_cas_svm_ir[i] == 1:
        v = vec_snt.transform([test_concat_svm[i]])
        v_fs = v[0,list(selected_features_snt)]
        p = clf_fs_snt.best_estimator_.predict(v_fs)
        test_pred_cas_svm_ir[i] = p

# %%
collections.Counter(test_pred_cas_svm_ir)
# Out:
# Counter({0: 1115, 1: 211, 2: 17, 3: 94})

# %%
test_true = test_dataset_X_cas[column].replace('irrilevante', 0).replace('positivo', 1).replace('neutro', 2).replace('negativo', 3).replace('molto positivo', 1).replace('molto negativo', 3).tolist()

# %%
# 0=irrilevante, 1=positivo, 2=neutro, 3=negativo
print('F1 macro score on validation data: ' + str(f1_score(test_true, test_pred_cas_svm_ir, average='macro')))
print('F1 micro score on validation data: ' + str(f1_score(test_true, test_pred_cas_svm_ir, average='micro')))
cm = confusion_matrix(test_true, test_pred_cas_svm_ir, labels=[0, 1, 2, 3])
ax = sns.heatmap(cm, annot=True, xticklabels=['irrelevant','positive','neutral', 'negative'], yticklabels=['irrelevant','positive','neutral', 'negative'], fmt="d")
ax.xaxis.set_ticks_position('top')
# Out:
# F1 macro score on validation data: 0.33083103773955613
# F1 micro score on validation data: 0.7077244258872651

# %% [markdown]
# sentiment with BPEF

# %%
test_dataset_X_cas_bpef = test_dataset_X_cas.copy(deep=True)
test_pred_cas_bpef_ir = test_pred_cas_svm_ir

# %%
for i in range(len(test_pred_cas_bpef_ir)):
    if test_pred_cas_bpef_ir[i] == 1:
        testo = test_dataset_X_cas_bpef.iloc[i]['TESTO']
        quote = test_dataset_X_cas_bpef.iloc[i]['(Testo Citato)']
        p = bpef.predict(pd.Series(testo), pd.Series(quote))
        test_pred_cas_bpef_ir[i] = p[0]
# Out:
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ...
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########

# %%
# 0=irrilevante, 1=positivo, 2=neutro, 3=negativo
print('F1 macro score on validation data: ' + str(f1_score(test_true, test_pred_cas_bpef_ir, average='macro')))
print('F1 micro score on validation data: ' + str(f1_score(test_true, test_pred_cas_bpef_ir, average='micro')))
cm = confusion_matrix(test_true, test_pred_cas_bpef_ir, labels=[0, 1, 2, 3])
ax = sns.heatmap(cm, annot=True, xticklabels=['irrelevant','positive','neutral', 'negative'], yticklabels=['irrelevant','positive','neutral', 'negative'], fmt="d")
ax.xaxis.set_ticks_position('top')
# Out:
# F1 macro score on validation data: 0.41248997454531644
# F1 micro score on validation data: 0.7223382045929019

# %% [markdown]
# ## Unlabeled Data

# %%
new_unlabeled_dataset = pd.read_csv('unlabeled/unlabeled_dataset_engine.csv')
del new_unlabeled_dataset['Unnamed: 0']
new_unlabeled_dataset = new_unlabeled_dataset.replace(np.nan, '', regex=True)
new_unlabeled_dataset
# Out:
#              Forum     Thread_Title  \
# 0     Quattroruote  Porsche 911/992
# 1     Quattroruote  Porsche 911/992
# 2     Quattroruote  Porsche 911/992
# 3     Quattroruote  Porsche 911/992
# 4     Quattroruote  Porsche 911/992
# 5     Quattroruote  Porsche 911/992
# 6     Quattroruote  Porsche 911/992
# 7     Quattroruote  Porsche 911/992
# 8     Quattroruote  Porsche 911/992
# 9     Quattroruote  Porsche 911/992
# 10    Quattroruote  Porsche 911/992
# 11    Quattroruote  Porsche 911/992
# 12    Quattroruote  Porsche 911/992
# 13    Quattroruote  Porsche 911/992
# 14    Quattroruote  Porsche 911/992
# 15    Quattroruote  Porsche 911/992
# 16    Quattroruote  Porsche 911/992
# 17    Quattroruote  Porsche 911/992
# 18    Quattroruote  Porsche 911/992
# 19    Quattroruote  Porsche 911/992
# 20    Quattroruote  Porsche 911/992
# 21    Quattroruote  Porsche 911/992
# 22    Quattroruote  Porsche 911/992
# 23    Quattroruote  Porsche 911/992
# 24    Quattroruote  Porsche 911/992
# 25    Quattroruote  Porsche 911/992
# 26    Quattroruote  Porsche 911/992
# 27    Quattroruote  Porsche 911/992
# 28    Quattroruote  Porsche 911/992
# 29    Quattroruote  Porsche 911/992
# ...            ...              ...
# 2327  Porschemania    992 ECCOLA!!!
# 2328  Porschemania    992 ECCOLA!!!
# 2329  Porschemania    992 ECCOLA!!!
# 2330  Porschemania    992 ECCOLA!!!
# 2331  Porschemania    992 ECCOLA!!!
# 2332  Porschemania    992 ECCOLA!!!
# 2333  Porschemania    992 ECCOLA!!!
# 2334  Porschemania    992 ECCOLA!!!
# 2335  Porschemania    992 ECCOLA!!!
# 2336  Porschemania    992 ECCOLA!!!
# 2337  Porschemania    992 ECCOLA!!!
# 2338  Porschemania    992 ECCOLA!!!
# 2339  Porschemania    992 ECCOLA!!!
# 2340  Porschemania    992 ECCOLA!!!
# 2341  Porschemania    992 ECCOLA!!!
# 2342  Porschemania    992 ECCOLA!!!
# 2343  Porschemania    992 ECCOLA!!!
# 2344  Porschemania    992 ECCOLA!!!
# 2345  Porschemania    992 ECCOLA!!!
# 2346  Porschemania    992 ECCOLA!!!
# 2347  Porschemania    992 ECCOLA!!!
# 2348  Porschemania    992 ECCOLA!!!
# 2349  Porschemania    992 ECCOLA!!!
# 2350  Porschemania    992 ECCOLA!!!
# 2351  Porschemania    992 ECCOLA!!!
# 2352  Porschemania    992 ECCOLA!!!
# 2353  Porschemania    992 ECCOLA!!!
# 2354  Porschemania    992 ECCOLA!!!
# 2355  Porschemania    992 ECCOLA!!!
# 2356  Porschemania    992 ECCOLA!!!
#
#                                                     URL  \
# 0     https://forum.quattroruote.it/threads/porsche-...
# 1     https://forum.quattroruote.it/threads/porsche-...
# 2     https://forum.quattroruote.it/threads/porsche-...
# 3     https://forum.quattroruote.it/threads/porsche-...
# 4     https://forum.quattroruote.it/threads/porsche-...
# 5     https://forum.quattroruote.it/threads/porsche-...
# 6     https://forum.quattroruote.it/threads/porsche-...
# 7     https://forum.quattroruote.it/threads/porsche-...
# 8     https://forum.quattroruote.it/threads/porsche-...
# 9     https://forum.quattroruote.it/threads/porsche-...
# 10    https://forum.quattroruote.it/threads/porsche-...
# 11    https://forum.quattroruote.it/threads/porsche-...
# 12    https://forum.quattroruote.it/threads/porsche-...
# 13    https://forum.quattroruote.it/threads/porsche-...
# 14    https://forum.quattroruote.it/threads/porsche-...
# 15    https://forum.quattroruote.it/threads/porsche-...
# 16    https://forum.quattroruote.it/threads/porsche-...
# 17    https://forum.quattroruote.it/threads/porsche-...
# 18    https://forum.quattroruote.it/threads/porsche-...
# 19    https://forum.quattroruote.it/threads/porsche-...
# 20    https://forum.quattroruote.it/threads/porsche-...
# 21    https://forum.quattroruote.it/threads/porsche-...
# 22    https://forum.quattroruote.it/threads/porsche-...
# 23    https://forum.quattroruote.it/threads/porsche-...
# 24    https://forum.quattroruote.it/threads/porsche-...
# 25    https://forum.quattroruote.it/threads/porsche-...
# 26    https://forum.quattroruote.it/threads/porsche-...
# 27    https://forum.quattroruote.it/threads/porsche-...
# 28    https://forum.quattroruote.it/threads/porsche-...
# 29    https://forum.quattroruote.it/threads/porsche-...
# ...                                                 ...
# 2327  http://www.porschemania.it/discus/messages/968...
# 2328  http://www.porschemania.it/discus/messages/968...
# 2329  http://www.porschemania.it/discus/messages/968...
# 2330  http://www.porschemania.it/discus/messages/968...
# 2331  http://www.porschemania.it/discus/messages/968...
# 2332  http://www.porschemania.it/discus/messages/968...
# 2333  http://www.porschemania.it/discus/messages/968...
# 2334  http://www.porschemania.it/discus/messages/968...
# 2335  http://www.porschemania.it/discus/messages/968...
# 2336  http://www.porschemania.it/discus/messages/968...
# 2337  http://www.porschemania.it/discus/messages/968...
# 2338  http://www.porschemania.it/discus/messages/968...
# 2339  http://www.porschemania.it/discus/messages/968...
# 2340  http://www.porschemania.it/discus/messages/968...
# 2341  http://www.porschemania.it/discus/messages/968...
# 2342  http://www.porschemania.it/discus/messages/968...
# 2343  http://www.porschemania.it/discus/messages/968...
# 2344  http://www.porschemania.it/discus/messages/968...
# 2345  http://www.porschemania.it/discus/messages/968...
# 2346  http://www.porschemania.it/discus/messages/968...
# 2347  http://www.porschemania.it/discus/messages/968...
# 2348  http://www.porschemania.it/discus/messages/968...
# 2349  http://www.porschemania.it/discus/messages/968...
# 2350  http://www.porschemania.it/discus/messages/968...
# 2351  http://www.porschemania.it/discus/messages/968...
# 2352  http://www.porschemania.it/discus/messages/968...
# 2353  http://www.porschemania.it/discus/messages/968...
# 2354  http://www.porschemania.it/discus/messages/968...
# 2355  http://www.porschemania.it/discus/messages/968...
# 2356  http://www.porschemania.it/discus/messages/968...
#
#                               Timestamp      Username    Subscription_Date  \
# 0                   19-07-2017 01:26:00      pilota54  03-04-2009 02:01:04
# 1                   10-04-2018 18:06:00      pilota54  03-04-2009 02:01:04
# 2                   11-04-2018 20:16:00   Mastertanto  01-04-2009 03:16:07
# 3                   11-04-2018 20:27:00   Mastertanto  01-04-2009 03:16:07
# 4                   12-04-2018 00:50:00      pilota54  03-04-2009 02:01:04
# 5                   19-04-2018 14:03:00      pilota54  03-04-2009 02:01:04
# 6                   25-06-2018 18:09:00      pilota54  03-04-2009 02:01:04
# 7                    7-07-2018 11:43:00   Mastertanto  01-04-2009 03:16:07
# 8                    7-07-2018 11:58:00      pilota54  03-04-2009 02:01:04
# 9                    7-07-2018 15:30:00       LA MAGA  18-05-2018 23:35:16
# 10                   7-07-2018 16:23:00   Mastertanto  01-04-2009 03:16:07
# 11                   7-07-2018 18:10:00      pilota54  03-04-2009 02:01:04
# 12                   7-07-2018 21:17:00   Mastertanto  01-04-2009 03:16:07
# 13                   8-07-2018 08:55:00  mani in alto  22-06-2017 18:30:55
# 14                   7-07-2018 23:30:00      pilota54  03-04-2009 02:01:04
# 15                   7-09-2018 18:46:00      pilota54  03-04-2009 02:01:04
# 16                   8-09-2018 10:36:00   Mastertanto  01-04-2009 03:16:07
# 17                   8-09-2018 14:42:00      pilota54  03-04-2009 02:01:04
# 18                  25-09-2018 14:36:00   livorno1915  22-01-2010 14:30:43
# 19                  25-11-2018 00:57:00      pilota54  03-04-2009 02:01:04
# 20                  25-11-2018 19:36:00   Mastertanto  01-04-2009 03:16:07
# 21                  28-11-2018 09:52:00     perdegola  01-04-2009 18:46:34
# 22                  28-11-2018 12:45:00      pilota54  03-04-2009 02:01:04
# 23                  28-11-2018 12:29:00      xander71  01-04-2009 15:51:26
# 24                  29-11-2018 09:39:00      Lenny_84  17-02-2016 16:49:02
# 25                  30-11-2018 11:51:00     elancia75  01-04-2009 00:08:53
# 26                   1-12-2018 23:10:00      pilota54  03-04-2009 02:01:04
# 27                   1-12-2018 23:16:00         Ax-80  27-09-2018 23:46:17
# 28                   2-12-2018 09:49:00     perdegola  01-04-2009 18:46:34
# 29                   3-12-2018 10:10:00     perdegola  01-04-2009 18:46:34
# ...                                 ...           ...                  ...
# 2327   giovedì 29 novembre 2018 - 20:49        845ste           01-03-2014
# 2328   giovedì 29 novembre 2018 - 21:18  lamby_spezza           01-05-2017
# 2329   giovedì 29 novembre 2018 - 21:27  lamby_spezza           01-05-2017
# 2330   giovedì 29 novembre 2018 - 21:37        ric968           01-11-2006
# 2331   giovedì 29 novembre 2018 - 22:13   peppuccio71           01-01-2015
# 2332   giovedì 29 novembre 2018 - 22:35         elfer           01-09-2002
# 2333   venerdì 30 novembre 2018 - 14:04      poniello           01-04-2004
# 2334   venerdì 30 novembre 2018 - 14:15   peppuccio71           01-01-2015
# 2335   venerdì 30 novembre 2018 - 14:43      pirulero           01-06-2004
# 2336   venerdì 30 novembre 2018 - 19:36      poniello           01-04-2004
# 2337   venerdì 30 novembre 2018 - 20:26       greyfox           01-05-2003
# 2338   venerdì 30 novembre 2018 - 20:44      andrea70           01-11-2005
# 2339   venerdì 30 novembre 2018 - 21:25       miro911           01-12-2015
# 2340   venerdì 30 novembre 2018 - 21:54          diti           01-10-2012
# 2341   venerdì 30 novembre 2018 - 23:36      marco_77           01-12-2013
# 2342    sabato 01 dicembre 2018 - 08:49      poniello           01-04-2004
# 2343    sabato 01 dicembre 2018 - 09:29       francof           01-06-2005
# 2344    sabato 01 dicembre 2018 - 10:35      marco_77           01-12-2013
# 2345    sabato 01 dicembre 2018 - 11:45  crazydiamond           01-07-2003
# 2346    sabato 01 dicembre 2018 - 11:56   ennio_paolo           01-10-2007
# 2347    sabato 01 dicembre 2018 - 12:00       miro911           01-12-2015
# 2348  domenica 02 dicembre 2018 - 02:58           ans           01-11-2011
# 2349  domenica 02 dicembre 2018 - 10:06  andreaverona           01-10-2014
# 2350  domenica 02 dicembre 2018 - 10:21    stradivari           01-11-2003
# 2351  domenica 02 dicembre 2018 - 10:31  lamby_spezza           01-05-2017
# 2352  domenica 02 dicembre 2018 - 11:10      andrea70           01-11-2005
# 2353  domenica 02 dicembre 2018 - 11:20       as911tv           01-10-2016
# 2354  domenica 02 dicembre 2018 - 11:38  andreaverona           01-10-2014
# 2355  domenica 02 dicembre 2018 - 16:02       nikolas           01-03-2014
# 2356    lunedì 03 dicembre 2018 - 10:31      seo74seo           01-01-2015
#
#       Num_Messages                                              Quote  \
# 0            27259
# 1            27259
# 2             3582  'Dovrebbe essere presentata entro l\'anno la P...
# 3             3582  ' ma con variazioni più significative rispetto...
# 4            27259
# 5            27259
# 6            27259
# 7             3582  'Ancora test al "Ring" per l\'attesa Porsche 9...
# 8            27259
# 9             1075
# 10            3582  'Ame della 911 le versioni aspirate quello che...
# 11           27259  "Bellissimo senz'altro Però non è che possa sc...
# 12            3582  "Non ho ragione imho di dubitare che anche sen...
# 13            3982  'Il suono del V8 Maserati è bellissimo forse p...
# 14           27259  "Sono abbstanza d'accordo sulla questione rumo...
# 15           27259
# 16            3582  'Ecco le prime immagini in veste definitiva ht...
# 17           27259
# 18             112
# 19           27259
# 20            3582  'La 911-992 dovrebbe essere presentata al Salo...
# 21            2742
# 22           27259
# 23             831
# 24             762
# 25            8758
# 26           27259
# 27            4878
# 28            2742
# 29            2742
# ...            ...                                                ...
# 2327           890
# 2328           272  La leva del cambio, ancorch\xe9 automatico, \x...
# 2329           273  Ovviamente vettura facile da guidare, ma comun...
# 2330         10794
# 2331          1260
# 2332         14119
# 2333          8113
# 2334          1261
# 2335          2682
# 2336          8114
# 2337          2559
# 2338          5829
# 2339           565
# 2340           672
# 2341          2392  Ma nessuna auto come la 911 \xe8 cos\xec evide...
# 2342          8115                    Poni,aspettiamo il tuo giudizio
# 2343         11398
# 2344          2395
# 2345         10573                           Dall'alto \xe8 splendida
# 2346         16676
# 2347           566
# 2348          1658  E quindi, a mio avviso, questo dovrebbe essere...
# 2349          1336
# 2350           952
# 2351           276  Alla destra vorrei vedere parcheggiata una 997...
# 2352          5830
# 2353           130
# 2354          1337
# 2355           129
# 2356           122
#
#                                                    Text       Engine
# 0     Stanno circolando sul web le prime immagini di...       neutro
# 1     Dovrebbe essere presentata entro l'anno la Por...       neutro
# 2     A me va benissimo. E mantiene il vecchio, caro...       neutro
# 3     Per fortuna. Perché quello sarebbe un po' sven...     positivo
# 4     Si, sulla 911 di serie il motore centrale non ...       neutro
# 5     Proseguono i test al "Ring" della 992, in part...  irrilevante
# 6     Ancora test al "Ring" per l'attesa Porsche 911...  irrilevante
# 7     Io sono convinto che in ogni caso difficilment...  irrilevante
# 8     Ame della 911 (le versioni aspirate) quello ch...  irrilevante
# 9     chissà se ce la faranno a mettere il navigator...  irrilevante
# 10    Bellissimo, senz'altro. Però non è che possa s...     positivo
# 11    Non ho ragione (imho) di dubitare che anche se...     positivo
# 12    Il suono del V8 Maserati è bellissimo, forse p...     positivo
# 13    Sono abbstanza d'accordo sulla questione rumor...     positivo
# 14    Esatto, anche a me il rumore eccessivo dà un p...  irrilevante
# 15    Ecco le prime immagini in veste definitiva. ht...  irrilevante
# 16    A me piace, forse i fari posteriori senza vari...  irrilevante
# 17    Si, il giallo è un colore che sta sempre bene ...  irrilevante
# 18    La 911 (che detesto per gelosia: gelosia nei c...  irrilevante
# 19    La 911-992 dovrebbe essere presentata al Salon...  irrilevante
# 20                                                   .   irrilevante
# 21    Uscite le foto... che dire.. a me piace da sem...  irrilevante
# 22    Io posso solo sognarla, comunque è sempre bell...  irrilevante
# 23                                          sempre top        neutro
# 24    La adoro, ovviamente mi piace anche quest'ulti...  irrilevante
# 25    Carina, anche se un po' massiccia nella parte ...  irrilevante
# 26    Mah, a vederla così, nel filmato di Quattroruo...  irrilevante
# 27    Quelle griglie sotto il lunotto non mi convinc...  irrilevante
# 28    Pregevole il richiamo in legno alla 901 <img a...  irrilevante
# 29                                                edit   irrilevante
# ...                                                 ...          ...
# 2327                        eh...ma IL SOUND???????????       neutro
# 2328    Ricorda, in peggio (e non era facile..), que...  irrilevante
# 2329    Ne parlavo proprio oggi pomeriggio in una ch...  irrilevante
# 2330  Caro Lamberto sono d'accordissimo con te, orma...  irrilevante
# 2331  Qui si vedono meglio le differenze con la 991 ...  irrilevante
# 2332  La cosa pi\xf9 eclatante, che segue un corso c...  irrilevante
# 2333                                   a cosa somiglia?  irrilevante
# 2334                                    Alla 993 targa.  irrilevante
# 2335  si ci assomiglia (dall'alto)....ma se la metti...       neutro
# 2336        io ci vedo i parafanghi wide del 964 turbo   irrilevante
# 2337                        Dall'alto \xe8 splendida !!  irrilevante
# 2338  Un piccolo contributo.  Vediamo come \xe8 evol...  irrilevante
# 2339                    Poni,aspettiamo il tuo giudizio  irrilevante
# 2340  Andrea 70,  per quello che conta questa volta ...  irrilevante
# 2341   Concordo pienamente ed \xe8 questo (oltre che...  irrilevante
# 2342    non so se ci avete mai fatto caso, ma in 14 ...  irrilevante
# 2343  Mah, io un dubbio ( forte) l'avrei: " come vuo...  irrilevante
# 2344  Franco, fanno bene a non fare ricerche di merc...  irrilevante
# 2345   Alessandro,quando riusciranno a farle percorr...     positivo
# 2346                         Andrea70 +1  Poniello +1    irrilevante
# 2347                            Andrea70 +2 Poniello +2  irrilevante
# 2348   +3 ... aggiungerei alle tavole da surf sulle ...  irrilevante
# 2349  Andrea70 ritengo i tuoi interventi e vecchi po...  irrilevante
# 2350  La 911 \xe8 nata come auto sportiva ma versati...  irrilevante
# 2351    Grande Andrea  in effetti se bisogna sognare...  irrilevante
# 2352  Andreaverona,  Capisco il tuo intervento . Per...     positivo
# 2353  Sempre affascinante e desiderabile...ma quando...       neutro
# 2354  Chiarissimo Andrea, come sempre.  E sinceri co...  irrilevante
# 2355        https://www.youtube.com/watch?v=Zyjei2FI1Fo  irrilevante
# 2356  bello il paragone 911 / golf di andrea 70!  So...  irrilevante
#
# [2357 rows x 10 columns]

# %% [markdown]
# Preprocessing

# %%
unlabeled_dataset = new_unlabeled_dataset.copy(deep=True)
new_unlabeled_dataset
# Out:
#              Forum     Thread_Title  \
# 0     Quattroruote  Porsche 911/992
# 1     Quattroruote  Porsche 911/992
# 2     Quattroruote  Porsche 911/992
# 3     Quattroruote  Porsche 911/992
# 4     Quattroruote  Porsche 911/992
# 5     Quattroruote  Porsche 911/992
# 6     Quattroruote  Porsche 911/992
# 7     Quattroruote  Porsche 911/992
# 8     Quattroruote  Porsche 911/992
# 9     Quattroruote  Porsche 911/992
# 10    Quattroruote  Porsche 911/992
# 11    Quattroruote  Porsche 911/992
# 12    Quattroruote  Porsche 911/992
# 13    Quattroruote  Porsche 911/992
# 14    Quattroruote  Porsche 911/992
# 15    Quattroruote  Porsche 911/992
# 16    Quattroruote  Porsche 911/992
# 17    Quattroruote  Porsche 911/992
# 18    Quattroruote  Porsche 911/992
# 19    Quattroruote  Porsche 911/992
# 20    Quattroruote  Porsche 911/992
# 21    Quattroruote  Porsche 911/992
# 22    Quattroruote  Porsche 911/992
# 23    Quattroruote  Porsche 911/992
# 24    Quattroruote  Porsche 911/992
# 25    Quattroruote  Porsche 911/992
# 26    Quattroruote  Porsche 911/992
# 27    Quattroruote  Porsche 911/992
# 28    Quattroruote  Porsche 911/992
# 29    Quattroruote  Porsche 911/992
# ...            ...              ...
# 2327  Porschemania    992 ECCOLA!!!
# 2328  Porschemania    992 ECCOLA!!!
# 2329  Porschemania    992 ECCOLA!!!
# 2330  Porschemania    992 ECCOLA!!!
# 2331  Porschemania    992 ECCOLA!!!
# 2332  Porschemania    992 ECCOLA!!!
# 2333  Porschemania    992 ECCOLA!!!
# 2334  Porschemania    992 ECCOLA!!!
# 2335  Porschemania    992 ECCOLA!!!
# 2336  Porschemania    992 ECCOLA!!!
# 2337  Porschemania    992 ECCOLA!!!
# 2338  Porschemania    992 ECCOLA!!!
# 2339  Porschemania    992 ECCOLA!!!
# 2340  Porschemania    992 ECCOLA!!!
# 2341  Porschemania    992 ECCOLA!!!
# 2342  Porschemania    992 ECCOLA!!!
# 2343  Porschemania    992 ECCOLA!!!
# 2344  Porschemania    992 ECCOLA!!!
# 2345  Porschemania    992 ECCOLA!!!
# 2346  Porschemania    992 ECCOLA!!!
# 2347  Porschemania    992 ECCOLA!!!
# 2348  Porschemania    992 ECCOLA!!!
# 2349  Porschemania    992 ECCOLA!!!
# 2350  Porschemania    992 ECCOLA!!!
# 2351  Porschemania    992 ECCOLA!!!
# 2352  Porschemania    992 ECCOLA!!!
# 2353  Porschemania    992 ECCOLA!!!
# 2354  Porschemania    992 ECCOLA!!!
# 2355  Porschemania    992 ECCOLA!!!
# 2356  Porschemania    992 ECCOLA!!!
#
#                                                     URL  \
# 0     https://forum.quattroruote.it/threads/porsche-...
# 1     https://forum.quattroruote.it/threads/porsche-...
# 2     https://forum.quattroruote.it/threads/porsche-...
# 3     https://forum.quattroruote.it/threads/porsche-...
# 4     https://forum.quattroruote.it/threads/porsche-...
# 5     https://forum.quattroruote.it/threads/porsche-...
# 6     https://forum.quattroruote.it/threads/porsche-...
# 7     https://forum.quattroruote.it/threads/porsche-...
# 8     https://forum.quattroruote.it/threads/porsche-...
# 9     https://forum.quattroruote.it/threads/porsche-...
# 10    https://forum.quattroruote.it/threads/porsche-...
# 11    https://forum.quattroruote.it/threads/porsche-...
# 12    https://forum.quattroruote.it/threads/porsche-...
# 13    https://forum.quattroruote.it/threads/porsche-...
# 14    https://forum.quattroruote.it/threads/porsche-...
# 15    https://forum.quattroruote.it/threads/porsche-...
# 16    https://forum.quattroruote.it/threads/porsche-...
# 17    https://forum.quattroruote.it/threads/porsche-...
# 18    https://forum.quattroruote.it/threads/porsche-...
# 19    https://forum.quattroruote.it/threads/porsche-...
# 20    https://forum.quattroruote.it/threads/porsche-...
# 21    https://forum.quattroruote.it/threads/porsche-...
# 22    https://forum.quattroruote.it/threads/porsche-...
# 23    https://forum.quattroruote.it/threads/porsche-...
# 24    https://forum.quattroruote.it/threads/porsche-...
# 25    https://forum.quattroruote.it/threads/porsche-...
# 26    https://forum.quattroruote.it/threads/porsche-...
# 27    https://forum.quattroruote.it/threads/porsche-...
# 28    https://forum.quattroruote.it/threads/porsche-...
# 29    https://forum.quattroruote.it/threads/porsche-...
# ...                                                 ...
# 2327  http://www.porschemania.it/discus/messages/968...
# 2328  http://www.porschemania.it/discus/messages/968...
# 2329  http://www.porschemania.it/discus/messages/968...
# 2330  http://www.porschemania.it/discus/messages/968...
# 2331  http://www.porschemania.it/discus/messages/968...
# 2332  http://www.porschemania.it/discus/messages/968...
# 2333  http://www.porschemania.it/discus/messages/968...
# 2334  http://www.porschemania.it/discus/messages/968...
# 2335  http://www.porschemania.it/discus/messages/968...
# 2336  http://www.porschemania.it/discus/messages/968...
# 2337  http://www.porschemania.it/discus/messages/968...
# 2338  http://www.porschemania.it/discus/messages/968...
# 2339  http://www.porschemania.it/discus/messages/968...
# 2340  http://www.porschemania.it/discus/messages/968...
# 2341  http://www.porschemania.it/discus/messages/968...
# 2342  http://www.porschemania.it/discus/messages/968...
# 2343  http://www.porschemania.it/discus/messages/968...
# 2344  http://www.porschemania.it/discus/messages/968...
# 2345  http://www.porschemania.it/discus/messages/968...
# 2346  http://www.porschemania.it/discus/messages/968...
# 2347  http://www.porschemania.it/discus/messages/968...
# 2348  http://www.porschemania.it/discus/messages/968...
# 2349  http://www.porschemania.it/discus/messages/968...
# 2350  http://www.porschemania.it/discus/messages/968...
# 2351  http://www.porschemania.it/discus/messages/968...
# 2352  http://www.porschemania.it/discus/messages/968...
# 2353  http://www.porschemania.it/discus/messages/968...
# 2354  http://www.porschemania.it/discus/messages/968...
# 2355  http://www.porschemania.it/discus/messages/968...
# 2356  http://www.porschemania.it/discus/messages/968...
#
#                               Timestamp      Username    Subscription_Date  \
# 0                   19-07-2017 01:26:00      pilota54  03-04-2009 02:01:04
# 1                   10-04-2018 18:06:00      pilota54  03-04-2009 02:01:04
# 2                   11-04-2018 20:16:00   Mastertanto  01-04-2009 03:16:07
# 3                   11-04-2018 20:27:00   Mastertanto  01-04-2009 03:16:07
# 4                   12-04-2018 00:50:00      pilota54  03-04-2009 02:01:04
# 5                   19-04-2018 14:03:00      pilota54  03-04-2009 02:01:04
# 6                   25-06-2018 18:09:00      pilota54  03-04-2009 02:01:04
# 7                    7-07-2018 11:43:00   Mastertanto  01-04-2009 03:16:07
# 8                    7-07-2018 11:58:00      pilota54  03-04-2009 02:01:04
# 9                    7-07-2018 15:30:00       LA MAGA  18-05-2018 23:35:16
# 10                   7-07-2018 16:23:00   Mastertanto  01-04-2009 03:16:07
# 11                   7-07-2018 18:10:00      pilota54  03-04-2009 02:01:04
# 12                   7-07-2018 21:17:00   Mastertanto  01-04-2009 03:16:07
# 13                   8-07-2018 08:55:00  mani in alto  22-06-2017 18:30:55
# 14                   7-07-2018 23:30:00      pilota54  03-04-2009 02:01:04
# 15                   7-09-2018 18:46:00      pilota54  03-04-2009 02:01:04
# 16                   8-09-2018 10:36:00   Mastertanto  01-04-2009 03:16:07
# 17                   8-09-2018 14:42:00      pilota54  03-04-2009 02:01:04
# 18                  25-09-2018 14:36:00   livorno1915  22-01-2010 14:30:43
# 19                  25-11-2018 00:57:00      pilota54  03-04-2009 02:01:04
# 20                  25-11-2018 19:36:00   Mastertanto  01-04-2009 03:16:07
# 21                  28-11-2018 09:52:00     perdegola  01-04-2009 18:46:34
# 22                  28-11-2018 12:45:00      pilota54  03-04-2009 02:01:04
# 23                  28-11-2018 12:29:00      xander71  01-04-2009 15:51:26
# 24                  29-11-2018 09:39:00      Lenny_84  17-02-2016 16:49:02
# 25                  30-11-2018 11:51:00     elancia75  01-04-2009 00:08:53
# 26                   1-12-2018 23:10:00      pilota54  03-04-2009 02:01:04
# 27                   1-12-2018 23:16:00         Ax-80  27-09-2018 23:46:17
# 28                   2-12-2018 09:49:00     perdegola  01-04-2009 18:46:34
# 29                   3-12-2018 10:10:00     perdegola  01-04-2009 18:46:34
# ...                                 ...           ...                  ...
# 2327   giovedì 29 novembre 2018 - 20:49        845ste           01-03-2014
# 2328   giovedì 29 novembre 2018 - 21:18  lamby_spezza           01-05-2017
# 2329   giovedì 29 novembre 2018 - 21:27  lamby_spezza           01-05-2017
# 2330   giovedì 29 novembre 2018 - 21:37        ric968           01-11-2006
# 2331   giovedì 29 novembre 2018 - 22:13   peppuccio71           01-01-2015
# 2332   giovedì 29 novembre 2018 - 22:35         elfer           01-09-2002
# 2333   venerdì 30 novembre 2018 - 14:04      poniello           01-04-2004
# 2334   venerdì 30 novembre 2018 - 14:15   peppuccio71           01-01-2015
# 2335   venerdì 30 novembre 2018 - 14:43      pirulero           01-06-2004
# 2336   venerdì 30 novembre 2018 - 19:36      poniello           01-04-2004
# 2337   venerdì 30 novembre 2018 - 20:26       greyfox           01-05-2003
# 2338   venerdì 30 novembre 2018 - 20:44      andrea70           01-11-2005
# 2339   venerdì 30 novembre 2018 - 21:25       miro911           01-12-2015
# 2340   venerdì 30 novembre 2018 - 21:54          diti           01-10-2012
# 2341   venerdì 30 novembre 2018 - 23:36      marco_77           01-12-2013
# 2342    sabato 01 dicembre 2018 - 08:49      poniello           01-04-2004
# 2343    sabato 01 dicembre 2018 - 09:29       francof           01-06-2005
# 2344    sabato 01 dicembre 2018 - 10:35      marco_77           01-12-2013
# 2345    sabato 01 dicembre 2018 - 11:45  crazydiamond           01-07-2003
# 2346    sabato 01 dicembre 2018 - 11:56   ennio_paolo           01-10-2007
# 2347    sabato 01 dicembre 2018 - 12:00       miro911           01-12-2015
# 2348  domenica 02 dicembre 2018 - 02:58           ans           01-11-2011
# 2349  domenica 02 dicembre 2018 - 10:06  andreaverona           01-10-2014
# 2350  domenica 02 dicembre 2018 - 10:21    stradivari           01-11-2003
# 2351  domenica 02 dicembre 2018 - 10:31  lamby_spezza           01-05-2017
# 2352  domenica 02 dicembre 2018 - 11:10      andrea70           01-11-2005
# 2353  domenica 02 dicembre 2018 - 11:20       as911tv           01-10-2016
# 2354  domenica 02 dicembre 2018 - 11:38  andreaverona           01-10-2014
# 2355  domenica 02 dicembre 2018 - 16:02       nikolas           01-03-2014
# 2356    lunedì 03 dicembre 2018 - 10:31      seo74seo           01-01-2015
#
#       Num_Messages                                              Quote  \
# 0            27259
# 1            27259
# 2             3582  'Dovrebbe essere presentata entro l\'anno la P...
# 3             3582  ' ma con variazioni più significative rispetto...
# 4            27259
# 5            27259
# 6            27259
# 7             3582  'Ancora test al "Ring" per l\'attesa Porsche 9...
# 8            27259
# 9             1075
# 10            3582  'Ame della 911 le versioni aspirate quello che...
# 11           27259  "Bellissimo senz'altro Però non è che possa sc...
# 12            3582  "Non ho ragione imho di dubitare che anche sen...
# 13            3982  'Il suono del V8 Maserati è bellissimo forse p...
# 14           27259  "Sono abbstanza d'accordo sulla questione rumo...
# 15           27259
# 16            3582  'Ecco le prime immagini in veste definitiva ht...
# 17           27259
# 18             112
# 19           27259
# 20            3582  'La 911-992 dovrebbe essere presentata al Salo...
# 21            2742
# 22           27259
# 23             831
# 24             762
# 25            8758
# 26           27259
# 27            4878
# 28            2742
# 29            2742
# ...            ...                                                ...
# 2327           890
# 2328           272  La leva del cambio, ancorch\xe9 automatico, \x...
# 2329           273  Ovviamente vettura facile da guidare, ma comun...
# 2330         10794
# 2331          1260
# 2332         14119
# 2333          8113
# 2334          1261
# 2335          2682
# 2336          8114
# 2337          2559
# 2338          5829
# 2339           565
# 2340           672
# 2341          2392  Ma nessuna auto come la 911 \xe8 cos\xec evide...
# 2342          8115                    Poni,aspettiamo il tuo giudizio
# 2343         11398
# 2344          2395
# 2345         10573                           Dall'alto \xe8 splendida
# 2346         16676
# 2347           566
# 2348          1658  E quindi, a mio avviso, questo dovrebbe essere...
# 2349          1336
# 2350           952
# 2351           276  Alla destra vorrei vedere parcheggiata una 997...
# 2352          5830
# 2353           130
# 2354          1337
# 2355           129
# 2356           122
#
#                                                    Text       Engine
# 0     Stanno circolando sul web le prime immagini di...       neutro
# 1     Dovrebbe essere presentata entro l'anno la Por...       neutro
# 2     A me va benissimo. E mantiene il vecchio, caro...       neutro
# 3     Per fortuna. Perché quello sarebbe un po' sven...     positivo
# 4     Si, sulla 911 di serie il motore centrale non ...       neutro
# 5     Proseguono i test al "Ring" della 992, in part...  irrilevante
# 6     Ancora test al "Ring" per l'attesa Porsche 911...  irrilevante
# 7     Io sono convinto che in ogni caso difficilment...  irrilevante
# 8     Ame della 911 (le versioni aspirate) quello ch...  irrilevante
# 9     chissà se ce la faranno a mettere il navigator...  irrilevante
# 10    Bellissimo, senz'altro. Però non è che possa s...     positivo
# 11    Non ho ragione (imho) di dubitare che anche se...     positivo
# 12    Il suono del V8 Maserati è bellissimo, forse p...     positivo
# 13    Sono abbstanza d'accordo sulla questione rumor...     positivo
# 14    Esatto, anche a me il rumore eccessivo dà un p...  irrilevante
# 15    Ecco le prime immagini in veste definitiva. ht...  irrilevante
# 16    A me piace, forse i fari posteriori senza vari...  irrilevante
# 17    Si, il giallo è un colore che sta sempre bene ...  irrilevante
# 18    La 911 (che detesto per gelosia: gelosia nei c...  irrilevante
# 19    La 911-992 dovrebbe essere presentata al Salon...  irrilevante
# 20                                                   .   irrilevante
# 21    Uscite le foto... che dire.. a me piace da sem...  irrilevante
# 22    Io posso solo sognarla, comunque è sempre bell...  irrilevante
# 23                                          sempre top        neutro
# 24    La adoro, ovviamente mi piace anche quest'ulti...  irrilevante
# 25    Carina, anche se un po' massiccia nella parte ...  irrilevante
# 26    Mah, a vederla così, nel filmato di Quattroruo...  irrilevante
# 27    Quelle griglie sotto il lunotto non mi convinc...  irrilevante
# 28    Pregevole il richiamo in legno alla 901 <img a...  irrilevante
# 29                                                edit   irrilevante
# ...                                                 ...          ...
# 2327                        eh...ma IL SOUND???????????       neutro
# 2328    Ricorda, in peggio (e non era facile..), que...  irrilevante
# 2329    Ne parlavo proprio oggi pomeriggio in una ch...  irrilevante
# 2330  Caro Lamberto sono d'accordissimo con te, orma...  irrilevante
# 2331  Qui si vedono meglio le differenze con la 991 ...  irrilevante
# 2332  La cosa pi\xf9 eclatante, che segue un corso c...  irrilevante
# 2333                                   a cosa somiglia?  irrilevante
# 2334                                    Alla 993 targa.  irrilevante
# 2335  si ci assomiglia (dall'alto)....ma se la metti...       neutro
# 2336        io ci vedo i parafanghi wide del 964 turbo   irrilevante
# 2337                        Dall'alto \xe8 splendida !!  irrilevante
# 2338  Un piccolo contributo.  Vediamo come \xe8 evol...  irrilevante
# 2339                    Poni,aspettiamo il tuo giudizio  irrilevante
# 2340  Andrea 70,  per quello che conta questa volta ...  irrilevante
# 2341   Concordo pienamente ed \xe8 questo (oltre che...  irrilevante
# 2342    non so se ci avete mai fatto caso, ma in 14 ...  irrilevante
# 2343  Mah, io un dubbio ( forte) l'avrei: " come vuo...  irrilevante
# 2344  Franco, fanno bene a non fare ricerche di merc...  irrilevante
# 2345   Alessandro,quando riusciranno a farle percorr...     positivo
# 2346                         Andrea70 +1  Poniello +1    irrilevante
# 2347                            Andrea70 +2 Poniello +2  irrilevante
# 2348   +3 ... aggiungerei alle tavole da surf sulle ...  irrilevante
# 2349  Andrea70 ritengo i tuoi interventi e vecchi po...  irrilevante
# 2350  La 911 \xe8 nata come auto sportiva ma versati...  irrilevante
# 2351    Grande Andrea  in effetti se bisogna sognare...  irrilevante
# 2352  Andreaverona,  Capisco il tuo intervento . Per...     positivo
# 2353  Sempre affascinante e desiderabile...ma quando...       neutro
# 2354  Chiarissimo Andrea, come sempre.  E sinceri co...  irrilevante
# 2355        https://www.youtube.com/watch?v=Zyjei2FI1Fo  irrilevante
# 2356  bello il paragone 911 / golf di andrea 70!  So...  irrilevante
#
# [2357 rows x 10 columns]

# %%
irr_rel_concat = []
pp = Preprocessor()
for i in range(len(unlabeled_dataset)):
    irr_rel_concat.append(combine_text_quote(pp.preprocessText(unlabeled_dataset['Text'].iloc[i], use_stemmer=True, ner=True), pp.preprocessText(unlabeled_dataset['Quote'].iloc[i], use_stemmer=True, ner=True), divide_quote=False))

# %% [markdown]
# Vectorize for irrelevant / relevant

# %%
irr_rel_vectorized = vec.transform(irr_rel_concat)[:, list(selected_features_logreg)]
irr_rel_vectorized.shape
# Out:
# (2357, 1684)

# %% [markdown]
# Predict irerelevant/relevant

# %%
unlabeled_pred_ir = clf_logreg_fs.best_estimator_.predict(irr_rel_vectorized)

# %%
collections.Counter(unlabeled_pred_ir)
# Out:
# Counter({1: 633, 0: 1724})

# %% [markdown]
# Predict Brand Sentiment

# %%
for i in range(len(unlabeled_pred_ir)):
    if unlabeled_pred_ir[i] == 1:
        testo = unlabeled_dataset.iloc[i]['Text']
        quote = unlabeled_dataset.iloc[i]['Quote']
        p = bpef.predict(pd.Series(testo), pd.Series(quote))
        print(p)
        unlabeled_pred_ir[i] = p[0]
# Out:
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [2]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [3]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [3]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ...
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [3]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [3]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [3]
# ######## ('word', False, 'svm') ########
# ######## ('word', False, 'logreg') ########
# ######## ('word', False, 'naibay') ########
# ######## ('word', False, 'rndfst') ########
# ######## ('word', True, 'svm') ########
# ######## ('word', True, 'logreg') ########
# ######## ('word', True, 'naibay') ########
# ######## ('word', True, 'rndfst') ########
# ######## ('pos', False, 'svm') ########
# ######## ('pos', False, 'logreg') ########
# ######## ('pos', False, 'naibay') ########
# ######## ('pos', False, 'rndfst') ########
# ######## ('pos', True, 'svm') ########
# ######## ('pos', True, 'logreg') ########
# ######## ('pos', True, 'naibay') ########
# ######## ('pos', True, 'rndfst') ########
# ######## ('swnt', False, 'svm') ########
# ######## ('swnt', False, 'logreg') ########
# ######## ('swnt', False, 'naibay') ########
# ######## ('swnt', False, 'rndfst') ########
# ######## ('swnt', True, 'svm') ########
# ######## ('swnt', True, 'logreg') ########
# ######## ('swnt', True, 'naibay') ########
# ######## ('swnt', True, 'rndfst') ########
# [1]

# %%
collections.Counter(unlabeled_pred_ir)
# Out:
# Counter({2: 47, 0: 1724, 1: 508, 3: 78})

# %%
unlabeled_labels = []
for i in range(len(unlabeled_pred_ir)):
    if unlabeled_pred_ir[i] == 0:
        unlabeled_labels.append('irrilevante')
    elif unlabeled_pred_ir[i] == 1:
        unlabeled_labels.append('positivo')
    elif unlabeled_pred_ir[i] == 2:
        unlabeled_labels.append('neutro')
    elif unlabeled_pred_ir[i] == 3:
        unlabeled_labels.append('negativo')

# %%
new_unlabeled_dataset['Brand'] = unlabeled_labels

# %%
new_unlabeled_dataset
# Out:
#              Forum     Thread_Title  \
# 0     Quattroruote  Porsche 911/992
# 1     Quattroruote  Porsche 911/992
# 2     Quattroruote  Porsche 911/992
# 3     Quattroruote  Porsche 911/992
# 4     Quattroruote  Porsche 911/992
# 5     Quattroruote  Porsche 911/992
# 6     Quattroruote  Porsche 911/992
# 7     Quattroruote  Porsche 911/992
# 8     Quattroruote  Porsche 911/992
# 9     Quattroruote  Porsche 911/992
# 10    Quattroruote  Porsche 911/992
# 11    Quattroruote  Porsche 911/992
# 12    Quattroruote  Porsche 911/992
# 13    Quattroruote  Porsche 911/992
# 14    Quattroruote  Porsche 911/992
# 15    Quattroruote  Porsche 911/992
# 16    Quattroruote  Porsche 911/992
# 17    Quattroruote  Porsche 911/992
# 18    Quattroruote  Porsche 911/992
# 19    Quattroruote  Porsche 911/992
# 20    Quattroruote  Porsche 911/992
# 21    Quattroruote  Porsche 911/992
# 22    Quattroruote  Porsche 911/992
# 23    Quattroruote  Porsche 911/992
# 24    Quattroruote  Porsche 911/992
# 25    Quattroruote  Porsche 911/992
# 26    Quattroruote  Porsche 911/992
# 27    Quattroruote  Porsche 911/992
# 28    Quattroruote  Porsche 911/992
# 29    Quattroruote  Porsche 911/992
# ...            ...              ...
# 2327  Porschemania    992 ECCOLA!!!
# 2328  Porschemania    992 ECCOLA!!!
# 2329  Porschemania    992 ECCOLA!!!
# 2330  Porschemania    992 ECCOLA!!!
# 2331  Porschemania    992 ECCOLA!!!
# 2332  Porschemania    992 ECCOLA!!!
# 2333  Porschemania    992 ECCOLA!!!
# 2334  Porschemania    992 ECCOLA!!!
# 2335  Porschemania    992 ECCOLA!!!
# 2336  Porschemania    992 ECCOLA!!!
# 2337  Porschemania    992 ECCOLA!!!
# 2338  Porschemania    992 ECCOLA!!!
# 2339  Porschemania    992 ECCOLA!!!
# 2340  Porschemania    992 ECCOLA!!!
# 2341  Porschemania    992 ECCOLA!!!
# 2342  Porschemania    992 ECCOLA!!!
# 2343  Porschemania    992 ECCOLA!!!
# 2344  Porschemania    992 ECCOLA!!!
# 2345  Porschemania    992 ECCOLA!!!
# 2346  Porschemania    992 ECCOLA!!!
# 2347  Porschemania    992 ECCOLA!!!
# 2348  Porschemania    992 ECCOLA!!!
# 2349  Porschemania    992 ECCOLA!!!
# 2350  Porschemania    992 ECCOLA!!!
# 2351  Porschemania    992 ECCOLA!!!
# 2352  Porschemania    992 ECCOLA!!!
# 2353  Porschemania    992 ECCOLA!!!
# 2354  Porschemania    992 ECCOLA!!!
# 2355  Porschemania    992 ECCOLA!!!
# 2356  Porschemania    992 ECCOLA!!!
#
#                                                     URL  \
# 0     https://forum.quattroruote.it/threads/porsche-...
# 1     https://forum.quattroruote.it/threads/porsche-...
# 2     https://forum.quattroruote.it/threads/porsche-...
# 3     https://forum.quattroruote.it/threads/porsche-...
# 4     https://forum.quattroruote.it/threads/porsche-...
# 5     https://forum.quattroruote.it/threads/porsche-...
# 6     https://forum.quattroruote.it/threads/porsche-...
# 7     https://forum.quattroruote.it/threads/porsche-...
# 8     https://forum.quattroruote.it/threads/porsche-...
# 9     https://forum.quattroruote.it/threads/porsche-...
# 10    https://forum.quattroruote.it/threads/porsche-...
# 11    https://forum.quattroruote.it/threads/porsche-...
# 12    https://forum.quattroruote.it/threads/porsche-...
# 13    https://forum.quattroruote.it/threads/porsche-...
# 14    https://forum.quattroruote.it/threads/porsche-...
# 15    https://forum.quattroruote.it/threads/porsche-...
# 16    https://forum.quattroruote.it/threads/porsche-...
# 17    https://forum.quattroruote.it/threads/porsche-...
# 18    https://forum.quattroruote.it/threads/porsche-...
# 19    https://forum.quattroruote.it/threads/porsche-...
# 20    https://forum.quattroruote.it/threads/porsche-...
# 21    https://forum.quattroruote.it/threads/porsche-...
# 22    https://forum.quattroruote.it/threads/porsche-...
# 23    https://forum.quattroruote.it/threads/porsche-...
# 24    https://forum.quattroruote.it/threads/porsche-...
# 25    https://forum.quattroruote.it/threads/porsche-...
# 26    https://forum.quattroruote.it/threads/porsche-...
# 27    https://forum.quattroruote.it/threads/porsche-...
# 28    https://forum.quattroruote.it/threads/porsche-...
# 29    https://forum.quattroruote.it/threads/porsche-...
# ...                                                 ...
# 2327  http://www.porschemania.it/discus/messages/968...
# 2328  http://www.porschemania.it/discus/messages/968...
# 2329  http://www.porschemania.it/discus/messages/968...
# 2330  http://www.porschemania.it/discus/messages/968...
# 2331  http://www.porschemania.it/discus/messages/968...
# 2332  http://www.porschemania.it/discus/messages/968...
# 2333  http://www.porschemania.it/discus/messages/968...
# 2334  http://www.porschemania.it/discus/messages/968...
# 2335  http://www.porschemania.it/discus/messages/968...
# 2336  http://www.porschemania.it/discus/messages/968...
# 2337  http://www.porschemania.it/discus/messages/968...
# 2338  http://www.porschemania.it/discus/messages/968...
# 2339  http://www.porschemania.it/discus/messages/968...
# 2340  http://www.porschemania.it/discus/messages/968...
# 2341  http://www.porschemania.it/discus/messages/968...
# 2342  http://www.porschemania.it/discus/messages/968...
# 2343  http://www.porschemania.it/discus/messages/968...
# 2344  http://www.porschemania.it/discus/messages/968...
# 2345  http://www.porschemania.it/discus/messages/968...
# 2346  http://www.porschemania.it/discus/messages/968...
# 2347  http://www.porschemania.it/discus/messages/968...
# 2348  http://www.porschemania.it/discus/messages/968...
# 2349  http://www.porschemania.it/discus/messages/968...
# 2350  http://www.porschemania.it/discus/messages/968...
# 2351  http://www.porschemania.it/discus/messages/968...
# 2352  http://www.porschemania.it/discus/messages/968...
# 2353  http://www.porschemania.it/discus/messages/968...
# 2354  http://www.porschemania.it/discus/messages/968...
# 2355  http://www.porschemania.it/discus/messages/968...
# 2356  http://www.porschemania.it/discus/messages/968...
#
#                               Timestamp      Username    Subscription_Date  \
# 0                   19-07-2017 01:26:00      pilota54  03-04-2009 02:01:04
# 1                   10-04-2018 18:06:00      pilota54  03-04-2009 02:01:04
# 2                   11-04-2018 20:16:00   Mastertanto  01-04-2009 03:16:07
# 3                   11-04-2018 20:27:00   Mastertanto  01-04-2009 03:16:07
# 4                   12-04-2018 00:50:00      pilota54  03-04-2009 02:01:04
# 5                   19-04-2018 14:03:00      pilota54  03-04-2009 02:01:04
# 6                   25-06-2018 18:09:00      pilota54  03-04-2009 02:01:04
# 7                    7-07-2018 11:43:00   Mastertanto  01-04-2009 03:16:07
# 8                    7-07-2018 11:58:00      pilota54  03-04-2009 02:01:04
# 9                    7-07-2018 15:30:00       LA MAGA  18-05-2018 23:35:16
# 10                   7-07-2018 16:23:00   Mastertanto  01-04-2009 03:16:07
# 11                   7-07-2018 18:10:00      pilota54  03-04-2009 02:01:04
# 12                   7-07-2018 21:17:00   Mastertanto  01-04-2009 03:16:07
# 13                   8-07-2018 08:55:00  mani in alto  22-06-2017 18:30:55
# 14                   7-07-2018 23:30:00      pilota54  03-04-2009 02:01:04
# 15                   7-09-2018 18:46:00      pilota54  03-04-2009 02:01:04
# 16                   8-09-2018 10:36:00   Mastertanto  01-04-2009 03:16:07
# 17                   8-09-2018 14:42:00      pilota54  03-04-2009 02:01:04
# 18                  25-09-2018 14:36:00   livorno1915  22-01-2010 14:30:43
# 19                  25-11-2018 00:57:00      pilota54  03-04-2009 02:01:04
# 20                  25-11-2018 19:36:00   Mastertanto  01-04-2009 03:16:07
# 21                  28-11-2018 09:52:00     perdegola  01-04-2009 18:46:34
# 22                  28-11-2018 12:45:00      pilota54  03-04-2009 02:01:04
# 23                  28-11-2018 12:29:00      xander71  01-04-2009 15:51:26
# 24                  29-11-2018 09:39:00      Lenny_84  17-02-2016 16:49:02
# 25                  30-11-2018 11:51:00     elancia75  01-04-2009 00:08:53
# 26                   1-12-2018 23:10:00      pilota54  03-04-2009 02:01:04
# 27                   1-12-2018 23:16:00         Ax-80  27-09-2018 23:46:17
# 28                   2-12-2018 09:49:00     perdegola  01-04-2009 18:46:34
# 29                   3-12-2018 10:10:00     perdegola  01-04-2009 18:46:34
# ...                                 ...           ...                  ...
# 2327   giovedì 29 novembre 2018 - 20:49        845ste           01-03-2014
# 2328   giovedì 29 novembre 2018 - 21:18  lamby_spezza           01-05-2017
# 2329   giovedì 29 novembre 2018 - 21:27  lamby_spezza           01-05-2017
# 2330   giovedì 29 novembre 2018 - 21:37        ric968           01-11-2006
# 2331   giovedì 29 novembre 2018 - 22:13   peppuccio71           01-01-2015
# 2332   giovedì 29 novembre 2018 - 22:35         elfer           01-09-2002
# 2333   venerdì 30 novembre 2018 - 14:04      poniello           01-04-2004
# 2334   venerdì 30 novembre 2018 - 14:15   peppuccio71           01-01-2015
# 2335   venerdì 30 novembre 2018 - 14:43      pirulero           01-06-2004
# 2336   venerdì 30 novembre 2018 - 19:36      poniello           01-04-2004
# 2337   venerdì 30 novembre 2018 - 20:26       greyfox           01-05-2003
# 2338   venerdì 30 novembre 2018 - 20:44      andrea70           01-11-2005
# 2339   venerdì 30 novembre 2018 - 21:25       miro911           01-12-2015
# 2340   venerdì 30 novembre 2018 - 21:54          diti           01-10-2012
# 2341   venerdì 30 novembre 2018 - 23:36      marco_77           01-12-2013
# 2342    sabato 01 dicembre 2018 - 08:49      poniello           01-04-2004
# 2343    sabato 01 dicembre 2018 - 09:29       francof           01-06-2005
# 2344    sabato 01 dicembre 2018 - 10:35      marco_77           01-12-2013
# 2345    sabato 01 dicembre 2018 - 11:45  crazydiamond           01-07-2003
# 2346    sabato 01 dicembre 2018 - 11:56   ennio_paolo           01-10-2007
# 2347    sabato 01 dicembre 2018 - 12:00       miro911           01-12-2015
# 2348  domenica 02 dicembre 2018 - 02:58           ans           01-11-2011
# 2349  domenica 02 dicembre 2018 - 10:06  andreaverona           01-10-2014
# 2350  domenica 02 dicembre 2018 - 10:21    stradivari           01-11-2003
# 2351  domenica 02 dicembre 2018 - 10:31  lamby_spezza           01-05-2017
# 2352  domenica 02 dicembre 2018 - 11:10      andrea70           01-11-2005
# 2353  domenica 02 dicembre 2018 - 11:20       as911tv           01-10-2016
# 2354  domenica 02 dicembre 2018 - 11:38  andreaverona           01-10-2014
# 2355  domenica 02 dicembre 2018 - 16:02       nikolas           01-03-2014
# 2356    lunedì 03 dicembre 2018 - 10:31      seo74seo           01-01-2015
#
#       Num_Messages                                              Quote  \
# 0            27259
# 1            27259
# 2             3582  'Dovrebbe essere presentata entro l\'anno la P...
# 3             3582  ' ma con variazioni più significative rispetto...
# 4            27259
# 5            27259
# 6            27259
# 7             3582  'Ancora test al "Ring" per l\'attesa Porsche 9...
# 8            27259
# 9             1075
# 10            3582  'Ame della 911 le versioni aspirate quello che...
# 11           27259  "Bellissimo senz'altro Però non è che possa sc...
# 12            3582  "Non ho ragione imho di dubitare che anche sen...
# 13            3982  'Il suono del V8 Maserati è bellissimo forse p...
# 14           27259  "Sono abbstanza d'accordo sulla questione rumo...
# 15           27259
# 16            3582  'Ecco le prime immagini in veste definitiva ht...
# 17           27259
# 18             112
# 19           27259
# 20            3582  'La 911-992 dovrebbe essere presentata al Salo...
# 21            2742
# 22           27259
# 23             831
# 24             762
# 25            8758
# 26           27259
# 27            4878
# 28            2742
# 29            2742
# ...            ...                                                ...
# 2327           890
# 2328           272  La leva del cambio, ancorch\xe9 automatico, \x...
# 2329           273  Ovviamente vettura facile da guidare, ma comun...
# 2330         10794
# 2331          1260
# 2332         14119
# 2333          8113
# 2334          1261
# 2335          2682
# 2336          8114
# 2337          2559
# 2338          5829
# 2339           565
# 2340           672
# 2341          2392  Ma nessuna auto come la 911 \xe8 cos\xec evide...
# 2342          8115                    Poni,aspettiamo il tuo giudizio
# 2343         11398
# 2344          2395
# 2345         10573                           Dall'alto \xe8 splendida
# 2346         16676
# 2347           566
# 2348          1658  E quindi, a mio avviso, questo dovrebbe essere...
# 2349          1336
# 2350           952
# 2351           276  Alla destra vorrei vedere parcheggiata una 997...
# 2352          5830
# 2353           130
# 2354          1337
# 2355           129
# 2356           122
#
#                                                    Text       Engine  \
# 0     Stanno circolando sul web le prime immagini di...       neutro
# 1     Dovrebbe essere presentata entro l'anno la Por...       neutro
# 2     A me va benissimo. E mantiene il vecchio, caro...       neutro
# 3     Per fortuna. Perché quello sarebbe un po' sven...     positivo
# 4     Si, sulla 911 di serie il motore centrale non ...       neutro
# 5     Proseguono i test al "Ring" della 992, in part...  irrilevante
# 6     Ancora test al "Ring" per l'attesa Porsche 911...  irrilevante
# 7     Io sono convinto che in ogni caso difficilment...  irrilevante
# 8     Ame della 911 (le versioni aspirate) quello ch...  irrilevante
# 9     chissà se ce la faranno a mettere il navigator...  irrilevante
# 10    Bellissimo, senz'altro. Però non è che possa s...     positivo
# 11    Non ho ragione (imho) di dubitare che anche se...     positivo
# 12    Il suono del V8 Maserati è bellissimo, forse p...     positivo
# 13    Sono abbstanza d'accordo sulla questione rumor...     positivo
# 14    Esatto, anche a me il rumore eccessivo dà un p...  irrilevante
# 15    Ecco le prime immagini in veste definitiva. ht...  irrilevante
# 16    A me piace, forse i fari posteriori senza vari...  irrilevante
# 17    Si, il giallo è un colore che sta sempre bene ...  irrilevante
# 18    La 911 (che detesto per gelosia: gelosia nei c...  irrilevante
# 19    La 911-992 dovrebbe essere presentata al Salon...  irrilevante
# 20                                                   .   irrilevante
# 21    Uscite le foto... che dire.. a me piace da sem...  irrilevante
# 22    Io posso solo sognarla, comunque è sempre bell...  irrilevante
# 23                                          sempre top        neutro
# 24    La adoro, ovviamente mi piace anche quest'ulti...  irrilevante
# 25    Carina, anche se un po' massiccia nella parte ...  irrilevante
# 26    Mah, a vederla così, nel filmato di Quattroruo...  irrilevante
# 27    Quelle griglie sotto il lunotto non mi convinc...  irrilevante
# 28    Pregevole il richiamo in legno alla 901 <img a...  irrilevante
# 29                                                edit   irrilevante
# ...                                                 ...          ...
# 2327                        eh...ma IL SOUND???????????       neutro
# 2328    Ricorda, in peggio (e non era facile..), que...  irrilevante
# 2329    Ne parlavo proprio oggi pomeriggio in una ch...  irrilevante
# 2330  Caro Lamberto sono d'accordissimo con te, orma...  irrilevante
# 2331  Qui si vedono meglio le differenze con la 991 ...  irrilevante
# 2332  La cosa pi\xf9 eclatante, che segue un corso c...  irrilevante
# 2333                                   a cosa somiglia?  irrilevante
# 2334                                    Alla 993 targa.  irrilevante
# 2335  si ci assomiglia (dall'alto)....ma se la metti...       neutro
# 2336        io ci vedo i parafanghi wide del 964 turbo   irrilevante
# 2337                        Dall'alto \xe8 splendida !!  irrilevante
# 2338  Un piccolo contributo.  Vediamo come \xe8 evol...  irrilevante
# 2339                    Poni,aspettiamo il tuo giudizio  irrilevante
# 2340  Andrea 70,  per quello che conta questa volta ...  irrilevante
# 2341   Concordo pienamente ed \xe8 questo (oltre che...  irrilevante
# 2342    non so se ci avete mai fatto caso, ma in 14 ...  irrilevante
# 2343  Mah, io un dubbio ( forte) l'avrei: " come vuo...  irrilevante
# 2344  Franco, fanno bene a non fare ricerche di merc...  irrilevante
# 2345   Alessandro,quando riusciranno a farle percorr...     positivo
# 2346                         Andrea70 +1  Poniello +1    irrilevante
# 2347                            Andrea70 +2 Poniello +2  irrilevante
# 2348   +3 ... aggiungerei alle tavole da surf sulle ...  irrilevante
# 2349  Andrea70 ritengo i tuoi interventi e vecchi po...  irrilevante
# 2350  La 911 \xe8 nata come auto sportiva ma versati...  irrilevante
# 2351    Grande Andrea  in effetti se bisogna sognare...  irrilevante
# 2352  Andreaverona,  Capisco il tuo intervento . Per...     positivo
# 2353  Sempre affascinante e desiderabile...ma quando...       neutro
# 2354  Chiarissimo Andrea, come sempre.  E sinceri co...  irrilevante
# 2355        https://www.youtube.com/watch?v=Zyjei2FI1Fo  irrilevante
# 2356  bello il paragone 911 / golf di andrea 70!  So...  irrilevante
#
#             Brand
# 0          neutro
# 1     irrilevante
# 2     irrilevante
# 3     irrilevante
# 4     irrilevante
# 5     irrilevante
# 6     irrilevante
# 7        positivo
# 8     irrilevante
# 9     irrilevante
# 10    irrilevante
# 11    irrilevante
# 12    irrilevante
# 13    irrilevante
# 14    irrilevante
# 15    irrilevante
# 16       positivo
# 17       positivo
# 18       positivo
# 19    irrilevante
# 20       positivo
# 21    irrilevante
# 22    irrilevante
# 23       positivo
# 24    irrilevante
# 25    irrilevante
# 26       positivo
# 27    irrilevante
# 28    irrilevante
# 29    irrilevante
# ...           ...
# 2327  irrilevante
# 2328     positivo
# 2329     positivo
# 2330     positivo
# 2331     positivo
# 2332     positivo
# 2333  irrilevante
# 2334  irrilevante
# 2335  irrilevante
# 2336  irrilevante
# 2337  irrilevante
# 2338     positivo
# 2339  irrilevante
# 2340  irrilevante
# 2341  irrilevante
# 2342     negativo
# 2343     negativo
# 2344     positivo
# 2345  irrilevante
# 2346  irrilevante
# 2347  irrilevante
# 2348  irrilevante
# 2349     positivo
# 2350  irrilevante
# 2351     negativo
# 2352     positivo
# 2353  irrilevante
# 2354  irrilevante
# 2355  irrilevante
# 2356  irrilevante
#
# [2357 rows x 11 columns]

# %%
new_unlabeled_dataset.to_csv('unlabeled/unlabeled_dataset_engine.csv')

# %%
import dill
dill.dump_session('notebook_env.db')

# %%
import dill
dill.load_session('notebook_env.db')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-c20f3932f3ec> in <module>
#       1 import dill
# ----> 2 dill.load_session('notebook_env.db')
#
# /usr/local/lib/python3.6/dist-packages/dill/_dill.py in load_session(filename, main)
#     408         unpickler._main = main
#     409         unpickler._session = True
# --> 410         module = unpickler.load()
#     411         unpickler._session = False
#     412         main.__dict__.update(module.__dict__)
#
# /usr/local/lib/python3.6/dist-packages/dill/_dill.py in _load_type(name)
#     575
#     576 def _load_type(name):
# --> 577     return _reverse_typemap[name]
#     578
#     579 def _create_type(typeobj, *args):
#
# KeyError: 'ClassType'
